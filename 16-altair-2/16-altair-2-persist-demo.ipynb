# %%
# !pip install persist_ext==1.5.1

# %% [markdown]
# ## PersIst: Persistent Interactions in Computational Notebooks
#
# At Visualization Design Lab (VDL) we are working on a JupyterLab extension called `PersIst` which allows us to persist and replay our interactions done in notebook by tracking the provenance of the interactions done. It supports tracking interactions on Vega-Altair Charts as well as an interactive data table to manipulate data.
#
# The provenance tracking in PersIst is powered by another project from VDL called [Trrack](https://apps.vdl.sci.utah.edu/trrack) which allows us to track interaction history and reproduce them later.
#
# After transforming the data using interactions, we can directly create new Python variables to use the resulting dataframe in our code.
#
# All the interactions and created variables are saved. PersIst goes beyond Vega-Altair and supports multiple interactions like __filtering__, __annotating__, __assigning category__, __rename & drop columns__, etc.
#
# Let's look at a quick demo

# %%
import persist_ext as PR
from vega_datasets import data
import altair as alt

# %%
iris = data.iris()
iris
# Out:
#      sepalLength  sepalWidth  petalLength  petalWidth    species
# 0            5.1         3.5          1.4         0.2     setosa
# 1            4.9         3.0          1.4         0.2     setosa
# 2            4.7         3.2          1.3         0.2     setosa
# 3            4.6         3.1          1.5         0.2     setosa
# 4            5.0         3.6          1.4         0.2     setosa
# ..           ...         ...          ...         ...        ...
# 145          6.7         3.0          5.2         2.3  virginica
# 146          6.3         2.5          5.0         1.9  virginica
# 147          6.5         3.0          5.2         2.0  virginica
# 148          6.2         3.4          5.4         2.3  virginica
# 149          5.9         3.0          5.1         1.8  virginica
#
# [150 rows x 5 columns]

# %%
scatterplot = PR.vis.scatterplot(iris, x="sepalLength:Q", y="sepalWidth:Q", color="species", height=300, width=300)
scatterplot
# Out:
# OutputWithTrrackWidget(body_widget=VegaLiteChartWidget(debounce_wait=250.0, df_columns=['sepalLength', 'sepalW…

# %%
processed_df_dyn = PR.df.get("processed_df_dyn")
processed_df_dyn
# Out:
#      sepal_length  sepalWidth  petalLength  petalWidth    species  \
# 0             4.9         3.0          1.4         0.2     setosa
# 1             5.4         3.9          1.7         0.4     setosa
# 2             4.4         2.9          1.4         0.2     setosa
# 3             5.4         3.7          1.5         0.2     setosa
# 4             4.8         3.0          1.4         0.1     setosa
# ..            ...         ...          ...         ...        ...
# 113           6.7         3.0          5.2         2.3  virginica
# 114           6.3         2.5          5.0         1.9  virginica
# 115           6.5         3.0          5.2         2.0  virginica
# 116           6.2         3.4          5.4         2.3  virginica
# 117           5.9         3.0          5.1         1.8  virginica
#
#                       __annotations
# 0    23-10-23 (13:36) - Interesting
# 1                     No Annotation
# 2    23-10-23 (13:36) - Interesting
# 3                     No Annotation
# 4    23-10-23 (13:36) - Interesting
# ..                              ...
# 113                   No Annotation
# 114                   No Annotation
# 115                   No Annotation
# 116  23-10-23 (13:36) - Interesting
# 117  23-10-23 (13:36) - Interesting
#
# [118 rows x 6 columns]

# %%
filtered_dataset = PR.df.get("filtered_dataset")
filtered_dataset
# Out:
#      sepalLength  sepalWidth  petalLength  petalWidth    species  \
# 0            4.9         3.0          1.4         0.2     setosa
# 1            5.4         3.9          1.7         0.4     setosa
# 2            4.4         2.9          1.4         0.2     setosa
# 3            5.4         3.7          1.5         0.2     setosa
# 4            4.8         3.0          1.4         0.1     setosa
# ..           ...         ...          ...         ...        ...
# 113          6.7         3.0          5.2         2.3  virginica
# 114          6.3         2.5          5.0         1.9  virginica
# 115          6.5         3.0          5.2         2.0  virginica
# 116          6.2         3.4          5.4         2.3  virginica
# 117          5.9         3.0          5.1         1.8  virginica
#
#      __annotations
# 0    No Annotation
# 1    No Annotation
# 2    No Annotation
# 3    No Annotation
# 4    No Annotation
# ..             ...
# 113  No Annotation
# 114  No Annotation
# 115  No Annotation
# 116  No Annotation
# 117  No Annotation
#
# [118 rows x 6 columns]

# %%
cars = data.cars()

selection = alt.selection_interval(name="selection", encodings=["x"])

chart = alt.Chart(cars).mark_bar().encode(
    x="utcyear(Year):O",
    y="count()",
    color=alt.condition(selection, alt.value("steelblue"), alt.value("gray"))
).add_params(
    selection
)

PR.vis.TrrackableChart(chart)
# Out:
# OutputWithTrrackWidget(body_widget=VegaLiteChartWidget(debounce_wait=250.0, df_columns=['Name', 'Miles_per_Gal…

# %%
era_df = PR.df.get("era_df")
era_df
# Out:
#                           Name  Miles_per_Gallon  Cylinders  Displacement  \
# 0    chevrolet chevelle malibu              18.0          8         307.0
# 1            buick skylark 320              15.0          8         350.0
# 2           plymouth satellite              18.0          8         318.0
# 3                amc rebel sst              16.0          8         304.0
# 4                  ford torino              17.0          8         302.0
# ..                         ...               ...        ...           ...
# 401            ford mustang gl              27.0          4         140.0
# 402                  vw pickup              44.0          4          97.0
# 403              dodge rampage              32.0          4         135.0
# 404                ford ranger              28.0          4         120.0
# 405                 chevy s-10              31.0          4         119.0
#
#      Horsepower  Weight_in_lbs  Acceleration       Year  Origin  \
# 0         130.0           3504          12.0 1970-01-01     USA
# 1         165.0           3693          11.5 1970-01-01     USA
# 2         150.0           3436          11.0 1970-01-01     USA
# 3         150.0           3433          12.0 1970-01-01     USA
# 4         140.0           3449          10.5 1970-01-01     USA
# ..          ...            ...           ...        ...     ...
# 401        86.0           2790          15.6 1982-01-01     USA
# 402        52.0           2130          24.6 1982-01-01  Europe
# 403        84.0           2295          11.6 1982-01-01     USA
# 404        79.0           2625          18.6 1982-01-01     USA
# 405        82.0           2720          19.4 1982-01-01     USA
#
#      __annotations        Era
# 0    No Annotation  Early 70s
# 1    No Annotation  Early 70s
# 2    No Annotation  Early 70s
# 3    No Annotation  Early 70s
# 4    No Annotation  Early 70s
# ..             ...        ...
# 401  No Annotation        80s
# 402  No Annotation        80s
# 403  No Annotation        80s
# 404  No Annotation        80s
# 405  No Annotation        80s
#
# [406 rows x 11 columns]

# %%
categorized_df_grouped = PR.df.get("categorized_df_grouped", groupby="Era", aggregate={"Miles_per_Gallon": "mean", "Cylinders": "mean", "Displacement": "mean", "Horsepower": "mean", "Weight_in_lbs": "mean", "Acceleration": "mean"})
categorized_df_grouped
# Out:
#            Miles_per_Gallon  Cylinders  Displacement  Horsepower  \
# Era
# 80s               31.908989   4.311111    126.655556   80.406977
# Early 70s         18.528000   6.196970    245.450758  127.725191
# Late 70s          24.176344   5.537634    190.903226  101.784946
# Mid-70s           21.478022   5.516484    192.615385   99.111111
#
#            Weight_in_lbs  Acceleration
# Era
# 80s          2474.311111     16.613333
# Early 70s    3285.704545     14.280303
# Late 70s     2962.967742     15.696774
# Mid-70s      3051.483516     16.054945

# %%
PR.vis.interactive_table(cars)
# Out:
# OutputWithTrrackWidget(body_widget=InteractiveTableWidget(df_columns=['Name', 'Miles_per_Gallon', 'Cylinders',…

# %%
data_table_df_dyn = PR.df.get("data_table_df_dyn")
data_table_df_dyn
# Out:
#                              Name   mpg  Cylinders  Displacement  Horsepower  \
# 19        buick estate wagon (sw)  14.0          8         455.0       225.0
# 8                pontiac catalina  14.0          8         455.0       225.0
# 102      buick electra 225 custom  12.0          8         455.0       225.0
# 6                chevrolet impala  14.0          8         454.0       220.0
# 101  chrysler new yorker brougham  13.0          8         440.0       215.0
# ..                            ...   ...        ...           ...         ...
# 60            toyota corolla 1200  31.0          4          71.0        65.0
# 118                     maxda rx3  18.0          3          70.0        90.0
# 78                mazda rx2 coupe  19.0          3          70.0        97.0
# 341                 mazda rx-7 gs  23.7          3          70.0       100.0
# 124                      fiat 128  29.0          4          68.0        49.0
#
#      Weight_in_lbs  Acceleration       Year  Origin  __annotations
# 19            3086          10.0 1970-01-01     USA  No Annotation
# 8             4425          10.0 1970-01-01     USA  No Annotation
# 102           4951          11.0 1973-01-01     USA  No Annotation
# 6             4354           9.0 1970-01-01     USA  No Annotation
# 101           4735          11.0 1973-01-01     USA  No Annotation
# ..             ...           ...        ...     ...            ...
# 60            1773          19.0 1971-01-01   Japan  No Annotation
# 118           2124          13.5 1973-01-01   Japan  No Annotation
# 78            2330          13.5 1972-01-01   Japan  No Annotation
# 341           2420          12.5 1980-01-01   Japan  No Annotation
# 124           1867          19.5 1973-01-01  Europe  No Annotation
#
# [406 rows x 10 columns]

# %%
h
