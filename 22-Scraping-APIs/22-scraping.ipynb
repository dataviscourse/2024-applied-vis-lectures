# %% [markdown]
# # Applied Data Visualization – Web Scraping
#
# In this lecture we will explore how we can extract data from a web-page using automatic scraping and crawling with [Beautiful Soup](https://www.crummy.com/software/BeautifulSoup/bs4/doc/).
#
# First, we'll talk a bit about HTML though.

# %%
# install html5lib
#!pip install html5lib
# install lxml
#!pip install lxml

# %%
import matplotlib
import matplotlib.pyplot as plt
import pandas as pd
plt.style.use('default')
# %matplotlib inline
import matplotlib_inline
matplotlib_inline.backend_inline.set_matplotlib_formats('svg', 'pdf')

# %% [markdown]
# ## HTML and the DOM
#
# We will scrape web-pages that are (partially) written in HTML and represented in the DOM. DOM stands for  Document Object Model, while HTML stands for “HyperText Markup Language”. 25 years ago, that used to be a meaningful description of what HTML actually did: it has links (hypertext), and it is a markup language. The latest version of HTML, however, the HTML5 standard, does much, much more: graphics, audio, video, etc. So it is easier to think of HTML as “whatever it is that web browsers know how to interpret”, and just not think about the actual term.

# %% [markdown]
# ### Elements
#
# The important thing about HTML is that the markup is represented by elements. An HTML element is a portion of the content that is surrounded by a pair of tags of the same name. Like this:
#
# ```html
# <strong>This is an HTML element.</strong>
# ```
#
# In this element, strong is the name of the tag; the open tag is `<strong>`, and the matching closing tag is `</strong>`. The way you should interpret this is that the text “This is an HTML element” should be “strong”, i.e., typically this will be bold text.
#
# HTML elements can and commonly do nest:
#
# ```html
# <strong>This is strong, and <u>this is underlined and strong.</u></strong>
# ```
#
# In addition to the names, opening tags can contain extra information about the element. These are called attributes:
#
# ```html
# <a href='http://www.google.com'>A link to Google's main page</a>
# ```
#
# In this case, we’re using the `a` element which stood for “anchor”, but now is almost universally used as a “link”. The attribute `href` means “HTML reference”, which actually makes sense for a change. The meaning given to each attribute changes from element to element.
#
# Important attributes for our purposes are `id` and `class`. The id attribute gives the attribute a unique identifier, which can then be used to access the element programmatically. Think of it as making the element accessible via a global variable.
#
# The class is similar but is intendent to be applied to a whole “class” of elements.
#
# HTML pages require some boilerplate. Here is a minimal page:
#
# ```html
# <!DOCTYPE html>
# <html lang="en">
# <head>
#     <meta charset="UTF-8">
#     <title></title>
# </head>
# <body>
# Hello World! What's up?
# </body>
# </html>
# ```
#
# The `<head>` contains meta-information such as the titel of the site, the `<body>` contains the actual data.

# %% [markdown]
# ### Hierarchy
#
# Data in HTML is often structured hirearchically:
#
# ```html
# <body>
#   <article>
#     <span class="date">Published: 1969-10-22</span>
#     <span class="author">Led Zeppelin</span>
#     <h1>Ramble On</h1>
#     <div class="content">
#     Leaves are falling all around, It's time I was on my way.
#     Thanks to you, I'm much obliged for such a pleasant stay.
#     But now it's time for me to go. The autumn moon lights my way.
#     For now I smell the rain, and with it pain, and it's headed my way.
#     </div>
#   </article>
#   <article>
#     <span class="date">Published: 2016-05-03</span>
#     <span class="author">Radiohead</span>
#     <h1>Burn the Witch</h1>
#     <div class="content">
#     Stay in the shadows
#     Cheer at the gallows
#     This is a round up
#     This is a low flying panic attack
#     Sing a song on the jukebox that goes
#     Burn the witch
#     Burn the witch
#     We know where you live
#     </div>
#   </article>
# </body>
# ```
#
# Here, the title of the song is nested three levels deep: `body > article > h1`.

# %% [markdown]
# ### Tables
#
# Data is also often stored in HTML tables, which are enclosed in a `<table>` tag. `<tr>` indicates a row (table row), `<th>` and `<td>` are used to demark cells, either header cells (`<th>`, table header) or regular cells (`<td>`, table data). Here's an example:
#
# ```html
# <table>
#     <tr>
#         <th></th>
#         <th>The Beatles</th>
#         <th>Led Zeppelin</th>
#     </tr>
#     <tr>
#         <td># Band Members</td>
#         <td>4</td>
#         <td>4</td>
#     </tr>
# </table>
# ```

# %% [markdown]
# ### The DOM
#
# As we have seen above, a markup document looks a lot like a tree: it has a root, the HTML element, and elements can have children that are containing elements themselves.
#
# While HTML is a textual representation of a markup document, the DOM is a programming interface for it. Also the DOM represents the state of a page as it's rendered, that (nowadays) doesn't mean that there is an underlying HTML document that corresponds to that exactly. Rather, the DOM is dynamically generated with, e.g., JavaScript.
#
# In this class we will use “DOM” to mean the tree created by the web browsers to represent the document.
#
# #### Inspecting the DOM in a browser
#
# Perhaps the most important habit when scraping is to investigate the source of a page using the Developer Tools. In this case, we’ll look at the **element tree**, by clicking on the menu bar: View → Developer → Developer Tools.
#
# Alternatively, you can right click on any part of the webpage, and choose “Inspect Element”. Notice that there can be a big difference between what is in the DOM and what is in the source.
#
# Take a look at the DOM of [this html page](lyrics.html). Next, we'll scrape the data from this page!

# %% [markdown]
# # Scraping with BeautifulSoup
#
# [BeautifulSoup](https://www.crummy.com/software/BeautifulSoup/) is a Python library design for computationally extracting data from html documents. It supports navigating in the DOM and retreiving exactly the data elements you need.
#
# Let's start with a simple example using the [lyrics.html](lyrics.html) file.

# %%
from bs4 import BeautifulSoup

# we tell BeautifulSoup and tell it which parser to use
song_soup = BeautifulSoup(open("lyrics.html"), "html.parser")
# the output corresponds exactly to the html file
song_soup
# Out:
# <!DOCTYPE html>
#
# <html lang="en">
# <head>
# <meta charset="utf-8"/>
# <title>Lyrics</title>
# </head>
# <body>
# <article id="zep">
# <span class="date">Published: 1969-10-22</span>
# <span class="author">Led Zeppelin</span>
# <h1>Ramble On</h1>
# <div class="content">
#     Leaves are falling all around, It's time I was on my way.
#     Thanks to you, I'm much obliged for such a pleasant stay.
#     But now it's time for me to go. The autumn moon lights my way.
#     For now I smell the rain, and with it pain, and it's headed my way.
#     </div>
# </article>
# <article id="radio">
# <span class="date">Published: 2016-05-03</span>
# <span class="author">Radiohead</span>
# <h1>Burn the Witch</h1>
# <div class="content">
#     Stay in the shadows
#     Cheer at the gallows
#     This is a round up
#     This is a low flying panic attack
#     Sing a song on the jukebox that goes
#     Burn the witch
#     Burn the witch
#     We know where you live
#     </div>
# </article>
# </body>
# </html>

# %% [markdown]
# Sometimes, generated (minified) html can be hard to read (not in this case), so we can format it:

# %%
print(song_soup.prettify())
# Out:
# <!DOCTYPE html>
# <html lang="en">
#  <head>
#   <meta charset="utf-8"/>
#   <title>
#    Lyrics
#   </title>
#  </head>
#  <body>
#   <article id="zep">
#    <span class="date">
#     Published: 1969-10-22
#    </span>
#    <span class="author">
#     Led Zeppelin
#    </span>
#    <h1>
#     Ramble On
#    </h1>
#    <div class="content">
#     Leaves are falling all around, It's time I was on my way.
#     Thanks to you, I'm much obliged for such a pleasant stay.
#     But now it's time for me to go. The autumn moon lights my way.
#     For now I smell the rain, and with it pain, and it's headed my way.
#    </div>
#   </article>
#   <article id="radio">
#    <span class="date">
#     Published: 2016-05-03
#    </span>
#    <span class="author">
#     Radiohead
#    </span>
#    <h1>
#     Burn the Witch
#    </h1>
#    <div class="content">
#     Stay in the shadows
#     Cheer at the gallows
#     This is a round up
#     This is a low flying panic attack
#     Sing a song on the jukebox that goes
#     Burn the witch
#     Burn the witch
#     We know where you live
#    </div>
#   </article>
#  </body>
# </html>

# %% [markdown]
# We can access content by tags:

# %%
# get the title tag
song_soup.title
# Out:
# <title>Lyrics</title>

# %% [markdown]
# And get the text out of the tag:

# %%
song_soup.title.string
# Out:
# 'Lyrics'

# %% [markdown]
# Directly accessing an element works for the first occurence of a tag, we don't get the others.

# %%
song_soup.div
# Out:
# <div class="content">
#     Leaves are falling all around, It's time I was on my way.
#     Thanks to you, I'm much obliged for such a pleasant stay.
#     But now it's time for me to go. The autumn moon lights my way.
#     For now I smell the rain, and with it pain, and it's headed my way.
#     </div>

# %% [markdown]
# Again, we can retreive the text content of an element:

# %%
print(song_soup.div.string)
# Out:
#     Leaves are falling all around, It's time I was on my way.
#     Thanks to you, I'm much obliged for such a pleasant stay.
#     But now it's time for me to go. The autumn moon lights my way.
#     For now I smell the rain, and with it pain, and it's headed my way.

# %% [markdown]
# We can use attributes to find a specific element:

# %%
song_soup.find(id="zep")
# Out:
# <article id="zep">
# <span class="date">Published: 1969-10-22</span>
# <span class="author">Led Zeppelin</span>
# <h1>Ramble On</h1>
# <div class="content">
#     Leaves are falling all around, It's time I was on my way.
#     Thanks to you, I'm much obliged for such a pleasant stay.
#     But now it's time for me to go. The autumn moon lights my way.
#     For now I smell the rain, and with it pain, and it's headed my way.
#     </div>
# </article>

# %% [markdown]
#  We can also get only the text, not the html markup with [`find()`](https://www.crummy.com/software/BeautifulSoup/bs4/doc/#find):

# %%
text = song_soup.find(id="zep").get_text()
print(text)
# Out:
# Published: 1969-10-22
# Led Zeppelin
# Ramble On
#
#     Leaves are falling all around, It's time I was on my way.
#     Thanks to you, I'm much obliged for such a pleasant stay.
#     But now it's time for me to go. The autumn moon lights my way.
#     For now I smell the rain, and with it pain, and it's headed my way.

# %% [markdown]
# We can also use [find_all()](https://www.crummy.com/software/BeautifulSoup/bs4/doc/#calling-a-tag-is-like-calling-find-all) to get all instances of a tag:

# %%
h1s = song_soup.find_all("h1")
h1s
# Out:
# [<h1>Ramble On</h1>, <h1>Burn the Witch</h1>]

# %% [markdown]
# This returns a list of beautiful soup elements:

# %%
type(h1s[0])
# Out:
# bs4.element.Tag

# %% [markdown]
# It's easy to get the text out of this:

# %%
string_h1s = [tag.get_text() for tag in h1s]
string_h1s
# Out:
# ['Ramble On', 'Burn the Witch']

# %% [markdown]
# Since `find_all` is so commonly used, you can use a shortcut by just calling directly on an object:

# %%
song_soup("div")
# Out:
# [<div class="content">
#      Leaves are falling all around, It's time I was on my way.
#      Thanks to you, I'm much obliged for such a pleasant stay.
#      But now it's time for me to go. The autumn moon lights my way.
#      For now I smell the rain, and with it pain, and it's headed my way.
#      </div>,
#  <div class="content">
#      Stay in the shadows
#      Cheer at the gallows
#      This is a round up
#      This is a low flying panic attack
#      Sing a song on the jukebox that goes
#      Burn the witch
#      Burn the witch
#      We know where you live
#      </div>]

# %% [markdown]
# We can address the elements in the returned object directly:

# %%
song_soup("div")[1]
# Out:
# <div class="content">
#     Stay in the shadows
#     Cheer at the gallows
#     This is a round up
#     This is a low flying panic attack
#     Sing a song on the jukebox that goes
#     Burn the witch
#     Burn the witch
#     We know where you live
#     </div>

# %% [markdown]
# Or iterate over it:

# %%
for p in song_soup.find_all("div"):
    print("---")
    print(p)
# Out:
# ---
# <div class="content">
#     Leaves are falling all around, It's time I was on my way.
#     Thanks to you, I'm much obliged for such a pleasant stay.
#     But now it's time for me to go. The autumn moon lights my way.
#     For now I smell the rain, and with it pain, and it's headed my way.
#     </div>
# ---
# <div class="content">
#     Stay in the shadows
#     Cheer at the gallows
#     This is a round up
#     This is a low flying panic attack
#     Sing a song on the jukebox that goes
#     Burn the witch
#     Burn the witch
#     We know where you live
#     </div>

# %% [markdown]
# ### CSS Selectors
#
# We can also use CSS selectors. CSS Selectors apply, among others, to elements, classes, and IDs.
#
# Below is an example of how CSS is used to style different elements.
#
#
# ```CSS
# /* Element Selector */
# article {
#   color: FireBrick;
# }
#
# /* ID selector */
# #myID {
#   color: Tomato;
# }
#
# /* Class selector */
# .myClass {
#   color: Aquamarine;
# }
#
# /* Child selector. Only DIRECT children match */
# p > b {
#   color: SteelBlue;
# }
#
# /* Descendant selector. Every time a b is nested within a div this matches */
# div b {
#   color: green;
# }
#
# ```
#
# [Here is an example](https://jsfiddle.net/gxhqv26m/1/) with all the important selectors.
#
# Let's try this in Python:

# %%
# selecting all elements of class .content
song_soup.select(".content")
# Out:
# [<div class="content">
#      Leaves are falling all around, It's time I was on my way.
#      Thanks to you, I'm much obliged for such a pleasant stay.
#      But now it's time for me to go. The autumn moon lights my way.
#      For now I smell the rain, and with it pain, and it's headed my way.
#      </div>,
#  <div class="content">
#      Stay in the shadows
#      Cheer at the gallows
#      This is a round up
#      This is a low flying panic attack
#      Sing a song on the jukebox that goes
#      Burn the witch
#      Burn the witch
#      We know where you live
#      </div>]

# %%
# selecting all divs that are somewhere below the id radio in the tree
song_soup.select("#radio div")
# Out:
# [<div class="content">
#      Stay in the shadows
#      Cheer at the gallows
#      This is a round up
#      This is a low flying panic attack
#      Sing a song on the jukebox that goes
#      Burn the witch
#      Burn the witch
#      We know where you live
#      </div>]

# %% [markdown]
# OK, now we know how to extract information out of a website. Let's look at a complete example.

# %% [markdown]
# ## Fetching a Website
#
# Downloading websites is easy and very efficient. It turns out, that you can cause quite a high load on a server when you scrape it. To avoid that, webmasters usually publish what kinds of scraping they allow on their websites. You should check out a website's terms of service and the `robots.txt` of a domain before crawling excessively. Terms of service are usually broad, so searching for “scraping” or “crawling” is a good idea.
#
# Let's take a look at [Google Scholar's robots.txt](https://scholar.google.com/robots.txt):
#
# ```
# User-agent: *
# Disallow: /search
# Allow: /search/about
# Disallow: /sdch
# Disallow: /groups
# Disallow: /index.html?
# Disallow: /?
# Allow: /?hl=
# ...
# Disallow: /scholar
# Disallow: /citations?
# ...
# ```
#
# Here it specifies that you're not allowed to crawl a lot of the pages. The `/scholar` subdirectory is especially painful because it prohibits you from generating queries dynamically.
#
# It's also common that sites ask you to delay crawiling:
#
# ```
# Crawl-delay: 30
# Request-rate: 1/30
# ```
#
# You should respect those restrictions. Now, no one can stop you from running a request through a crawler, but sites like google scholar will block you VERY quickly if you request to many pages in a short time-frame.
#
# An alternative strategy to dynamically accessing the site you're crawling (as we're doing in the next example) is to download a local copy of the website and crawl that. This ensures that you hit the site only once per page. A good tool to achieve that is [wget](https://www.gnu.org/software/wget/).

# %% [markdown]
# ### Example: Utah's course enrollments
#
# We're going to build a dataset of classes offered next spring at the U and look at the enrollment numbers. We'll use the catalog listed here:
# https://class-schedule.app.utah.edu/main/1254/class_list.html?subject=CS
#
# The U doesn't seem to care whether/how we crawl the websites, the [fineprint](https://www.utah.edu/disclaimer/) doesn't mention it and there is no `robots.txt`: http://www.utah.edu/robots.txt
#
# We'll use the [`urllib.request`](https://docs.python.org/3.0/library/urllib.request.html) library to retreive the websites.

# %%
import urllib.request
url = "https://class-schedule.app.utah.edu/main/1254/"
# here we actually access the website
with urllib.request.urlopen(url) as response:
    html = response.read()
    html = html.decode('utf-8')

# save the file
with open('class_schedule.html', 'w') as new_file:
    new_file.write(html)

# here it's already a local operation
soup = BeautifulSoup(html, 'html.parser')

# %% [markdown]
# Let's take a look at the first 5000 characters of this page:

# %%
print(soup.prettify()[0:5000])
# Out:
# <!DOCTYPE html>
# <html lang="en" xmlns="http://www.w3.org/1999/xhtml">
#  <head>
#   <title>
#    Class Schedules
#   </title>
#   <meta charset="utf-8"/>
#   <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
#   <meta content="width=device-width, initial-scale=1" name="viewport"/>
#   <link href="https://fonts.googleapis.com/css?family=Open+Sans+Condensed:300,300i,700" rel="stylesheet"/>
#   <link href="https://fonts.googleapis.com/css?family=Open+Sans:300,300i,400,400i,600,600i,700,700i,800,800i" rel="stylesheet"/>
#   <link href="/static/bootstrap/main.css" rel="stylesheet"/>
#   <link href="/static/bootstrap/addins.css" rel="stylesheet"/>
#   <link href="/static/images/favicon.ico" rel="icon" type="image/png"/>
#   <link crossorigin="anonymous" href="https://cdn.jsdelivr.net/npm/bootstrap-icons@1.11.3/font/bootstrap-icons.min.css" integrity="sha256-9kPW/n5nn53j4WMRYAxe9c1rCY96Oogo/MKSVdKzPmI=" rel="stylesheet"/>
#   <link crossorigin="anonymous" href="https://cdn.jsdelivr.net/npm/jquery-ui@1.14.0/themes/base/all.css" integrity="sha256-DNKQmjU2FwFhSgFxlOahFCaiqQopMbZpuG9BKuO20zs=" rel="stylesheet"/>
#   <script crossorigin="anonymous" integrity="sha256-/JqT3SQfawRcv/BIHPThkBvs0OEvtFFmqPF/lYI/Cxo=" nonce="LVLVR2W/wB2neSPTFaUNZty2vabHzfckPUmxhC954Tw=" src="https://cdn.jsdelivr.net/npm/jquery@3.7.1/dist/jquery.min.js">
#   </script>
#   <script crossorigin="anonymous" integrity="sha256-Fb0zP4jE3JHqu+IBB9YktLcSjI1Zc6J2b6gTjB0LpoM=" nonce="LVLVR2W/wB2neSPTFaUNZty2vabHzfckPUmxhC954Tw=" src="https://cdn.jsdelivr.net/npm/jquery-ui@1.14.0/dist/jquery-ui.min.js">
#   </script>
#   <script crossorigin="anonymous" integrity="sha384-kenU1KFdBIe4zVF0s0G1M5b4hcpxyD9F7jL+jjXkk+Q2h455rYXK/7HAuoJl+0I4" nonce="LVLVR2W/wB2neSPTFaUNZty2vabHzfckPUmxhC954Tw=" src="https://cdn.jsdelivr.net/npm/bootstrap@5.2.3/dist/js/bootstrap.bundle.min.js">
#   </script>
#   <!-- Google tag (gtag.js) -->
#   <script async="" nonce="LVLVR2W/wB2neSPTFaUNZty2vabHzfckPUmxhC954Tw=" src="https://www.googletagmanager.com/gtag/js?id=G-3JD7YQZW6Z">
#   </script>
#   <script nonce="LVLVR2W/wB2neSPTFaUNZty2vabHzfckPUmxhC954Tw=" src="/static/scripts/analytics/main.js">
#   </script>
#   <script nonce="LVLVR2W/wB2neSPTFaUNZty2vabHzfckPUmxhC954Tw=" src="/static/scripts/elevator.min.js">
#   </script>
#   <script nonce="LVLVR2W/wB2neSPTFaUNZty2vabHzfckPUmxhC954Tw=" src="/static/scripts/addins.js">
#   </script>
#   <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
#  </head>
#  <body class="d-flex flex-column bg-light">
#   <!--*** START OF NAVIGATION ***-->
#   <nav class="navbar navbar-expand-xxl bg-body-tertiary navbar-dark uu-nav d-print-none p-0">
#    <div class="container-fluid ms-0 ps-0">
#     <div class="align-self-center">
#      <a href="https://utah.edu" target="_blank">
#       <img alt="The University of Utah" class="uu-logo" src="/static/images/uofu.png"/>
#      </a>
#     </div>
#     <button aria-controls="navbarSupportedContent" aria-expanded="false" aria-label="Toggle navigation" class="navbar-toggler" data-bs-target="#navbarSupportedContent" data-bs-toggle="collapse" type="button">
#      <span class="navbar-toggler-icon m-1">
#      </span>
#     </button>
#     <div class="collapse navbar-collapse" id="navbarSupportedContent">
#      <ul class="navbar-nav ms-auto text-nowrap">
#       <li class="nav-item">
#        <a class="nav-link" href="index.html">
#         Home
#        </a>
#       </li>
#       <li class="nav-item dropdown">
#        <a aria-expanded="false" aria-haspopup="true" class="nav-link dropdown-toggle" data-bs-toggle="dropdown" href="#" id="navbarDropdown" role="button">
#         Terms
#        </a>
#        <ul class="dropdown-menu">
#         <li>
#          <a class="dropdown-item" href="/main/1254/index.html">
#           Spring 2025
#          </a>
#         </li>
#         <li>
#          <a class="dropdown-item" href="/main/1248/index.html">
#           Fall 2024
#          </a>
#         </li>
#         <li>
#          <a class="dropdown-item" href="/main/1246/index.html">
#           Summer 2024
#          </a>
#         </li>
#        </ul>
#       </li>
#       <li class="nav-item">
#        <a class="nav-link" href="//registrar.utah.edu/register/schedule-builder.php" target="_blank">
#         Schedule Builder
#        </a>
#       </li>
#       <li class="nav-item">
#        <a class="nav-link" href="//registrar.utah.edu/handbook/" target="_blank">
#         Student Handbook
#        </a>
#       </li>
#       <li class="nav-item">
#        <a class="nav-link" href="//catalog.utah.edu/" target="_blank">
#         General Catalog
#        </a>
#       </li>
#       <li class="nav-item">
#        <a class="nav-link" href="//registrar.utah.edu/academic-calendars/spring2025.php" target="_blank">
#         Academic Calendar
#        </a>
#       </li>
#       <li class="nav-item">
#        <a class="nav-link" href="http://www.bookstore.utah.edu/UTAH/SelectTermDept.aspx" target="_blank">
#         Find Textbooks
#        </a>
#       </li>
#       <li class="nav-item">
#        <a class="nav-link" href="https://student-course-feedback.app.utah.edu" target="_blank">
#         View Cou

# %% [markdown]
# What we want to get out of this page is the link to the subject specific subject course lists.
#
# While you could find this in the text output in python, it's much easier to find the relevant parts in your browser's built in inspector. Here, we've highlighted one of the subjects:
#
# ![Chrome Inspector](inspector.png)

# %% [markdown]
# This is the relevant HTML snippet:
#
# ```html
# <div class="d-grid d-md-block gap-2">
#   <a class="btn btn-light m-1" href="class_list.html?subject=CS">CS - Computer Science</a>
# </div>
# ```
#
# We can scrape this based on the "btn-light" class attribute. Note that this isn't a great class name, and already hints at how brittle scraping is. There are also some other buttons that are styled like this and we'll have to get rid of those.
#
# Let's build a dictionary of subject shorthands to a tuple of the full subject name and links to the relevant courses. For CS this should look like this:
#
# ```
# CS: (Computer Science, https://class-schedule.app.utah.edu/main/1254/class_list.html?subject=CS)
# ```

# %%
subjects = {}

for subject in soup.find_all(class_="btn-light"):
    # the url is relative. 
    # We can get the tail by retrieving the link out the href attribute of the a tag  
    link_tail = subject.get("href")
    # concatenate the base URL and the tail of the link
    link = url + link_tail
    
    subject_name = subject.get_text()
    
    # there are a few extra buttons – the alphabetical index at the top that we want to get rid of
    if len(subject_name) < 2:
        continue
    
    # the subject shortname and name is embedded within the <a> tag, separated by " - "
    subject_short, subject_long = subject_name.split(" - ", 1) 
    # print(subject_short, subject_long)   
    # write it to the dictionary
    subjects[subject_short] = (subject_long, link)

subjects
# Out:
# {'ACCTG': ('Accounting',
#   'https://class-schedule.app.utah.edu/main/1254/class_list.html?subject=ACCTG'),
#  'AEROS': ('Aerospace Studies',
#   'https://class-schedule.app.utah.edu/main/1254/class_list.html?subject=AEROS'),
#  'ANAT': ('Neurobiology and Anatomy',
#   'https://class-schedule.app.utah.edu/main/1254/class_list.html?subject=ANAT'),
#  'ANES': ('Anesthesiology',
#   'https://class-schedule.app.utah.edu/main/1254/class_list.html?subject=ANES'),
#  'ANTH': ('Anthropology',
#   'https://class-schedule.app.utah.edu/main/1254/class_list.html?subject=ANTH'),
#  'ARAB': ('Arabic',
#   'https://class-schedule.app.utah.edu/main/1254/class_list.html?subject=ARAB'),
#  'ARCH': ('Architecture',
#   'https://class-schedule.app.utah.edu/main/1254/class_list.html?subject=ARCH'),
#  'ART': ('Art',
#   'https://class-schedule.app.utah.edu/main/1254/class_list.html?subject=ART'),
#  'ARTH': ('Art History',
#   'https://class-schedule.app.utah.edu/main/1254/class_list.html?subject=ARTH'),
#  'ARTX': ('Arts Technology',
#   'https://class-schedule.app.utah.edu/main/1254/class_list.html?subject=ARTX'),
#  'ASL': ('American Sign Language',
#   'https://class-schedule.app.utah.edu/main/1254/class_list.html?subject=ASL'),
#  'ASTP': ('Asian Studies',
#   'https://class-schedule.app.utah.edu/main/1254/class_list.html?subject=ASTP'),
#  'ASTR': ('Astronomy',
#   'https://class-schedule.app.utah.edu/main/1254/class_list.html?subject=ASTR'),
#  'ATHL': ('Athletics',
#   'https://class-schedule.app.utah.edu/main/1254/class_list.html?subject=ATHL'),
#  'ATMOS': ('Atmospheric Sciences',
#   'https://class-schedule.app.utah.edu/main/1254/class_list.html?subject=ATMOS'),
#  'ATSM': ('Athletic Training and Sports Medicine',
#   'https://class-schedule.app.utah.edu/main/1254/class_list.html?subject=ATSM'),
#  'BALLE': ('Ballet',
#   'https://class-schedule.app.utah.edu/main/1254/class_list.html?subject=BALLE'),
#  'BART': ('Book Arts',
#   'https://class-schedule.app.utah.edu/main/1254/class_list.html?subject=BART'),
#  'BENN': ('Bennion Center',
#   'https://class-schedule.app.utah.edu/main/1254/class_list.html?subject=BENN'),
#  'BIO C': ('Biochemistry',
#   'https://class-schedule.app.utah.edu/main/1254/class_list.html?subject=BIO%20C'),
#  'BIOL': ('Biology',
#   'https://class-schedule.app.utah.edu/main/1254/class_list.html?subject=BIOL'),
#  'BLCHM': ('Biological Chemistry',
#   'https://class-schedule.app.utah.edu/main/1254/class_list.html?subject=BLCHM'),
#  'BME': ('Biomedical Engineering',
#   'https://class-schedule.app.utah.edu/main/1254/class_list.html?subject=BME'),
#  'BMI': ('Biomedical Informatics',
#   'https://class-schedule.app.utah.edu/main/1254/class_list.html?subject=BMI'),
#  'BUS': ('Business',
#   'https://class-schedule.app.utah.edu/main/1254/class_list.html?subject=BUS'),
#  'CERM': ('Ceramics',
#   'https://class-schedule.app.utah.edu/main/1254/class_list.html?subject=CERM'),
#  'CH EN': ('Chemical Engineering',
#   'https://class-schedule.app.utah.edu/main/1254/class_list.html?subject=CH%20EN'),
#  'CHEM': ('Chemistry',
#   'https://class-schedule.app.utah.edu/main/1254/class_list.html?subject=CHEM'),
#  'CHIN': ('Chinese',
#   'https://class-schedule.app.utah.edu/main/1254/class_list.html?subject=CHIN'),
#  'CL CV': ('Classical Civilization',
#   'https://class-schedule.app.utah.edu/main/1254/class_list.html?subject=CL%20CV'),
#  'CLCS': ('Comparative Literary and Cultural Studies',
#   'https://class-schedule.app.utah.edu/main/1254/class_list.html?subject=CLCS'),
#  'CMP': ('City & Metropolitan Planning',
#   'https://class-schedule.app.utah.edu/main/1254/class_list.html?subject=CMP'),
#  'COMM': ('Communication',
#   'https://class-schedule.app.utah.edu/main/1254/class_list.html?subject=COMM'),
#  'COMP': ('Computing',
#   'https://class-schedule.app.utah.edu/main/1254/class_list.html?subject=COMP'),
#  'CRIM': ('Criminology',
#   'https://class-schedule.app.utah.edu/main/1254/class_list.html?subject=CRIM'),
#  'CS': ('Computer Science',
#   'https://class-schedule.app.utah.edu/main/1254/class_list.html?subject=CS'),
#  'CSD': ('Communication Sciences and Disorders',
#   'https://class-schedule.app.utah.edu/main/1254/class_list.html?subject=CSD'),
#  'CTLE': ('Center for Teaching Excellence',
#   'https://class-schedule.app.utah.edu/main/1254/class_list.html?subject=CTLE'),
#  'CVEEN': ('Civil and Environmental Engineering',
#   'https://class-schedule.app.utah.edu/main/1254/class_list.html?subject=CVEEN'),
#  'CVP': ('Cardiovascular Perfusion',
#   'https://class-schedule.app.utah.edu/main/1254/class_list.html?subject=CVP'),
#  'DANC': ('Modern Dance',
#   'https://class-schedule.app.utah.edu/main/1254/class_list.html?subject=DANC'),
#  'DENT': ('Dentistry',
#   'https://class-schedule.app.utah.edu/main/1254/class_list.html?subject=DENT'),
#  'DERM': ('Dermatology',
#   'https://class-schedule.app.utah.edu/main/1254/class_list.html?subject=DERM'),
#  'DES': ('Design',
#   'https://class-schedule.app.utah.edu/main/1254/class_list.html?subject=DES'),
#  'DESGR': ('Graphic Design',
#   'https://class-schedule.app.utah.edu/main/1254/class_list.html?subject=DESGR'),
#  'DISAB': ('Disability Studies',
#   'https://class-schedule.app.utah.edu/main/1254/class_list.html?subject=DISAB'),
#  'DRAW': ('Drawing',
#   'https://class-schedule.app.utah.edu/main/1254/class_list.html?subject=DRAW'),
#  'DS': ('Data Science',
#   'https://class-schedule.app.utah.edu/main/1254/class_list.html?subject=DS'),
#  'ECE': ('Electrical and Computer Engineering',
#   'https://class-schedule.app.utah.edu/main/1254/class_list.html?subject=ECE'),
#  'ECON': ('Economics',
#   'https://class-schedule.app.utah.edu/main/1254/class_list.html?subject=ECON'),
#  'ECS': ('Education, Culture and Society',
#   'https://class-schedule.app.utah.edu/main/1254/class_list.html?subject=ECS'),
#  'ED PS': ('Educational Psychology',
#   'https://class-schedule.app.utah.edu/main/1254/class_list.html?subject=ED%20PS'),
#  'EDTEC': ('Educational Technology',
#   'https://class-schedule.app.utah.edu/main/1254/class_list.html?subject=EDTEC'),
#  'EDU': ('Education',
#   'https://class-schedule.app.utah.edu/main/1254/class_list.html?subject=EDU'),
#  'EHUM': ('Environmental Humanities',
#   'https://class-schedule.app.utah.edu/main/1254/class_list.html?subject=EHUM'),
#  'ELI': ('English Language Institute',
#   'https://class-schedule.app.utah.edu/main/1254/class_list.html?subject=ELI'),
#  'ELP': ('Educational Leadership & Policy',
#   'https://class-schedule.app.utah.edu/main/1254/class_list.html?subject=ELP'),
#  'EMER': ('Emergency Medicine',
#   'https://class-schedule.app.utah.edu/main/1254/class_list.html?subject=EMER'),
#  'ENGIN': ('Engineering',
#   'https://class-schedule.app.utah.edu/main/1254/class_list.html?subject=ENGIN'),
#  'ENGL': ('English',
#   'https://class-schedule.app.utah.edu/main/1254/class_list.html?subject=ENGL'),
#  'ENTP': ('Entrepreneurship',
#   'https://class-schedule.app.utah.edu/main/1254/class_list.html?subject=ENTP'),
#  'ENV': ('Environment, Society, and Sustainability',
#   'https://class-schedule.app.utah.edu/main/1254/class_list.html?subject=ENV'),
#  'ENVST': ('Environmental and Sustainability Studies',
#   'https://class-schedule.app.utah.edu/main/1254/class_list.html?subject=ENVST'),
#  'ESSF': ('ESS Fitness Courses',
#   'https://class-schedule.app.utah.edu/main/1254/class_list.html?subject=ESSF'),
#  'ESSFC': ('ESS Fitness Noncredit Certificate',
#   'https://class-schedule.app.utah.edu/main/1254/class_list.html?subject=ESSFC'),
#  'ETHNC': ('Ethnic Studies',
#   'https://class-schedule.app.utah.edu/main/1254/class_list.html?subject=ETHNC'),
#  'FA': ('Fine Arts',
#   'https://class-schedule.app.utah.edu/main/1254/class_list.html?subject=FA'),
#  'FCS': ('Family and Consumer Studies',
#   'https://class-schedule.app.utah.edu/main/1254/class_list.html?subject=FCS'),
#  'FCSC': ('Family and Consumer Studies Noncredit Certificate',
#   'https://class-schedule.app.utah.edu/main/1254/class_list.html?subject=FCSC'),
#  'FILM': ('Film and Media Arts',
#   'https://class-schedule.app.utah.edu/main/1254/class_list.html?subject=FILM'),
#  'FINAN': ('Finance',
#   'https://class-schedule.app.utah.edu/main/1254/class_list.html?subject=FINAN'),
#  'FP MD': ('Family and Preventive Medicine',
#   'https://class-schedule.app.utah.edu/main/1254/class_list.html?subject=FP%20MD'),
#  'FRNCH': ('French',
#   'https://class-schedule.app.utah.edu/main/1254/class_list.html?subject=FRNCH'),
#  'GAMES': ('Games',
#   'https://class-schedule.app.utah.edu/main/1254/class_list.html?subject=GAMES'),
#  'GEO': ('Geology and Geophysics',
#   'https://class-schedule.app.utah.edu/main/1254/class_list.html?subject=GEO'),
#  'GEOG': ('Geography',
#   'https://class-schedule.app.utah.edu/main/1254/class_list.html?subject=GEOG'),
#  'GERM': ('German',
#   'https://class-schedule.app.utah.edu/main/1254/class_list.html?subject=GERM'),
#  'GERON': ('Gerontology',
#   'https://class-schedule.app.utah.edu/main/1254/class_list.html?subject=GERON'),
#  'GNDR': ('Gender Studies',
#   'https://class-schedule.app.utah.edu/main/1254/class_list.html?subject=GNDR'),
#  'GREEK': ('Greek',
#   'https://class-schedule.app.utah.edu/main/1254/class_list.html?subject=GREEK'),
#  'H EDU': ('Health Promotion & Education',
#   'https://class-schedule.app.utah.edu/main/1254/class_list.html?subject=H%20EDU'),
#  'H EDUC': ('Health Promotion & Education Noncredit Certificate',
#   'https://class-schedule.app.utah.edu/main/1254/class_list.html?subject=H%20EDUC'),
#  'H GEN': ('Human Genetics',
#   'https://class-schedule.app.utah.edu/main/1254/class_list.html?subject=H%20GEN'),
#  'HINDI': ('Hindi',
#   'https://class-schedule.app.utah.edu/main/1254/class_list.html?subject=HINDI'),
#  'HIST': ('History',
#   'https://class-schedule.app.utah.edu/main/1254/class_list.html?subject=HIST'),
#  'HKR': ('Health, Kinesiology, and Recreation',
#   'https://class-schedule.app.utah.edu/main/1254/class_list.html?subject=HKR'),
#  'HNKLY': ('Hinckley Institute',
#   'https://class-schedule.app.utah.edu/main/1254/class_list.html?subject=HNKLY'),
#  'HONOR': ('Honors College',
#   'https://class-schedule.app.utah.edu/main/1254/class_list.html?subject=HONOR'),
#  'HSP': ('Health, Society and Policy',
#   'https://class-schedule.app.utah.edu/main/1254/class_list.html?subject=HSP'),
#  'HUM': ('Humanities',
#   'https://class-schedule.app.utah.edu/main/1254/class_list.html?subject=HUM'),
#  'IAGE': ('International Affairs and Global Enterprise',
#   'https://class-schedule.app.utah.edu/main/1254/class_list.html?subject=IAGE'),
#  'INTL': ('International Studies',
#   'https://class-schedule.app.utah.edu/main/1254/class_list.html?subject=INTL'),
#  'INTMD': ('Internal Medicine',
#   'https://class-schedule.app.utah.edu/main/1254/class_list.html?subject=INTMD'),
#  'IS': ('Information Systems',
#   'https://class-schedule.app.utah.edu/main/1254/class_list.html?subject=IS'),
#  'ITAL': ('Italian',
#   'https://class-schedule.app.utah.edu/main/1254/class_list.html?subject=ITAL'),
#  'JAPAN': ('Japanese',
#   'https://class-schedule.app.utah.edu/main/1254/class_list.html?subject=JAPAN'),
#  'KINES': ('Kinesiology',
#   'https://class-schedule.app.utah.edu/main/1254/class_list.html?subject=KINES'),
#  'KOREA': ('Korean',
#   'https://class-schedule.app.utah.edu/main/1254/class_list.html?subject=KOREA'),
#  'LAS': ('Latin American Studies',
#   'https://class-schedule.app.utah.edu/main/1254/class_list.html?subject=LAS'),
#  'LATIN': ('Latin',
#   'https://class-schedule.app.utah.edu/main/1254/class_list.html?subject=LATIN'),
#  'LAW': ('Law',
#   'https://class-schedule.app.utah.edu/main/1254/class_list.html?subject=LAW'),
#  'LAWC': ('Law Noncredit Certificate',
#   'https://class-schedule.app.utah.edu/main/1254/class_list.html?subject=LAWC'),
#  'LEAP': ('LEAP Program',
#   'https://class-schedule.app.utah.edu/main/1254/class_list.html?subject=LEAP'),
#  'LING': ('Linguistics',
#   'https://class-schedule.app.utah.edu/main/1254/class_list.html?subject=LING'),
#  'LINGC': ('Linguistics Noncredit Certificate',
#   'https://class-schedule.app.utah.edu/main/1254/class_list.html?subject=LINGC'),
#  'LLART': ('Art and Photography',
#   'https://class-schedule.app.utah.edu/main/1254/class_list.html?subject=LLART'),
#  'LLCFT': ('Crafts',
#   'https://class-schedule.app.utah.edu/main/1254/class_list.html?subject=LLCFT'),
#  'LLFW': ('Food and Wine',
#   'https://class-schedule.app.utah.edu/main/1254/class_list.html?subject=LLFW'),
#  'LLHG': ('Home and Garden',
#   'https://class-schedule.app.utah.edu/main/1254/class_list.html?subject=LLHG'),
#  'LLHL': ('Healthy Living',
#   'https://class-schedule.app.utah.edu/main/1254/class_list.html?subject=LLHL'),
#  'LLLAN': ('Language',
#   'https://class-schedule.app.utah.edu/main/1254/class_list.html?subject=LLLAN'),
#  'LLMT': ('Music and Theatre',
#   'https://class-schedule.app.utah.edu/main/1254/class_list.html?subject=LLMT'),
#  'LLPOT': ('Potpourri',
#   'https://class-schedule.app.utah.edu/main/1254/class_list.html?subject=LLPOT'),
#  'LLREC': ('Recreation',
#   'https://class-schedule.app.utah.edu/main/1254/class_list.html?subject=LLREC'),
#  'LLWRC': ('Writing/Creative',
#   'https://class-schedule.app.utah.edu/main/1254/class_list.html?subject=LLWRC'),
#  'MATH': ('Mathematics',
#   'https://class-schedule.app.utah.edu/main/1254/class_list.html?subject=MATH'),
#  'MBA': ('Master Business Administration',
#   'https://class-schedule.app.utah.edu/main/1254/class_list.html?subject=MBA'),
#  'MBIOL': ('Molecular Biology',
#   'https://class-schedule.app.utah.edu/main/1254/class_list.html?subject=MBIOL'),
#  'MD CH': ('Pharmacy - Medicinal Chemistry',
#   'https://class-schedule.app.utah.edu/main/1254/class_list.html?subject=MD%20CH'),
#  'MD ID': ('Interdepartmental Medicine',
#   'https://class-schedule.app.utah.edu/main/1254/class_list.html?subject=MD%20ID'),
#  'MD LB': ('Medical Laboratory Science',
#   'https://class-schedule.app.utah.edu/main/1254/class_list.html?subject=MD%20LB'),
#  'MDCRC': ('Clinical Research Center',
#   'https://class-schedule.app.utah.edu/main/1254/class_list.html?subject=MDCRC'),
#  'ME EN': ('Mechanical Engineering',
#   'https://class-schedule.app.utah.edu/main/1254/class_list.html?subject=ME%20EN'),
#  'MET E': ('Metallurgical Engineering',
#   'https://class-schedule.app.utah.edu/main/1254/class_list.html?subject=MET%20E'),
#  'MG EN': ('Mining Engineering',
#   'https://class-schedule.app.utah.edu/main/1254/class_list.html?subject=MG%20EN'),
#  'MGT': ('Management',
#   'https://class-schedule.app.utah.edu/main/1254/class_list.html?subject=MGT'),
#  'MHA': ('Master Healthcare Administration',
#   'https://class-schedule.app.utah.edu/main/1254/class_list.html?subject=MHA'),
#  'MID E': ('Middle East Language and Area Studies',
#   'https://class-schedule.app.utah.edu/main/1254/class_list.html?subject=MID%20E'),
#  'MIL S': ('Military Science',
#   'https://class-schedule.app.utah.edu/main/1254/class_list.html?subject=MIL%20S'),
#  'MKTG': ('Marketing',
#   'https://class-schedule.app.utah.edu/main/1254/class_list.html?subject=MKTG'),
#  'MSE': ('Materials Science and Engineering',
#   'https://class-schedule.app.utah.edu/main/1254/class_list.html?subject=MSE'),
#  'MST': ('Master of Science and Technology',
#   'https://class-schedule.app.utah.edu/main/1254/class_list.html?subject=MST'),
#  'MUSC': ('Music',
#   'https://class-schedule.app.utah.edu/main/1254/class_list.html?subject=MUSC'),
#  'NAHTL': ('Nahuatl',
#   'https://class-schedule.app.utah.edu/main/1254/class_list.html?subject=NAHTL'),
#  'NAVJO': ('Navajo',
#   'https://class-schedule.app.utah.edu/main/1254/class_list.html?subject=NAVJO'),
#  'NEURO': ('Neurology',
#   'https://class-schedule.app.utah.edu/main/1254/class_list.html?subject=NEURO'),
#  'NEUSC': ('Neuroscience',
#   'https://class-schedule.app.utah.edu/main/1254/class_list.html?subject=NEUSC'),
#  'NSURG': ('Neurosurgery',
#   'https://class-schedule.app.utah.edu/main/1254/class_list.html?subject=NSURG'),
#  'NUCL': ('Nuclear Engineering',
#   'https://class-schedule.app.utah.edu/main/1254/class_list.html?subject=NUCL'),
#  'NUIP': ('Nutrition and Integrative Physiology',
#   'https://class-schedule.app.utah.edu/main/1254/class_list.html?subject=NUIP'),
#  'NURS': ('Nursing',
#   'https://class-schedule.app.utah.edu/main/1254/class_list.html?subject=NURS'),
#  'NV SC': ('Naval Science',
#   'https://class-schedule.app.utah.edu/main/1254/class_list.html?subject=NV%20SC'),
#  'OBST': ('Obstetrics',
#   'https://class-schedule.app.utah.edu/main/1254/class_list.html?subject=OBST'),
#  'OC TH': ('Occupational Therapy',
#   'https://class-schedule.app.utah.edu/main/1254/class_list.html?subject=OC%20TH'),
#  'OEHS': ('Occupational and Environmental Health',
#   'https://class-schedule.app.utah.edu/main/1254/class_list.html?subject=OEHS'),
#  'ONCSC': ('Oncological Sciences',
#   'https://class-schedule.app.utah.edu/main/1254/class_list.html?subject=ONCSC'),
#  'OPHTH': ('Ophthalmology',
#   'https://class-schedule.app.utah.edu/main/1254/class_list.html?subject=OPHTH'),
#  'ORTHO': ('Orthopedics',
#   'https://class-schedule.app.utah.edu/main/1254/class_list.html?subject=ORTHO'),
#  'OSC': ('Operations and Supply Chain',
#   'https://class-schedule.app.utah.edu/main/1254/class_list.html?subject=OSC'),
#  'PADMN': ('Public Administration',
#   'https://class-schedule.app.utah.edu/main/1254/class_list.html?subject=PADMN'),
#  'PAS': ('Physician Assistant Studies',
#   'https://class-schedule.app.utah.edu/main/1254/class_list.html?subject=PAS'),
#  'PATH': ('Pathology',
#   'https://class-schedule.app.utah.edu/main/1254/class_list.html?subject=PATH'),
#  'PBHLT': ('Public Health',
#   'https://class-schedule.app.utah.edu/main/1254/class_list.html?subject=PBHLT'),
#  'PCS': ('Peace and Conflict Studies',
#   'https://class-schedule.app.utah.edu/main/1254/class_list.html?subject=PCS'),
#  'PCTH': ('Pharmacotherapy',
#   'https://class-schedule.app.utah.edu/main/1254/class_list.html?subject=PCTH'),
#  'PED': ('Pediatrics',
#   'https://class-schedule.app.utah.edu/main/1254/class_list.html?subject=PED'),
#  'PERS': ('Persian',
#   'https://class-schedule.app.utah.edu/main/1254/class_list.html?subject=PERS'),
#  'PH MD': ('Phys Med & Rehabilitation',
#   'https://class-schedule.app.utah.edu/main/1254/class_list.html?subject=PH%20MD'),
#  'PH TH': ('Physical Therapy',
#   'https://class-schedule.app.utah.edu/main/1254/class_list.html?subject=PH%20TH'),
#  'PH TX': ('Pharmacology and Toxicology',
#   'https://class-schedule.app.utah.edu/main/1254/class_list.html?subject=PH%20TX'),
#  'PHARM': ('Pharmacy',
#   'https://class-schedule.app.utah.edu/main/1254/class_list.html?subject=PHARM'),
#  'PHCEU': ('Molecular Pharmaceutics',
#   'https://class-schedule.app.utah.edu/main/1254/class_list.html?subject=PHCEU'),
#  'PHIL': ('Philosophy',
#   'https://class-schedule.app.utah.edu/main/1254/class_list.html?subject=PHIL'),
#  'PHOTO': ('Digital Photography',
#   'https://class-schedule.app.utah.edu/main/1254/class_list.html?subject=PHOTO'),
#  'PHS': ('Population Health Sciences',
#   'https://class-schedule.app.utah.edu/main/1254/class_list.html?subject=PHS'),
#  'PHYS': ('Physics',
#   'https://class-schedule.app.utah.edu/main/1254/class_list.html?subject=PHYS'),
#  'POLS': ('Political Science',
#   'https://class-schedule.app.utah.edu/main/1254/class_list.html?subject=POLS'),
#  'PRINT': ('Printmaking',
#   'https://class-schedule.app.utah.edu/main/1254/class_list.html?subject=PRINT'),
#  'PROEA': ('Professional Education Academies',
#   'https://class-schedule.app.utah.edu/main/1254/class_list.html?subject=PROEA'),
#  'PROED': ('Professional Education',
#   'https://class-schedule.app.utah.edu/main/1254/class_list.html?subject=PROED'),
#  'PRT': ('Parks, Recreation and Tourism',
#   'https://class-schedule.app.utah.edu/main/1254/class_list.html?subject=PRT'),
#  'PRTL': ('PRT Outdoor Adventure - Land',
#   'https://class-schedule.app.utah.edu/main/1254/class_list.html?subject=PRTL'),
#  'PRTS': ('PRT Outdoor Adventure - Snow',
#   'https://class-schedule.app.utah.edu/main/1254/class_list.html?subject=PRTS'),
#  'PRTW': ('PRT Outdoor Adventure - Water',
#   'https://class-schedule.app.utah.edu/main/1254/class_list.html?subject=PRTW'),
#  'PSY': ('Psychology',
#   'https://class-schedule.app.utah.edu/main/1254/class_list.html?subject=PSY'),
#  'PSYCT': ('Psychiatry',
#   'https://class-schedule.app.utah.edu/main/1254/class_list.html?subject=PSYCT'),
#  'PTGSE': ('Portuguese',
#   'https://class-schedule.app.utah.edu/main/1254/class_list.html?subject=PTGSE'),
#  'PUBPL': ('Public Policy',
#   'https://class-schedule.app.utah.edu/main/1254/class_list.html?subject=PUBPL'),
#  'QAMO': ('Quantitative Analysis of Markets and Organizations',
#   'https://class-schedule.app.utah.edu/main/1254/class_list.html?subject=QAMO'),
#  'QUECH': ('Quechua',
#   'https://class-schedule.app.utah.edu/main/1254/class_list.html?subject=QUECH'),
#  'RDLGY': ('Radiology',
#   'https://class-schedule.app.utah.edu/main/1254/class_list.html?subject=RDLGY'),
#  'RDONC': ('Radiation Oncology',
#   'https://class-schedule.app.utah.edu/main/1254/class_list.html?subject=RDONC'),
#  'RECTH': ('Recreational Therapy',
#   'https://class-schedule.app.utah.edu/main/1254/class_list.html?subject=RECTH'),
#  'REDEV': ('Real Estate Development',
#   'https://class-schedule.app.utah.edu/main/1254/class_list.html?subject=REDEV'),
#  'RELS': ('Religious Studies',
#   'https://class-schedule.app.utah.edu/main/1254/class_list.html?subject=RELS'),
#  'RHSCI': ('Rehabilitation Sciences',
#   'https://class-schedule.app.utah.edu/main/1254/class_list.html?subject=RHSCI'),
#  'ROBOT': ('Robotics',
#   'https://class-schedule.app.utah.edu/main/1254/class_list.html?subject=ROBOT'),
#  'RUSS': ('Russian',
#   'https://class-schedule.app.utah.edu/main/1254/class_list.html?subject=RUSS'),
#  'SAMOA': ('Samoan',
#   'https://class-schedule.app.utah.edu/main/1254/class_list.html?subject=SAMOA'),
#  'SBS': ('Social and Behavioral Science',
#   'https://class-schedule.app.utah.edu/main/1254/class_list.html?subject=SBS'),
#  'SCI': ('Science',
#   'https://class-schedule.app.utah.edu/main/1254/class_list.html?subject=SCI'),
#  'SCLPT': ('Sculpture/Intermedia',
#   'https://class-schedule.app.utah.edu/main/1254/class_list.html?subject=SCLPT'),
#  'SIME': ('Systems, Industrial, and Management Engineering',
#   'https://class-schedule.app.utah.edu/main/1254/class_list.html?subject=SIME'),
#  'SOC': ('Sociology',
#   'https://class-schedule.app.utah.edu/main/1254/class_list.html?subject=SOC'),
#  'SP ED': ('Special Education',
#   'https://class-schedule.app.utah.edu/main/1254/class_list.html?subject=SP%20ED'),
#  'SPAN': ('Spanish',
#   'https://class-schedule.app.utah.edu/main/1254/class_list.html?subject=SPAN'),
#  'SR EL': ('Senior Electives',
#   'https://class-schedule.app.utah.edu/main/1254/class_list.html?subject=SR%20EL'),
#  'STAT': ('Statistics',
#   'https://class-schedule.app.utah.edu/main/1254/class_list.html?subject=STAT'),
#  'STRAT': ('Strategy',
#   'https://class-schedule.app.utah.edu/main/1254/class_list.html?subject=STRAT'),
#  'SURG': ('Surgery',
#   'https://class-schedule.app.utah.edu/main/1254/class_list.html?subject=SURG'),
#  'SW': ('Social Work',
#   'https://class-schedule.app.utah.edu/main/1254/class_list.html?subject=SW'),
#  'SWC': ('Social Work Noncredit Certificate',
#   'https://class-schedule.app.utah.edu/main/1254/class_list.html?subject=SWC'),
#  'THEA': ('Theatre',
#   'https://class-schedule.app.utah.edu/main/1254/class_list.html?subject=THEA'),
#  'TONGA': ('Tongan',
#   'https://class-schedule.app.utah.edu/main/1254/class_list.html?subject=TONGA'),
#  'UGS': ('Undergraduate Studies',
#   'https://class-schedule.app.utah.edu/main/1254/class_list.html?subject=UGS'),
#  'UUHED': ('MEd in Health Professions',
#   'https://class-schedule.app.utah.edu/main/1254/class_list.html?subject=UUHED'),
#  'UUHSC': ('Health Sciences Center',
#   'https://class-schedule.app.utah.edu/main/1254/class_list.html?subject=UUHSC'),
#  'VIET': ('Vietnamese',
#   'https://class-schedule.app.utah.edu/main/1254/class_list.html?subject=VIET'),
#  'WLC': ('World Languages and Cultures',
#   'https://class-schedule.app.utah.edu/main/1254/class_list.html?subject=WLC'),
#  'WRTG': ('Writing and Rhetoric Studies',
#   'https://class-schedule.app.utah.edu/main/1254/class_list.html?subject=WRTG'),
#  'YECU': ('Club U camps',
#   'https://class-schedule.app.utah.edu/main/1254/class_list.html?subject=YECU'),
#  'YEHS': ('High School',
#   'https://class-schedule.app.utah.edu/main/1254/class_list.html?subject=YEHS'),
#  'YESPR': ('Sports and Recreation',
#   'https://class-schedule.app.utah.edu/main/1254/class_list.html?subject=YESPR')}

# %% [markdown]
# Let's look at the entry for CS:

# %%
subjects["CS"]
# Out:
# ('Computer Science',
#  'https://class-schedule.app.utah.edu/main/1254/class_list.html?subject=CS')

# %% [markdown]
# That's what we want.
#
# As an aside: we could have taken a different approach here. Note how the URL has a deterministic query parameter that matches the subject:
#
# ```
# class_list.html?subject=MATH
# ```
#
# We could use this to also retrieve the links if we only had the subject shortnames.

# %% [markdown]
# #### Getting a list of classes
#
# Next, it's time to get the courses. Let's look at the [website for CS](https://class-schedule.app.utah.edu/main/1254/class_list.html?subject=CS).
#
# We'll fetch this class list in a function where we pass in the subject name:

# %%
def getWebsiteAsSoup(url):
    """ 
    Retrieve a website and return it as a BeautifulSoup object.   
    """
    
    req = urllib.request.Request(url)
    with urllib.request.urlopen(req) as response:
        classlist_html = response.read()
    
    print(classlist_html)
    
    class_soup = BeautifulSoup(classlist_html, 'html.parser')
    with open('class_list.html', 'w') as new_file:
        new_file.write(str(class_soup))
        
    return class_soup

# %% [markdown]
# Let's run this function for CS and look at the output:

# %%
class_soup = getWebsiteAsSoup(subjects["CS"][1])
# Out:
# b'<!DOCTYPE html>\n<html lang="en" xmlns="http://www.w3.org/1999/xhtml">\n<head>\n    \n    <title>Class Schedule</title>\n    <meta charset="utf-8"/>\n    <meta content="IE=edge" http-equiv="X-UA-Compatible"/>\n    <meta content="width=device-width, initial-scale=1" name="viewport"/>\n\n    <link href="https://fonts.googleapis.com/css?family=Open+Sans+Condensed:300,300i,700" rel="stylesheet"/>\n    <link href="https://fonts.googleapis.com/css?family=Open+Sans:300,300i,400,400i,600,600i,700,700i,800,800i" rel="stylesheet"/>\n    <link rel="stylesheet" href="/static/bootstrap/main.css"/>\n    <link rel="stylesheet" href="/static/bootstrap/addins.css"/>\n    <link rel="icon" href="/static/images/favicon.ico" type="image/png"/>\n    <link rel="stylesheet" href="https://cdn.jsdelivr.net/npm/bootstrap-icons@1.11.3/font/bootstrap-icons.min.css" integrity="sha256-9kPW/n5nn53j4WMRYAxe9c1rCY96Oogo/MKSVdKzPmI=" crossorigin="anonymous">\n    <link rel="stylesheet" href="https://cdn.jsdelivr.net/npm/jquery-ui@1.14.0/themes/base/all.css" integrity="sha256-DNKQmjU2FwFhSgFxlOahFCaiqQopMbZpuG9BKuO20zs=" crossorigin="anonymous">\n\n    <script nonce="zKzm1IH7GRKj8NxZDOZWndOBMMH7/0X3cU+Kgi1OHMU=" src="https://cdn.jsdelivr.net/npm/jquery@3.7.1/dist/jquery.min.js" integrity="sha256-/JqT3SQfawRcv/BIHPThkBvs0OEvtFFmqPF/lYI/Cxo=" crossorigin="anonymous"></script>\n    <script nonce="zKzm1IH7GRKj8NxZDOZWndOBMMH7/0X3cU+Kgi1OHMU=" src="https://cdn.jsdelivr.net/npm/jquery-ui@1.14.0/dist/jquery-ui.min.js" integrity="sha256-Fb0zP4jE3JHqu+IBB9YktLcSjI1Zc6J2b6gTjB0LpoM=" crossorigin="anonymous"></script>\n    <script nonce="zKzm1IH7GRKj8NxZDOZWndOBMMH7/0X3cU+Kgi1OHMU=" src="https://cdn.jsdelivr.net/npm/bootstrap@5.2.3/dist/js/bootstrap.bundle.min.js" integrity="sha384-kenU1KFdBIe4zVF0s0G1M5b4hcpxyD9F7jL+jjXkk+Q2h455rYXK/7HAuoJl+0I4" crossorigin="anonymous"></script>\n    <!-- Google tag (gtag.js) -->\n    <script nonce="zKzm1IH7GRKj8NxZDOZWndOBMMH7/0X3cU+Kgi1OHMU=" async src="https://www.googletagmanager.com/gtag/js?id=G-3JD7YQZW6Z"></script>\n    \n    \n    <script nonce="zKzm1IH7GRKj8NxZDOZWndOBMMH7/0X3cU+Kgi1OHMU=" src="/static/scripts/analytics/main.js"></script>\n    <script nonce="zKzm1IH7GRKj8NxZDOZWndOBMMH7/0X3cU+Kgi1OHMU=" src="/static/scripts/elevator.min.js"></script>\n    <script nonce="zKzm1IH7GRKj8NxZDOZWndOBMMH7/0X3cU+Kgi1OHMU=" src="/static/scripts/addins.js"></script>\n    \n    <meta charset="UTF-8"/>\n</head>\n\n<body class="d-flex flex-column bg-light">\n\n<!--*** START OF NAVIGATION ***-->\n<nav class="navbar navbar-expand-xxl bg-body-tertiary navbar-dark uu-nav d-print-none p-0">\n    <div class="container-fluid ms-0 ps-0">\n\n        <div class="align-self-center">\n            <a href="https://utah.edu" target="_blank">\n                <img class="uu-logo" src="/static/images/uofu.png" alt="The University of Utah"/>\n            </a>\n        </div>\n\n        <button aria-controls="navbarSupportedContent" aria-expanded="false" aria-label="Toggle navigation"\n                class="navbar-toggler" data-bs-target="#navbarSupportedContent" data-bs-toggle="collapse"\n                type="button">\n            <span class="navbar-toggler-icon m-1"></span>\n        </button>\n\n        <div class="collapse navbar-collapse" id="navbarSupportedContent">\n            <ul class="navbar-nav ms-auto text-nowrap">\n                <li class="nav-item"><a class="nav-link" href="index.html">Home</a></li>\n                <li class="nav-item dropdown">\n                    <a class="nav-link dropdown-toggle" href="#" id="navbarDropdown" role="button" data-bs-toggle="dropdown" aria-haspopup="true" aria-expanded="false">\n                        Terms\n                    </a>\n                    <ul class="dropdown-menu">\n                        <li>\n                            <a class="dropdown-item"\n                               href="/main/1254/index.html">Spring 2025</a>\n                        </li>\n                        <li>\n     ...

# %%
print(class_soup.prettify())
# Out:
# <!DOCTYPE html>
# <html lang="en" xmlns="http://www.w3.org/1999/xhtml">
#  <head>
#   <title>
#    Class Schedule
#   </title>
#   <meta charset="utf-8"/>
#   <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
#   <meta content="width=device-width, initial-scale=1" name="viewport"/>
#   <link href="https://fonts.googleapis.com/css?family=Open+Sans+Condensed:300,300i,700" rel="stylesheet"/>
#   <link href="https://fonts.googleapis.com/css?family=Open+Sans:300,300i,400,400i,600,600i,700,700i,800,800i" rel="stylesheet"/>
#   <link href="/static/bootstrap/main.css" rel="stylesheet"/>
#   <link href="/static/bootstrap/addins.css" rel="stylesheet"/>
#   <link href="/static/images/favicon.ico" rel="icon" type="image/png"/>
#   <link crossorigin="anonymous" href="https://cdn.jsdelivr.net/npm/bootstrap-icons@1.11.3/font/bootstrap-icons.min.css" integrity="sha256-9kPW/n5nn53j4WMRYAxe9c1rCY96Oogo/MKSVdKzPmI=" rel="stylesheet"/>
#   <link crossorigin="anonymous" href="https://cdn.jsdelivr.net/npm/jquery-ui@1.14.0/themes/base/all.css" integrity="sha256-DNKQmjU2FwFhSgFxlOahFCaiqQopMbZpuG9BKuO20zs=" rel="stylesheet"/>
#   <script crossorigin="anonymous" integrity="sha256-/JqT3SQfawRcv/BIHPThkBvs0OEvtFFmqPF/lYI/Cxo=" nonce="zKzm1IH7GRKj8NxZDOZWndOBMMH7/0X3cU+Kgi1OHMU=" src="https://cdn.jsdelivr.net/npm/jquery@3.7.1/dist/jquery.min.js">
#   </script>
#   <script crossorigin="anonymous" integrity="sha256-Fb0zP4jE3JHqu+IBB9YktLcSjI1Zc6J2b6gTjB0LpoM=" nonce="zKzm1IH7GRKj8NxZDOZWndOBMMH7/0X3cU+Kgi1OHMU=" src="https://cdn.jsdelivr.net/npm/jquery-ui@1.14.0/dist/jquery-ui.min.js">
#   </script>
#   <script crossorigin="anonymous" integrity="sha384-kenU1KFdBIe4zVF0s0G1M5b4hcpxyD9F7jL+jjXkk+Q2h455rYXK/7HAuoJl+0I4" nonce="zKzm1IH7GRKj8NxZDOZWndOBMMH7/0X3cU+Kgi1OHMU=" src="https://cdn.jsdelivr.net/npm/bootstrap@5.2.3/dist/js/bootstrap.bundle.min.js">
#   </script>
#   <!-- Google tag (gtag.js) -->
#   <script async="" nonce="zKzm1IH7GRKj8NxZDOZWndOBMMH7/0X3cU+Kgi1OHMU=" src="https://www.googletagmanager.com/gtag/js?id=G-3JD7YQZW6Z">
#   </script>
#   <script nonce="zKzm1IH7GRKj8NxZDOZWndOBMMH7/0X3cU+Kgi1OHMU=" src="/static/scripts/analytics/main.js">
#   </script>
#   <script nonce="zKzm1IH7GRKj8NxZDOZWndOBMMH7/0X3cU+Kgi1OHMU=" src="/static/scripts/elevator.min.js">
#   </script>
#   <script nonce="zKzm1IH7GRKj8NxZDOZWndOBMMH7/0X3cU+Kgi1OHMU=" src="/static/scripts/addins.js">
#   </script>
#   <meta charset="utf-8"/>
#  </head>
#  <body class="d-flex flex-column bg-light">
#   <!--*** START OF NAVIGATION ***-->
#   <nav class="navbar navbar-expand-xxl bg-body-tertiary navbar-dark uu-nav d-print-none p-0">
#    <div class="container-fluid ms-0 ps-0">
#     <div class="align-self-center">
#      <a href="https://utah.edu" target="_blank">
#       <img alt="The University of Utah" class="uu-logo" src="/static/images/uofu.png"/>
#      </a>
#     </div>
#     <button aria-controls="navbarSupportedContent" aria-expanded="false" aria-label="Toggle navigation" class="navbar-toggler" data-bs-target="#navbarSupportedContent" data-bs-toggle="collapse" type="button">
#      <span class="navbar-toggler-icon m-1">
#      </span>
#     </button>
#     <div class="collapse navbar-collapse" id="navbarSupportedContent">
#      <ul class="navbar-nav ms-auto text-nowrap">
#       <li class="nav-item">
#        <a class="nav-link" href="index.html">
#         Home
#        </a>
#       </li>
#       <li class="nav-item dropdown">
#        <a aria-expanded="false" aria-haspopup="true" class="nav-link dropdown-toggle" data-bs-toggle="dropdown" href="#" id="navbarDropdown" role="button">
#         Terms
#        </a>
#        <ul class="dropdown-menu">
#         <li>
#          <a class="dropdown-item" href="/main/1254/index.html">
#           Spring 2025
#          </a>
#         </li>
#         <li>
#          <a class="dropdown-item" href="/main/1248/index.html">
#           Fall 2024
#          </a>
#         </li>
#         <li>
#          <a class="dropdown-item" href="/main/1246/index.html">
#           Summer 2024
#          </a>
#         </li>
#        </ul>
#       </li>
#       <li class="nav-item">
#        <a class="nav-link" href="//registrar.utah.edu/register/schedule-builder.php" target="_blank">
#         Schedule Builder
#        </a>
#       </li>
#       <li class="nav-item">
#        <a class="nav-link" href="//registrar.utah.edu/handbook/" target="_blank">
#         Student Handbook
#        </a>
#       </li>
#       <li class="nav-item">
#        <a class="nav-link" href="//catalog.utah.edu/" target="_blank">
#         General Catalog
#        </a>
#       </li>
#       <li class="nav-item">
#        <a class="nav-link" href="//registrar.utah.edu/academic-calendars/spring2025.php" target="_blank">
#         Academic Calendar
#        </a>
#       </li>
#       <li class="nav-item">
#        <a class="nav-link" href="http://www.bookstore.utah.edu/UTAH/SelectTermDept.aspx" target="_blank">
#         Find Textbooks
#        </a>
#       </li>
#       <li class="nav-item">
#        <a class="nav-link" href="https://student-course-feedback.app.utah.edu" target="_blank">
#         View Course Feedback
#        </a>
#       </li>
#       <li class="nav-item">
#        <a class="nav-link" href="https://noncredit.utah.edu" target="_blank">
#         Add/Drop Non-credit Classes
#        </a>
#       </li>
#      </ul>
#     </div>
#    </div>
#   </nav>
#   <!--*** END OF NAVIGATION ***-->
#   <div class="container-fluid mb-auto mt-0 mx-0 p-0">
#    <div class="px-2 px-sm-4 px-md-5 mt-3">
#     <div class="row">
#      <div class="col-lg-10">
#       <section>
#        <h1>
#         <b>
#          <span>
#           Computer Science
#          </span>
#          -
#          <span>
#           Main Campus
#          </span>
#         </b>
#         <span>
#          - Spring 2025 Class Schedule
#         </span>
#        </h1>
#        <h2>
#        </h2>
#       </section>
#      </div>
#      <div class="col-lg-2">
#       <div class="subject-info">
#        <section>
#         <ul class="list-group mt-3">
#          <li class="list-group-item">
#           Location: MEB 3190
#          </li>
#          <li class="list-group-item">
#           Phone: 801-581-8224
#          </li>
#         </ul>
#        </section>
#       </div>
#      </div>
#     </div>
#    </div>
#    <!--*** CONTENT *** -->
#    <section class="container-fluid px-2 px-sm-4 px-md-5 flex-grow-1">
#     <div class="row">
#      <div class="col-12 col-sm-12 col-md-6 col-lg-4 col-xl-3">
#       <div class="d-grid gap-2 mt-3">
#        <button class="btn btn-sm btn-outline-dark btn-block" id="filter-show-hide">
#         <i class="fas fa-angle-up">
#         </i>
#         <span>
#          Hide Search &amp; Filters
#         </span>
#        </button>
#       </div>
#      </div>
#     </div>
#     <div class="row">
#      <div class="collapse show col-12 col-sm-12 col-md-6 col-lg-4 col-xl-3" id="filter-controls">
#       <div class="row">
#        <div class="col">
#         <div class="card mt-3 bg-search">
#          <div class="card-body">
#           <form action="search.html" method="post">
#            <div class="form-group">
#             <h2>
#              <label for="search">
#               Search for a Class
#              </label>
#             </h2>
#             <input class="form-control" id="search" name="searchString" placeholder="Search Code and/or Catalog Number" required="" type="text" value=""/>
#            </div>
#            <div class="d-grid gap-2 mt-3">
#             <button class="btn btn-block btn-primary" type="submit">
#              Search
#             </button>
#            </div>
#           </form>
#          </div>
#         </div>
#        </div>
#       </div>
#       <div class="row">
#        <div class="col">
#         <div class="card mt-3">
#          <div class="card-body">
#           <div class="pb-2">
#            <div class="row justify-content-between flex-nowrap">
#             <div class="col-8">
#              <h2>
#               Filter Classes
#              </h2>
#             </div>
#             <div class="col">
#              <button class="float-end float-top btn btn-sm btn-outline-dark" id="filter-reset">
#               Clear
#              </button>
#             </div>
#            </div>
#           </div>
#           <!-- Filter by Subject -->
#           <!-- This part is substantially duplicated in Filter by Classes -->
#           <!-- Filter by Classes -->
#           <div class="accordion accordion-flush" id="accordionClassFilter">
#            <div class="accordion-item">
#             <h2 class="accordion-header" id="heading9">
#              <button aria-controls="collapse9" aria-expanded="true" class="accordion-button collapsed" data-bs-target="#collapse9" data-bs-toggle="collapse" type="button">
#               Day
#              </button>
#             </h2>
#             <div aria-labelledby="heading9" class="accordion-collapse collapse" id="collapse9">
#              <div class="accordion-body">
#               <fieldset>
#                <legend>
#                 Select days:
#                </legend>
#                <label class="btn btn-light btn-sm m-1">
#                 <span>
#                  Mo
#                 </span>
#                 <input autocomplete="off" class="form-check-input" data-search-query="Mo" data-search-type="day" type="checkbox" value="">
#                 </input>
#                </label>
#                <label class="btn btn-light btn-sm m-1">
#                 <span>
#                  Tu
#                 </span>
#                 <input autocomplete="off" class="form-check-input" data-search-query="Tu" data-search-type="day" type="checkbox" value=""/>
#                </label>
#                <label class="btn btn-light btn-sm m-1">
#                 <span>
#                  We
#                 </span>
#                 <input autocomplete="off" class="form-check-input" data-search-query="We" data-search-type="day" type="checkbox" value=""/>
#                </label>
#                <label class="btn btn-light btn-sm m-1">
#                 <span>
#                  Th
#                 </span>
#                 <input autocomplete="off" class="form-check-input" data-search-query="Th" data-search-type="day" type="checkbox" value=""/>
#                </label>
#                <label class="btn btn-light btn-sm m-1">
#                 <span>
#                  Fr
#                 </span>
#                 <input autocomplete="off" class="form-check-input" data-search-query="Fr" data-search-type="day" type="checkbox" value=""/>
#                </label>
#                <label class="btn btn-light btn-sm m-1">
#                 <span>
#                  Sa
#                 </span>
#                 <input autocomplete="off" class="form-check-input" data-search-query="Sa" data-search-type="day" type="checkbox" value=""/>
#                </label>
#                <label class="btn btn-light btn-sm m-1">
#                 <span>
#                  Su
#                 </span>
#                 <input autocomplete="off" class="form-check-input" data-search-query="Su" data-search-type="day" type="checkbox" value=""/>
#                </label>
#               </fieldset>
#              </div>
#             </div>
#            </div>
#            <div class="accordion-item">
#             <h2 class="accordion-header" id="heading10">
#              <button aria-controls="collapse10" aria-expanded="true" class="accordion-button collapsed" data-bs-target="#collapse10" data-bs-toggle="collapse" type="button">
#               Time
#              </button>
#             </h2>
#             <div aria-labelledby="heading10" class="accordion-collapse collapse" id="collapse10">
#              <div class="accordion-body" id="filter-times">
#               <label class="btn btn-light btn-sm">
#                Morning
#                <input autocomplete="off" class="form-check-input" data-search-query="M" data-search-type="time" type="checkbox" value=""/>
#               </label>
#               <label class="btn btn-light btn-sm">
#                Afternoon
#                <input autocomplete="off" class="form-check-input" data-search-query="A" data-search-type="time" type="checkbox" value=""/>
#               </label>
#               <label class="btn btn-light btn-sm">
#                Evening
#                <input autocomplete="off" class="form-check-input" data-search-query="E" data-search-type="time" type="checkbox" value=""/>
#               </label>
#              </div>
#             </div>
#            </div>
#            <div class="accordion-item">
#             <h2 class="accordion-header" id="heading11">
#              <button aria-controls="collapse11" aria-expanded="true" class="accordion-button collapsed" data-bs-target="#collapse11" data-bs-toggle="collapse" type="button">
#               Off Campus
#              </button>
#             </h2>
#             <div aria-labelledby="heading11" class="accordion-collapse collapse" id="collapse11">
#              <div class="accordion-body" id="filter-off-campus">
#               <label class="btn btn-light btn-sm m-1">
#                Sandy
#                <input autocomplete="off" class="form-check-input" data-search-query="SANDY" data-search-type="building-code" type="checkbox" value=""/>
#               </label>
#               <label class="btn btn-light btn-sm m-1">
#                St. George
#                <input autocomplete="off" class="form-check-input" data-search-query="ST. GEORGE" data-search-type="building-code" type="checkbox" value=""/>
#               </label>
#               <label class="btn btn-light btn-sm m-1">
#                Herriman
#                <input autocomplete="off" class="form-check-input" data-search-query="JNPR" data-search-type="building-code" type="checkbox" value=""/>
#               </label>
#              </div>
#             </div>
#            </div>
#            <div class="accordion-item">
#             <h2 class="accordion-header" id="heading12">
#              <button aria-controls="collapse12" aria-expanded="true" class="accordion-button collapsed" data-bs-target="#collapse12" data-bs-toggle="collapse" type="button">
#               Gen Ed &amp; Bachelor Degree Courses
#              </button>
#             </h2>
#             <div aria-labelledby="heading12" class="accordion-collapse collapse" id="collapse12">
#              <div class="accordion-body" id="filter-attributes">
#               <label class="btn btn-light btn-sm m-1">
#                <span>
#                 AI
#                </span>
#                <input autocomplete="off" class="form-check-input" data-search-query="AI" data-search-type="req" type="checkbox" value="AI"/>
#               </label>
#               <label class="btn btn-light btn-sm m-1">
#                <span>
#                 BF
#                </span>
#                <input autocomplete="off" class="form-check-input" data-search-query="BF" data-search-type="req" type="checkbox" value="BF"/>
#               </label>
#               <label class="btn btn-light btn-sm m-1">
#                <span>
#                 CW
#                </span>
#                <input autocomplete="off" class="form-check-input" data-search-query="CW" data-search-type="req" type="checkbox" value="CW"/>
#               </label>
#               <label class="btn btn-light btn-sm m-1">
#                <span>
#                 DI
#                </span>
#                <input autocomplete="off" class="form-check-input" data-search-query="DI" data-search-type="req" type="checkbox" value="DI"/>
#               </label>
#               <label class="btn btn-light btn-sm m-1">
#                <span>
#                 DV
#                </span>
#                <input autocomplete="off" class="form-check-input" data-search-query="DV" data-search-type="req" type="checkbox" value="DV"/>
#               </label>
#               <label class="btn btn-light btn-sm m-1">
#                <span>
#                 FF
#                </span>
#                <input autocomplete="off" class="form-check-input" data-search-query="FF" data-search-type="req" type="checkbox" value="FF"/>
#               </label>
#               <label class="btn btn-light btn-sm m-1">
#                <span>
#                 HF
#                </span>
#                <input autocomplete="off" class="form-check-input" data-search-query="HF" data-search-type="req" type="checkbox" value="HF"/>
#               </label>
#               <label class="btn btn-light btn-sm m-1">
#                <span>
#                 IR
#                </span>
#                <input autocomplete="off" class="form-check-input" data-search-query="IR" data-search-type="req" type="checkbox" value="IR"/>
#               </label>
#               <label class="btn btn-light btn-sm m-1">
#                <span>
#                 LR
#                </span>
#                <input autocomplete="off" class="form-check-input" data-search-query="LR" data-search-type="req" type="checkbox" value="LR"/>
#               </label>
#               <label class="btn btn-light btn-sm m-1">
#                <span>
#                 LS
#                </span>
#                <input autocomplete="off" class="form-check-input" data-search-query="LS" data-search-type="req" type="checkbox" value="LS"/>
#               </label>
#               <label class="btn btn-light btn-sm m-1">
#                <span>
#                 PS
#                </span>
#                <input autocomplete="off" class="form-check-input" data-search-query="PS" data-search-type="req" type="checkbox" value="PS"/>
#               </label>
#               <label class="btn btn-light btn-sm m-1">
#                <span>
#                 QI
#                </span>
#                <input autocomplete="off" class="form-check-input" data-search-query="QI" data-search-type="req" type="checkbox" value="QI"/>
#               </label>
#               <label class="btn btn-light btn-sm m-1">
#                <span>
#                 QL
#                </span>
#                <input autocomplete="off" class="form-check-input" data-search-query="QL" data-search-type="req" type="checkbox" value="QL"/>
#               </label>
#               <label class="btn btn-light btn-sm m-1">
#                <span>
#                 WR1
#                </span>
#                <input autocomplete="off" class="form-check-input" data-search-query="WR1" data-search-type="req" type="checkbox" value="WR1"/>
#               </label>
#               <label class="btn btn-light btn-sm m-1">
#                <span>
#                 WR2
#                </span>
#                <input autocomplete="off" class="form-check-input" data-search-query="WR2" data-search-type="req" type="checkbox" value="WR2"/>
#               </label>
#              </div>
#             </div>
#            </div>
#            <div class="accordion-item">
#             <h2 class="accordion-header" id="heading13">
#              <button aria-controls="collapse13" aria-expanded="true" class="accordion-button collapsed" data-bs-target="#collapse13" data-bs-toggle="collapse" type="button">
#               Multiple Gen Ed and/or Bachelor degree requirement codes
#              </button>
#             </h2>
#             <div aria-labelledby="heading13" class="accordion-collapse collapse" id="collapse13">
#              <div class="accordion-body" id="filter-multi">
#               <label class="btn btn-light btn-sm m-1">
#                <span>
#                 BFHF
#                </span>
#                <input autocomplete="off" class="form-check-input" data-search-query="BFHF" data-search-type="req" type="checkbox" value="BFHF"/>
#               </label>
#               <label class="btn btn-light btn-sm m-1">
#                <span>
#                 CWDI
#                </span>
#                <input autocomplete="off" class="form-check-input" data-search-query="CWDI" data-search-type="req" type="checkbox" value="CWDI"/>
#               </label>
#               <label class="btn btn-light btn-sm m-1">
#                <span>
#                 CWDV
#                </span>
#                <input autocomplete="off" class="form-check-input" data-search-query="CWDV" data-search-type="req" type="checkbox" value="CWDV"/>
#               </label>
#               <label class="btn btn-light btn-sm m-1">
#                <span>
#                 CWHF
#                </span>
#                <input autocomplete="off" class="form-check-input" data-search-query="CWHF" data-search-type="req" type="checkbox" value="CWHF"/>
#               </label>
#               <label class="btn btn-light btn-sm m-1">
#                <span>
#                 CWIR
#                </span>
#                <input autocomplete="off" class="form-check-input" data-search-query="CWIR" data-search-type="req" type="checkbox" value="CWIR"/>
#               </label>
#               <label class="btn btn-light btn-sm m-1">
#                <span>
#                 DVBF
#                </span>
#                <input autocomplete="off" class="form-check-input" data-search-query="DVBF" data-search-type="req" type="checkbox" value="DVBF"/>
#               </label>
#               <label class="btn btn-light btn-sm m-1">
#                <span>
#                 DVFF
#                </span>
#                <input autocomplete="off" class="form-check-input" data-search-query="DVFF" data-search-type="req" type="checkbox" value="DVFF"/>
#               </label>
#               <label class="btn btn-light btn-sm m-1">
#                <span>
#                 DVHF
#                </span>
#                <input autocomplete="off" class="form-check-input" data-search-query="DVHF" data-search-type="req" type="checkbox" value="DVHF"/>
#               </label>
#               <label class="btn btn-light btn-sm m-1">
#                <span>
#                 DVLS
#                </span>
#                <input autocomplete="off" class="form-check-input" data-search-query="DVLS" data-search-type="req" type="checkbox" value="DVLS"/>
#               </label>
#               <label class="btn btn-light btn-sm m-1">
#                <span>
#                 FFHF
#                </span>
#                <input autocomplete="off" class="form-check-input" data-search-query="FFHF" data-search-type="req" type="checkbox" value="FFHF"/>
#               </label>
#               <label class="btn btn-light btn-sm m-1">
#                <span>
#                 IRBF
#                </span>
#                <input autocomplete="off" class="form-check-input" data-search-query="IRBF" data-search-type="req" type="checkbox" value="IRBF"/>
#               </label>
#               <label class="btn btn-light btn-sm m-1">
#                <span>
#                 IRFF
#                </span>
#                <input autocomplete="off" class="form-check-input" data-search-query="IRFF" data-search-type="req" type="checkbox" value="IRFF"/>
#               </label>
#               <label class="btn btn-light btn-sm m-1">
#                <span>
#                 IRHF
#                </span>
#                <input autocomplete="off" class="form-check-input" data-search-query="IRHF" data-search-type="req" type="checkbox" value="IRHF"/>
#               </label>
#               <label class="btn btn-light btn-sm m-1">
#                <span>
#                 IRLR
#                </span>
#                <input autocomplete="off" class="form-check-input" data-search-query="IRLR" data-search-type="req" type="checkbox" value="IRLR"/>
#               </label>
#               <label class="btn btn-light btn-sm m-1">
#                <span>
#                 IRPS
#                </span>
#                <input autocomplete="off" class="form-check-input" data-search-query="IRPS" data-search-type="req" type="checkbox" value="IRPS"/>
#               </label>
#               <label class="btn btn-light btn-sm m-1">
#                <span>
#                 LSPS
#                </span>
#                <input autocomplete="off" class="form-check-input" data-search-query="LSPS" data-search-type="req" type="checkbox" value="LSPS"/>
#               </label>
#               <label class="btn btn-light btn-sm m-1">
#                <span>
#                 QICW
#                </span>
#                <input autocomplete="off" class="form-check-input" data-search-query="QICW" data-search-type="req" type="checkbox" value="QICW"/>
#               </label>
#               <label class="btn btn-light btn-sm m-1">
#                <span>
#                 QIIR
#                </span>
#                <input autocomplete="off" class="form-check-input" data-search-query="QIIR" data-search-type="req" type="checkbox" value="QIIR"/>
#               </label>
#              </div>
#             </div>
#            </div>
#            <div class="accordion-item">
#             <h2 class="accordion-header" id="heading14">
#              <button aria-controls="collapse14" aria-expanded="true" class="accordion-button collapsed" data-bs-target="#collapse14" data-bs-toggle="collapse" type="button">
#               Continuing Education
#              </button>
#             </h2>
#             <div aria-labelledby="heading14" class="accordion-collapse collapse" id="collapse14">
#              <div class="accordion-body" id="filter-continuing-ed">
#               <label class="btn btn-light btn-sm">
#                AOCE
#                <input autocomplete="off" class="form-check-input" data-search-query="AOCE" data-search-type="attr" type="checkbox" value="AOCE"/>
#               </label>
#              </div>
#             </div>
#            </div>
#            <div class="accordion-item">
#             <h2 class="accordion-header" id="heading15">
#              <button aria-controls="collapse15" aria-expanded="true" class="accordion-button collapsed" data-bs-target="#collapse15" data-bs-toggle="collapse" type="button">
#               Flexible Classes
#              </button>
#             </h2>
#             <div aria-labelledby="heading15" class="accordion-collapse collapse" id="collapse15">
#              <div class="accordion-body" id="filter-flex">
#               <label class="btn btn-light btn-sm">
#                FLXU
#                <input autocomplete="off" class="form-check-input" data-search-query="FLXU" data-search-type="attr" type="checkbox" value="FLXU"/>
#               </label>
#              </div>
#             </div>
#            </div>
#            <div class="accordion-item">
#             <h2 class="accordion-header" id="heading16">
#              <button aria-controls="collapse16" aria-expanded="true" class="accordion-button collapsed" data-bs-target="#collapse16" data-bs-toggle="collapse" type="button">
#               Other Course Attributes
#              </button>
#             </h2>
#             <div aria-labelledby="heading16" class="accordion-collapse collapse" id="collapse16">
#              <div class="accordion-body" id="filter-other-codes">
#               <label class="btn btn-light btn-sm m-1">
#                <span>
#                 AOCE
#                </span>
#                <input autocomplete="off" class="form-check-input" data-search-query="AOCE" data-search-type="attr" type="checkbox" value="AOCE"/>
#               </label>
#               <label class="btn btn-light btn-sm m-1">
#                <span>
#                 CEL
#                </span>
#                <input autocomplete="off" class="form-check-input" data-search-query="CEL" data-search-type="attr" type="checkbox" value="CEL"/>
#               </label>
#               <label class="btn btn-light btn-sm m-1">
#                <span>
#                 CLAC
#                </span>
#                <input autocomplete="off" class="form-check-input" data-search-query="CLAC" data-search-type="attr" type="checkbox" value="CLAC"/>
#               </label>
#               <label class="btn btn-light btn-sm m-1">
#                <span>
#                 FLXU
#                </span>
#                <input autocomplete="off" class="form-check-input" data-search-query="FLXU" data-search-type="attr" type="checkbox" value="FLXU"/>
#               </label>
#               <label class="btn btn-light btn-sm m-1">
#                <span>
#                 HON
#                </span>
#                <input autocomplete="off" class="form-check-input" data-search-query="HON" data-search-type="attr" type="checkbox" value="HON"/>
#               </label>
#               <label class="btn btn-light btn-sm m-1">
#                <span>
#                 LEAP
#                </span>
#                <input autocomplete="off" class="form-check-input" data-search-query="LEAP" data-search-type="attr" type="checkbox" value="LEAP"/>
#               </label>
#               <label class="btn btn-light btn-sm m-1">
#                <span>
#                 OMBA
#                </span>
#                <input autocomplete="off" class="form-check-input" data-search-query="OMBA" data-search-type="attr" type="checkbox" value="OMBA"/>
#               </label>
#               <label class="btn btn-light btn-sm m-1">
#                <span>
#                 PMBA
#                </span>
#                <input autocomplete="off" class="form-check-input" data-search-query="PMBA" data-search-type="attr" type="checkbox" value="PMBA"/>
#               </label>
#               <label class="btn btn-light btn-sm m-1">
#                <span>
#                 SUST
#                </span>
#                <input autocomplete="off" class="form-check-input" data-search-query="SUST" data-search-type="attr" type="checkbox" value="SUST"/>
#               </label>
#              </div>
#             </div>
#            </div>
#            <div class="accordion-item">
#             <h2 class="accordion-header" id="heading17">
#              <button aria-controls="collapse17" aria-expanded="true" class="accordion-button collapsed" data-bs-target="#collapse17" data-bs-toggle="collapse" type="button">
#               Type
#              </button>
#             </h2>
#             <div aria-labelledby="heading17" class="accordion-collapse collapse" id="collapse17">
#              <div class="accordion-body" id="filter-type">
#               <label class="btn btn-light btn-sm m-1">
#                <span>
#                 Hybrid
#                </span>
#                <input autocomplete="off" class="form-check-input" data-search-query="H" data-search-type="type" type="checkbox" value=""/>
#               </label>
#               <label class="btn btn-light btn-sm m-1">
#                <span>
#                 In Person
#                </span>
#                <input autocomplete="off" class="form-check-input" data-search-query="P" data-search-type="type" type="checkbox" value=""/>
#               </label>
#               <label class="btn btn-light btn-sm m-1">
#                <span>
#                 Online
#                </span>
#                <input autocomplete="off" class="form-check-input" data-search-query="O" data-search-type="type" type="checkbox" value=""/>
#               </label>
#               <label class="btn btn-light btn-sm m-1">
#                <span>
#                 Remote Real-Time
#                </span>
#                <input autocomplete="off" class="form-check-input" data-search-query="R" data-search-type="type" type="checkbox" value=""/>
#               </label>
#              </div>
#             </div>
#            </div>
#            <div class="accordion-item">
#             <h2 class="accordion-header" id="heading18">
#              <button aria-controls="collapse18" aria-expanded="true" class="accordion-button collapsed" data-bs-target="#collapse18" data-bs-toggle="collapse" type="button">
#               Units
#              </button>
#             </h2>
#             <div aria-labelledby="heading18" class="accordion-collapse collapse" id="collapse18">
#              <div class="accordion-body" id="filter-units">
#               <div id="slider">
#                <div class="ui-slider-handle" id="custom-handle">
#                </div>
#               </div>
#               <input aria-label="Units" autocomplete="off" data-search-type="units" id="unit-slider" type="checkbox" value=""/>
#              </div>
#             </div>
#            </div>
#            <div class="accordion-item">
#             <h2 class="accordion-header" id="heading19">
#              <button aria-controls="collapse19" aria-expanded="true" class="accordion-button collapsed" data-bs-target="#collapse19" data-bs-toggle="collapse" type="button">
#               Seats Available
#              </button>
#             </h2>
#             <div aria-labelledby="heading19" class="accordion-collapse collapse" id="collapse19">
#              <div class="accordion-body" id="filter-seats">
#               <label class="btn btn-light btn-sm">
#                Seats Available
#                <input autocomplete="off" class="form-check-input" data-search-query="true" data-search-type="seats" type="checkbox" value=""/>
#               </label>
#              </div>
#             </div>
#            </div>
#           </div>
#          </div>
#         </div>
#        </div>
#       </div>
#      </div>
#      <div class="col">
#       <!-- ************* MAIN CONTENT AREA ****************** -->
#       <main id="uu-skip-target" role="main">
#        <div>
#         <div class="row">
#          <div class="col-xl-7">
#           <div class="card mt-3">
#            <div class="card-header" scope="col">
#             Departmental Advisors
#            </div>
#            <div class="card-body">
#             <div class="row mt-2">
#              <div class="col text-left">
#               Undergraduate Studies Office
#              </div>
#              <div class="col text-left">
#               Vicki Jackson
#              </div>
#              <div class="col-xl-6 text-left">
#               MEB 3190
#              </div>
#             </div>
#             <div class="row mt-2">
#              <div class="col text-left">
#               Graduate Studies Office
#              </div>
#              <div class="col text-left">
#               Jill Wilson
#              </div>
#              <div class="col-xl-6 text-left">
#               MEB 3190
#              </div>
#             </div>
#            </div>
#           </div>
#           <div class="card">
#            <div class="card-body">
#             <a class="btn btn-primary" href="https://student-course-feedback.app.utah.edu" target="_blank">
#              View Course Feedback
#             </a>
#            </div>
#           </div>
#          </div>
#          <div class="col">
#           <div class="card mt-3">
#            <div class="card-header">
#             Departmental Notes
#            </div>
#            <div class="card-body">
#             <p>
#              <span>
#               For course descriptions and pre-requisite information click on the subject column next to the appropriate catalog number.
#              </span>
#             </p>
#             <p>
#              <span>
#               THIS DEPARTMENT ENFORCES UNDERGRADUATE PREREQUISITES. Please note that the registration system may not factor in transfer work when determining if prerequisites have been met.   If you are unable to register for a course and think you have met the prerequisite(s), please contact an advisor from this department to inquire about obtaining a permission code.  You may be administratively dropped from a course if the prerequisite has not been met.
#              </span>
#             </p>
#            </div>
#           </div>
#          </div>
#         </div>
#        </div>
#        <div class="alert alert-secondary mt-3" role="alert">
#         <span class="allcaps">
#          Attention:
#         </span>
#         Classroom assignments may change between the time you
#                     register and when classes begin. Please check your class schedule for the latest classroom location
#                     information before attending class.
#        </div>
#        <!-- Class Details Table -->
#        <div id="class-details">
#         <div class="class-info card mt-3" id="11408">
#          <div class="card-body row d-none d-md-block">
#           <div class="col-12 p-0">
#            <div class="buttons">
#             <a class="btn btn-secondary btn-sm" href="description.html?subj=CS&amp;catno=1400&amp;section=001">
#              Class Details
#             </a>
#            </div>
#            <h3>
#             <a href="sections.html?subj=CS&amp;catno=1400">
#              CS 1400
#             </a>
#             -
#             <span>
#              001
#             </span>
#             <span>
#              Intro Comp Programming
#             </span>
#            </h3>
#           </div>
#           <div class="col-12 p-0">
#            <ul class="row breadcrumb-list list-unstyled">
#             <li class="col-sm-auto">
#              Class Number:
#              <a id="11408">
#              </a>
#             </li>
#             <li class="col-sm-auto">
#              Instructor:
#              <span>
#               <a href="https://profiles.faculty.utah.edu/u1364435" target="_blank">
#                BROWN, NOELLE
#               </a>
#              </span>
#             </li>
#             <li class="col-sm-auto">
#              Component:
#              <span>
#               Lecture
#              </span>
#             </li>
#             <li class="col-sm-auto">
#              Type:
#              <span data-type="P">
#               In Person
#              </span>
#             </li>
#             <li class="col-sm-auto" data-units="U4_0">
#              Units:
#              <span>
#               4.0
#              </span>
#             </li>
#             <li class="col-sm-auto">
#              Requisites: Yes
#             </li>
#             <li class="col-sm-auto">
#              Wait List:
#              <span>
#               No
#              </span>
#             </li>
#             <li class="col-sm-auto d-none" data-seats="true">
#              Seats Available:
#              <span>
#               180
#              </span>
#             </li>
#             <li class="col-sm-auto">
#              <a href="https://student-course-feedback.app.utah.edu/reports/CS/1400/Lecture" target="_blank">
#               View Feedback
#              </a>
#             </li>
#            </ul>
#            <hr/>
#            <span>
#             This course requires registration for a lab and/or discussion section. Students will be automatically registered for this lecture section when registering for the pertinent lab and/or discussion section. Students may take CS 1400 or CS 1420 as a their first CS course. For a guide on choosing a course, see
#             <a href="https://handbook.cs.utah.edu/2021-2022/Prospective_Students/choosing_between_1030_1400_1420.php" target="_blank">
#              https://handbook.cs.utah.edu/2021-2022/Prospective_Students/choosing_between_1030_1400_1420.php
#             </a>
#             .
#            </span>
#           </div>
#          </div>
#          <div class="card-body row d-block d-md-none">
#           <div class="col-12 p-0">
#            <h3>
#             <a href="sections.html?subj=CS&amp;catno=1400">
#              CS 1400
#             </a>
#             -
#             <span>
#              001
#             </span>
#             <span>
#              Intro Comp Programming
#             </span>
#            </h3>
#           </div>
#           <div class="col-12 p-0">
#            <ul class="row list-unstyled">
#             <li class="col-sm-auto">
#              Class Number:
#              <a name="11408">
#              </a>
#             </li>
#             <li class="col-sm-auto">
#              Instructor:
#              <span>
#               <a href="http://faculty.utah.edu/u1364435/teaching/index.hml" target="_blank">
#                BROWN, NOELLE
#               </a>
#              </span>
#             </li>
#             <li class="col-sm-auto">
#              Component:
#              <span>
#               Lecture
#              </span>
#             </li>
#             <li class="col-sm-auto">
#              Type:
#              <span data-type="P">
#               In Person
#              </span>
#             </li>
#             <li class="col-sm-auto" data-units="U4_0">
#              Units:
#              <span>
#               4.0
#              </span>
#             </li>
#             <li class="col-sm-auto">
#              Requisites: Yes
#             </li>
#             <li class="col-sm-auto">
#              Wait List:
#              <span>
#               No
#              </span>
#             </li>
#             <li class="col-sm-auto" data-seats="true">
#              Seats Available:
#              <span>
#               180
#              </span>
#             </li>
#            </ul>
#            <div class="buttons">
#             <a class="btn btn-secondary btn-sm" href="description.html?subj=CS&amp;catno=1400&amp;section=001">
#              Class Details
#             </a>
#            </div>
#            <hr class="class-notes-divider"/>
#            <span>
#             This course requires registration for a lab and/or discussion section. Students will be automatically registered for this lecture section when registering for the pertinent lab and/or discussion section. Students may take CS 1400 or CS 1420 as a their first CS course. For a guide on choosing a course, see
#             <a href="https://handbook.cs.utah.edu/2021-2022/Prospective_Students/choosing_between_1030_1400_1420.php" target="_blank">
#              https://handbook.cs.utah.edu/2021-2022/Prospective_Students/choosing_between_1030_1400_1420.php
#             </a>
#             .
#            </span>
#           </div>
#          </div>
#          <div class="card-footer mp-1">
#           <div class="row mb-2">
#            <div class="col">
#             <table class="table time-table">
#              <thead class="class-cards table minimal-headers">
#               <tr>
#                <th class="text-nowrap text-left text-muted h6 p-0" scope="col">
#                 Days / Times
#                </th>
#                <th class="text-nowrap text-right text-muted h6 p-0" scope="col">
#                 Locations
#                </th>
#               </tr>
#              </thead>
#              <tbody>
#               <tr>
#                <th class="text-nowrap text-left p-0" scope="row">
#                 <span data-day="MoWe">
#                  MoWe
#                 </span>
#                 /
#                 <span data-time="A">
#                  01:25PM-02:45PM
#                 </span>
#                </th>
#                <th class="text-nowrap text-right p-0" data-building-code="S BEH AUD" scope="row">
#                 <a href="http://map.utah.edu/index.html?code=S BEH AUD" target="_blank">
#                  S BEH AUD .
#                 </a>
#                </th>
#               </tr>
#              </tbody>
#             </table>
#            </div>
#           </div>
#          </div>
#         </div>
#         <div class="class-info card mt-3" id="11410">
#          <div class="card-body row d-none d-md-block">
#           <div class="col-12 p-0">
#            <div class="buttons">
#             <a class="btn btn-secondary btn-sm" href="description.html?subj=CS&amp;catno=1400&amp;section=003">
#              Class Details
#             </a>
#            </div>
#            <h3>
#             <a href="sections.html?subj=CS&amp;catno=1400">
#              CS 1400
#             </a>
#             -
#             <span>
#              003
#             </span>
#             <span>
#              Intro Comp Programming
#             </span>
#            </h3>
#           </div>
#           <div class="col-12 p-0">
#            <ul class="row breadcrumb-list list-unstyled">
#             <li class="col-sm-auto">
#              Class Number:
#              <a id="11410">
#              </a>
#              <span>
#               11410
#              </span>
#             </li>
#             <li class="col-sm-auto">
#              Instructor:
#              <span>
#               <a href="https://profiles.faculty.utah.edu/u1364435" target="_blank">
#                BROWN, NOELLE
#               </a>
#              </span>
#             </li>
#             <li class="col-sm-auto">
#              Component:
#              <span>
#               Laboratory
#              </span>
#             </li>
#             <li class="col-sm-auto">
#              Type:
#              <span data-type="P">
#               In Person
#              </span>
#             </li>
#             <li class="col-sm-auto" data-units="U-U-U">
#              Units:
#              <span>
#               --
#              </span>
#             </li>
#             <li class="col-sm-auto">
#              Requisites: Yes
#             </li>
#             <li class="col-sm-auto">
#              Wait List:
#              <span>
#               No
#              </span>
#             </li>
#             <li class="col-sm-auto d-none" data-seats="true">
#              Seats Available:
#              <span>
#               25
#              </span>
#             </li>
#             <li class="col-sm-auto">
#              <a href="https://student-course-feedback.app.utah.edu/reports/CS/1400/Laboratory" target="_blank">
#               View Feedback
#              </a>
#             </li>
#            </ul>
#           </div>
#          </div>
#          <div class="card-body row d-block d-md-none">
#           <div class="col-12 p-0">
#            <h3>
#             <a href="sections.html?subj=CS&amp;catno=1400">
#              CS 1400
#             </a>
#             -
#             <span>
#              003
#             </span>
#             <span>
#              Intro Comp Programming
#             </span>
#            </h3>
#           </div>
#           <div class="col-12 p-0">
#            <ul class="row list-unstyled">
#             <li class="col-sm-auto">
#              Class Number:
#              <a name="11410">
#              </a>
#              <span>
#               11410
#              </span>
#             </li>
#             <li class="col-sm-auto">
#              Instructor:
#              <span>
#               <a href="http://faculty.utah.edu/u1364435/teaching/index.hml" target="_blank">
#                BROWN, NOELLE
#               </a>
#              </span>
#             </li>
#             <li class="col-sm-auto">
#              Component:
#              <span>
#               Laboratory
#              </span>
#             </li>
#             <li class="col-sm-auto">
#              Type:
#              <span data-type="P">
#               In Person
#              </span>
#             </li>
#             <li class="col-sm-auto" data-units="U-U-U">
#              Units:
#              <span>
#               --
#              </span>
#             </li>
#             <li class="col-sm-auto">
#              Requisites: Yes
#             </li>
#             <li class="col-sm-auto">
#              Wait List:
#              <span>
#               No
#              </span>
#             </li>
#             <li class="col-sm-auto" data-seats="true">
#              Seats Available:
#              <span>
#               25
#              </span>
#             </li>
#            </ul>
#            <div class="buttons">
#             <a class="btn btn-secondary btn-sm" href="description.html?subj=CS&amp;catno=1400&amp;section=003">
#              Class Details
#             </a>
#            </div>
#           </div>
#          </div>
#          <div class="card-footer mp-1">
#           <div class="row mb-2">
#            <div class="col">
#             <table class="table time-table">
#              <thead class="class-cards table minimal-headers">
#               <tr>
#                <th class="text-nowrap text-left text-muted h6 p-0" scope="col">
#                 Days / Times
#                </th>
#                <th class="text-nowrap text-right text-muted h6 p-0" scope="col">
#                 Locations
#                </th>
#               </tr>
#              </thead>
#              <tbody>
#               <tr>
#                <th class="text-nowrap text-left p-0" scope="row">
#                 <span data-day="Tu">
#                  Tu
#                 </span>
#                 /
#                 <span data-time="M">
#                  09:40AM-10:30AM
#                 </span>
#                </th>
#                <th class="text-nowrap text-right p-0" data-building-code="MEB" scope="row">
#                 <a href="http://map.utah.edu/index.html?code=MEB" target="_blank">
#                  MEB 3225
#                 </a>
#                </th>
#               </tr>
#              </tbody>
#             </table>
#            </div>
#           </div>
#          </div>
#         </div>
#         <div class="class-info card mt-3" id="11411">
#          <div class="card-body row d-none d-md-block">
#           <div class="col-12 p-0">
#            <div class="buttons">
#             <a class="btn btn-secondary btn-sm" href="description.html?subj=CS&amp;catno=1400&amp;section=004">
#              Class Details
#             </a>
#            </div>
#            <h3>
#             <a href="sections.html?subj=CS&amp;catno=1400">
#              CS 1400
#             </a>
#             -
#             <span>
#              004
#             </span>
#             <span>
#              Intro Comp Programming
#             </span>
#            </h3>
#           </div>
#           <div class="col-12 p-0">
# ...
#             <li class="col-sm-auto">
#              Component:
#              <span>
#               Seminar
#              </span>
#             </li>
#             <li class="col-sm-auto">
#              Type:
#              <span data-type="P">
#               In Person
#              </span>
#             </li>
#             <li class="col-sm-auto" data-units="U1_0">
#              Units:
#              <span>
#               1.0
#              </span>
#             </li>
#             <li class="col-sm-auto">
#              Requisites: Yes
#             </li>
#             <li class="col-sm-auto">
#              Wait List:
#              <span>
#               No
#              </span>
#             </li>
#             <li class="col-sm-auto" data-seats="true">
#              Seats Available:
#              <span>
#               8
#              </span>
#             </li>
#            </ul>
#            <div class="buttons">
#             <a class="btn btn-secondary btn-sm" href="description.html?subj=CS&amp;catno=7939&amp;section=001">
#              Class Details
#             </a>
#            </div>
#           </div>
#          </div>
#          <div class="card-footer mp-1">
#           <div class="row mb-2">
#            <div class="col">
#             <table class="table time-table">
#              <thead class="class-cards table minimal-headers">
#               <tr>
#                <th class="text-nowrap text-left text-muted h6 p-0" scope="col">
#                 Days / Times
#                </th>
#                <th class="text-nowrap text-right text-muted h6 p-0" scope="col">
#                 Locations
#                </th>
#               </tr>
#              </thead>
#              <tbody>
#               <tr>
#                <th class="text-nowrap text-left p-0" scope="row">
#                 <span data-day="Th">
#                  Th
#                 </span>
#                 /
#                 <span data-time="A">
#                  02:00PM-02:50PM
#                 </span>
#                </th>
#                <th class="text-nowrap text-right p-0" data-building-code="WEB" scope="row">
#                 <a href="http://map.utah.edu/index.html?code=WEB" target="_blank">
#                  WEB 2230
#                 </a>
#                </th>
#               </tr>
#              </tbody>
#             </table>
#            </div>
#           </div>
#           <div class="row">
#            <div class="col">
#             <em>
#              Meets With
#             </em>
#             <ul class="mb-0">
#              <li>
#               ECE 6868 001
#              </li>
#              <li>
#               ME EN 6892 001
#              </li>
#              <li>
#               ROBOT 5800 001
#              </li>
#              <li>
#               ROBOT 6800 001
#              </li>
#             </ul>
#            </div>
#           </div>
#          </div>
#         </div>
#         <div class="class-info card mt-3" id="6441">
#          <div class="card-body row d-none d-md-block">
#           <div class="col-12 p-0">
#            <div class="buttons">
#             <a class="btn btn-secondary btn-sm" href="description.html?subj=CS&amp;catno=7941&amp;section=001">
#              Class Details
#             </a>
#            </div>
#            <h3>
#             <a href="sections.html?subj=CS&amp;catno=7941">
#              CS 7941
#             </a>
#             -
#             <span>
#              001
#             </span>
#             <span>
#              Data Science Seminar
#             </span>
#            </h3>
#           </div>
#           <div class="col-12 p-0">
#            <ul class="row breadcrumb-list list-unstyled">
#             <li class="col-sm-auto">
#              Class Number:
#              <a id="6441">
#              </a>
#              <span>
#               6441
#              </span>
#             </li>
#             <li class="col-sm-auto">
#              Instructor:
#              <span>
#               <a href="https://profiles.faculty.utah.edu/u6001941" target="_blank">
#                BHASKARA, ADITYA
#               </a>
#              </span>
#             </li>
#             <li class="col-sm-auto">
#              Component:
#              <span>
#               Seminar
#              </span>
#             </li>
#             <li class="col-sm-auto">
#              Type:
#              <span data-type="P">
#               In Person
#              </span>
#             </li>
#             <li class="col-sm-auto" data-units="U1_0">
#              Units:
#              <span>
#               1.0
#              </span>
#             </li>
#             <li class="col-sm-auto">
#              Requisites: Yes
#             </li>
#             <li class="col-sm-auto">
#              Wait List:
#              <span>
#               No
#              </span>
#             </li>
#             <li class="col-sm-auto d-none" data-seats="true">
#              Seats Available:
#              <span>
#               40
#              </span>
#             </li>
#             <li class="col-sm-auto">
#              <a href="https://student-course-feedback.app.utah.edu/reports/CS/7941/Seminar" target="_blank">
#               View Feedback
#              </a>
#             </li>
#            </ul>
#           </div>
#          </div>
#          <div class="card-body row d-block d-md-none">
#           <div class="col-12 p-0">
#            <h3>
#             <a href="sections.html?subj=CS&amp;catno=7941">
#              CS 7941
#             </a>
#             -
#             <span>
#              001
#             </span>
#             <span>
#              Data Science Seminar
#             </span>
#            </h3>
#           </div>
#           <div class="col-12 p-0">
#            <ul class="row list-unstyled">
#             <li class="col-sm-auto">
#              Class Number:
#              <a name="6441">
#              </a>
#              <span>
#               6441
#              </span>
#             </li>
#             <li class="col-sm-auto">
#              Instructor:
#              <span>
#               <a href="http://faculty.utah.edu/u6001941/teaching/index.hml" target="_blank">
#                BHASKARA, ADITYA
#               </a>
#              </span>
#             </li>
#             <li class="col-sm-auto">
#              Component:
#              <span>
#               Seminar
#              </span>
#             </li>
#             <li class="col-sm-auto">
#              Type:
#              <span data-type="P">
#               In Person
#              </span>
#             </li>
#             <li class="col-sm-auto" data-units="U1_0">
#              Units:
#              <span>
#               1.0
#              </span>
#             </li>
#             <li class="col-sm-auto">
#              Requisites: Yes
#             </li>
#             <li class="col-sm-auto">
#              Wait List:
#              <span>
#               No
#              </span>
#             </li>
#             <li class="col-sm-auto" data-seats="true">
#              Seats Available:
#              <span>
#               40
#              </span>
#             </li>
#            </ul>
#            <div class="buttons">
#             <a class="btn btn-secondary btn-sm" href="description.html?subj=CS&amp;catno=7941&amp;section=001">
#              Class Details
#             </a>
#            </div>
#           </div>
#          </div>
#          <div class="card-footer mp-1">
#           <div class="row mb-2">
#            <div class="col">
#             <table class="table time-table">
#              <thead class="class-cards table minimal-headers">
#               <tr>
#                <th class="text-nowrap text-left text-muted h6 p-0" scope="col">
#                 Days / Times
#                </th>
#                <th class="text-nowrap text-right text-muted h6 p-0" scope="col">
#                 Locations
#                </th>
#               </tr>
#              </thead>
#              <tbody>
#               <tr>
#                <th class="text-nowrap text-left p-0" scope="row">
#                 <span data-day="Fr">
#                  Fr
#                 </span>
#                 /
#                 <span data-time="A">
#                  01:25PM-02:45PM
#                 </span>
#                </th>
#                <th class="text-nowrap text-right p-0" data-building-code="WEB" scope="row">
#                 <a href="http://map.utah.edu/index.html?code=WEB" target="_blank">
#                  WEB L112
#                 </a>
#                </th>
#               </tr>
#              </tbody>
#             </table>
#            </div>
#           </div>
#           <div class="row">
#            <div class="col">
#             <em>
#              Meets With
#             </em>
#             <ul class="mb-0">
#              <li>
#               DS 3941 001
#              </li>
#             </ul>
#            </div>
#           </div>
#          </div>
#         </div>
#         <div class="class-info card mt-3" id="6476">
#          <div class="card-body row d-none d-md-block">
#           <div class="col-12 p-0">
#            <div class="buttons">
#             <a class="btn btn-secondary btn-sm" href="description.html?subj=CS&amp;catno=7942&amp;section=001">
#              Class Details
#             </a>
#            </div>
#            <h3>
#             <a href="sections.html?subj=CS&amp;catno=7942">
#              CS 7942
#             </a>
#             -
#             <span>
#              001
#             </span>
#             <span>
#              Visualization Seminar
#             </span>
#            </h3>
#           </div>
#           <div class="col-12 p-0">
#            <ul class="row breadcrumb-list list-unstyled">
#             <li class="col-sm-auto">
#              Class Number:
#              <a id="6476">
#              </a>
#              <span>
#               6476
#              </span>
#             </li>
#             <li class="col-sm-auto">
#              Instructor:
#              <span>
#               <a href="https://profiles.faculty.utah.edu/u0731785" target="_blank">
#                PHILLIPS, BEI WANG
#               </a>
#              </span>
#             </li>
#             <li class="col-sm-auto">
#              Component:
#              <span>
#               Seminar
#              </span>
#             </li>
#             <li class="col-sm-auto">
#              Type:
#              <span data-type="P">
#               In Person
#              </span>
#             </li>
#             <li class="col-sm-auto" data-units="U1_0">
#              Units:
#              <span>
#               1.0
#              </span>
#             </li>
#             <li class="col-sm-auto">
#              Requisites: Yes
#             </li>
#             <li class="col-sm-auto">
#              Wait List:
#              <span>
#               No
#              </span>
#             </li>
#             <li class="col-sm-auto d-none" data-seats="true">
#              Seats Available:
#              <span>
#               30
#              </span>
#             </li>
#             <li class="col-sm-auto">
#              <a href="https://student-course-feedback.app.utah.edu/reports/CS/7942/Seminar" target="_blank">
#               View Feedback
#              </a>
#             </li>
#            </ul>
#            <hr>
#             <span>
#              This class meets in WEB 3780.
#             </span>
#            </hr>
#           </div>
#          </div>
#          <div class="card-body row d-block d-md-none">
#           <div class="col-12 p-0">
#            <h3>
#             <a href="sections.html?subj=CS&amp;catno=7942">
#              CS 7942
#             </a>
#             -
#             <span>
#              001
#             </span>
#             <span>
#              Visualization Seminar
#             </span>
#            </h3>
#           </div>
#           <div class="col-12 p-0">
#            <ul class="row list-unstyled">
#             <li class="col-sm-auto">
#              Class Number:
#              <a name="6476">
#              </a>
#              <span>
#               6476
#              </span>
#             </li>
#             <li class="col-sm-auto">
#              Instructor:
#              <span>
#               <a href="http://faculty.utah.edu/u0731785/teaching/index.hml" target="_blank">
#                PHILLIPS, BEI WANG
#               </a>
#              </span>
#             </li>
#             <li class="col-sm-auto">
#              Component:
#              <span>
#               Seminar
#              </span>
#             </li>
#             <li class="col-sm-auto">
#              Type:
#              <span data-type="P">
#               In Person
#              </span>
#             </li>
#             <li class="col-sm-auto" data-units="U1_0">
#              Units:
#              <span>
#               1.0
#              </span>
#             </li>
#             <li class="col-sm-auto">
#              Requisites: Yes
#             </li>
#             <li class="col-sm-auto">
#              Wait List:
#              <span>
#               No
#              </span>
#             </li>
#             <li class="col-sm-auto" data-seats="true">
#              Seats Available:
#              <span>
#               30
#              </span>
#             </li>
#            </ul>
#            <div class="buttons">
#             <a class="btn btn-secondary btn-sm" href="description.html?subj=CS&amp;catno=7942&amp;section=001">
#              Class Details
#             </a>
#            </div>
#            <hr class="class-notes-divider"/>
#            <span>
#             This class meets in WEB 3780.
#            </span>
#           </div>
#          </div>
#          <div class="card-footer mp-1">
#           <div class="row mb-2">
#            <div class="col">
#             <table class="table time-table">
#              <thead class="class-cards table minimal-headers">
#               <tr>
#                <th class="text-nowrap text-left text-muted h6 p-0" scope="col">
#                 Days / Times
#                </th>
#                <th class="text-nowrap text-right text-muted h6 p-0" scope="col">
#                 Locations
#                </th>
#               </tr>
#              </thead>
#              <tbody>
#               <tr>
#                <th class="text-nowrap text-left p-0" scope="row">
#                 <span data-day="We">
#                  We
#                 </span>
#                 /
#                 <span data-time="A">
#                  12:00PM-01:00PM
#                 </span>
#                </th>
#                <th class="text-nowrap text-right p-0" data-building-code="TBA" scope="row">
#                 <span>
#                  TBA .
#                 </span>
#                </th>
#               </tr>
#              </tbody>
#             </table>
#            </div>
#           </div>
#          </div>
#         </div>
#        </div>
#        <div class="row mt-3">
#         <div class="col text-center">
#          <a href="seating_availability.html?subject=CS">
#           Seating availability for all CS classes
#          </a>
#         </div>
#        </div>
#       </main>
#       <!-- ************** END MAIN CONTENT AREA ************** -->
#      </div>
#     </div>
#    </section>
#    <!--*** END OF CONTENT ***-->
#    <a aria-label="Back to top" href="#back-to-top" id="back-to-top" title="Back to top">
#     <i class="bi bi-arrow-bar-up fs-4 fw-bold">
#     </i>
#    </a>
#   </div>
#   <!--*** START OF FOOTER ***-->
#   <footer class="mt-5 pb-5 d-flex flex-column">
#    <div class="container-fluid px-4 px-sm-5 py-4">
#     <div class="row">
#      <div class="col-sm-6 col-md-4 small text-light">
#       <p>
#        University Support Services
#        <br/>
#        102 S 200 E, Ste. 100
#        <br/>
#        Salt Lake City, UT 84111
#       </p>
#       <p>
#        <a class="text-light" href="http://www.utah.edu">
#         © The University of Utah
#        </a>
#       </p>
#      </div>
#      <div class="col-sm-6 col-md-4 small">
#       <p>
#        <a class="text-light" href="http://www.utah.edu/nondiscrimination/">
#         Nondiscrimination &amp; Accessibility
#        </a>
#        <br/>
#        <a class="text-light" href="http://www.utah.edu/disclaimer/">
#         Disclaimer
#        </a>
#        <br/>
#        <a class="text-light" href="http://www.utah.edu/privacy/">
#         Privacy
#        </a>
#        <br/>
#       </p>
#      </div>
#      <div class="col-sm-12 col-md-4">
#       <a href="https://imagineu.utah.edu/" target="_blank">
#        <img alt="The University of Utah - Imagine U" class="footer-logo" src="/static/images/imagine_u.svg"/>
#       </a>
#      </div>
#     </div>
#    </div>
#   </footer>
#   <!--*** END OF FOOTER ***-->
#  </body>
# </html>

# %% [markdown]
# Now, let's analyze this html in the inspector.

# %% [markdown]
# ![Class Site Inspected](class.png)
#
# The data is stored in nested divs that are children of the div with ID `class-details`. Let's extract that subset:

# %%
# now we check out an example to see what a good characteristic is
courses = class_soup.find(id="class-details")
print(courses)
# Out:
# <div id="class-details">
# <div class="class-info card mt-3" id="11408">
# <div class="card-body row d-none d-md-block">
# <div class="col-12 p-0">
# <div class="buttons">
# <a class="btn btn-secondary btn-sm" href="description.html?subj=CS&amp;catno=1400&amp;section=001">Class Details</a>
# </div>
# <h3>
# <a href="sections.html?subj=CS&amp;catno=1400">CS 1400</a>
#                         -
#                         <span>001</span>
# <span>Intro Comp Programming</span>
# </h3>
# </div>
# <div class="col-12 p-0">
# <ul class="row breadcrumb-list list-unstyled">
# <li class="col-sm-auto">Class Number:
#                             <a id="11408"></a>
# </li>
# <li class="col-sm-auto">Instructor:
#                             <span>
# <a href="https://profiles.faculty.utah.edu/u1364435" target="_blank">BROWN, NOELLE</a>
# </span>
# </li>
# <li class="col-sm-auto">Component:
#                             <span>Lecture</span>
# </li>
# <li class="col-sm-auto">Type:
#                             <span data-type="P">In Person</span>
# </li>
# <li class="col-sm-auto" data-units="U4_0">
#                             Units: <span>  4.0</span>
# </li>
# <li class="col-sm-auto">Requisites: Yes</li>
# <li class="col-sm-auto">Wait List:
#
#                             <span>No</span>
# </li>
# <li class="col-sm-auto d-none" data-seats="true">
#                             Seats Available: <span>180</span>
# </li>
# <li class="col-sm-auto">
# <a href="https://student-course-feedback.app.utah.edu/reports/CS/1400/Lecture" target="_blank">View Feedback</a>
# </li>
# </ul>
# <hr/>
# <span>This course requires registration for a lab and/or discussion section. Students will be automatically registered for this lecture section when registering for the pertinent lab and/or discussion section. Students may take CS 1400 or CS 1420 as a their first CS course. For a guide on choosing a course, see <a href="https://handbook.cs.utah.edu/2021-2022/Prospective_Students/choosing_between_1030_1400_1420.php" target="_blank">https://handbook.cs.utah.edu/2021-2022/Prospective_Students/choosing_between_1030_1400_1420.php</a>.  </span>
# </div>
# </div>
# <div class="card-body row d-block d-md-none">
# <div class="col-12 p-0">
# <h3>
# <a href="sections.html?subj=CS&amp;catno=1400">CS 1400</a>
#                             -
#                             <span>001</span>
# <span>Intro Comp Programming</span>
# </h3>
# </div>
# <div class="col-12 p-0">
# <ul class="row list-unstyled">
# <li class="col-sm-auto">Class Number:
#                                 <a name="11408"></a>
# </li>
# <li class="col-sm-auto">Instructor:
#                                 <span>
# <a href="http://faculty.utah.edu/u1364435/teaching/index.hml" target="_blank">BROWN, NOELLE</a>
# </span>
# </li>
# <li class="col-sm-auto">Component:
#                                 <span>Lecture</span>
# </li>
# <li class="col-sm-auto">Type:
#                                 <span data-type="P">In Person</span>
# </li>
# <li class="col-sm-auto" data-units="U4_0">
#                                 Units: <span>  4.0</span></li>
# <li class="col-sm-auto">Requisites: Yes</li>
# <li class="col-sm-auto">Wait List:
#
#                                 <span>No</span>
# </li>
# <li class="col-sm-auto" data-seats="true">
#                                 Seats Available: <span>180</span>
# </li>
# </ul>
# <div class="buttons">
# <a class="btn btn-secondary btn-sm" href="description.html?subj=CS&amp;catno=1400&amp;section=001">Class Details</a>
# </div>
# <hr class="class-notes-divider"/>
# <span>This course requires registration for a lab and/or discussion section. Students will be automatically registered for this lecture section when registering for the pertinent lab and/or discussion section. Students may take CS 1400 or CS 1420 as a their first CS course. For a guide on choosing a course, see <a href="https://handbook.cs.utah.edu/2021-2022/Prospective_Students/choosing_between_1030_1400_1420.php" target="_blank">https://handbook.cs.utah.edu/2021-2022/Prospective_Students/choosing_between_1030_1400_1420.php</a>.  </span>
# </div>
# </div>
# <div class="card-footer mp-1">
# <div class="row mb-2">
# <div class="col">
# <table class="table time-table">
# <thead class="class-cards table minimal-headers">
# <tr>
# <th class="text-nowrap text-left text-muted h6 p-0" scope="col">Days / Times</th>
# <th class="text-nowrap text-right text-muted h6 p-0" scope="col">Locations</th>
# </tr>
# </thead>
# <tbody>
# <tr>
# <th class="text-nowrap text-left p-0" scope="row">
# <span data-day="MoWe">MoWe</span>/<span data-time="A">01:25PM-02:45PM</span>
# </th>
# <th class="text-nowrap text-right p-0" data-building-code="S BEH AUD" scope="row">
# <a href="http://map.utah.edu/index.html?code=S BEH AUD" target="_blank">S BEH AUD .</a>
# </th>
# </tr>
# </tbody>
# </table>
# </div>
# </div>
# </div>
# </div>
# <div class="class-info card mt-3" id="11410">
# <div class="card-body row d-none d-md-block">
# <div class="col-12 p-0">
# <div class="buttons">
# <a class="btn btn-secondary btn-sm" href="description.html?subj=CS&amp;catno=1400&amp;section=003">Class Details</a>
# </div>
# <h3>
# <a href="sections.html?subj=CS&amp;catno=1400">CS 1400</a>
#                         -
#                         <span>003</span>
# <span>Intro Comp Programming</span>
# </h3>
# </div>
# <div class="col-12 p-0">
# <ul class="row breadcrumb-list list-unstyled">
# <li class="col-sm-auto">Class Number:
#                             <a id="11410"></a>
# <span>11410</span>
# </li>
# <li class="col-sm-auto">Instructor:
#                             <span>
# <a href="https://profiles.faculty.utah.edu/u1364435" target="_blank">BROWN, NOELLE</a>
# </span>
# </li>
# <li class="col-sm-auto">Component:
#                             <span>Laboratory</span>
# </li>
# <li class="col-sm-auto">Type:
#                             <span data-type="P">In Person</span>
# </li>
# <li class="col-sm-auto" data-units="U-U-U">
#                             Units: <span>--</span>
# </li>
# <li class="col-sm-auto">Requisites: Yes</li>
# <li class="col-sm-auto">Wait List:
#
#                             <span>No</span>
# </li>
# <li class="col-sm-auto d-none" data-seats="true">
#                             Seats Available: <span>25</span>
# </li>
# <li class="col-sm-auto">
# <a href="https://student-course-feedback.app.utah.edu/reports/CS/1400/Laboratory" target="_blank">View Feedback</a>
# </li>
# </ul>
# </div>
# </div>
# <div class="card-body row d-block d-md-none">
# <div class="col-12 p-0">
# <h3>
# <a href="sections.html?subj=CS&amp;catno=1400">CS 1400</a>
#                             -
#                             <span>003</span>
# <span>Intro Comp Programming</span>
# </h3>
# </div>
# <div class="col-12 p-0">
# <ul class="row list-unstyled">
# <li class="col-sm-auto">Class Number:
#                                 <a name="11410"></a><span>11410</span>
# </li>
# <li class="col-sm-auto">Instructor:
#                                 <span>
# <a href="http://faculty.utah.edu/u1364435/teaching/index.hml" target="_blank">BROWN, NOELLE</a>
# </span>
# </li>
# <li class="col-sm-auto">Component:
#                                 <span>Laboratory</span>
# </li>
# <li class="col-sm-auto">Type:
#                                 <span data-type="P">In Person</span>
# </li>
# <li class="col-sm-auto" data-units="U-U-U">
#                                 Units: <span>--</span></li>
# <li class="col-sm-auto">Requisites: Yes</li>
# <li class="col-sm-auto">Wait List:
#
#                                 <span>No</span>
# </li>
# <li class="col-sm-auto" data-seats="true">
#                                 Seats Available: <span>25</span>
# </li>
# </ul>
# <div class="buttons">
# <a class="btn btn-secondary btn-sm" href="description.html?subj=CS&amp;catno=1400&amp;section=003">Class Details</a>
# </div>
# </div>
# </div>
# <div class="card-footer mp-1">
# <div class="row mb-2">
# <div class="col">
# <table class="table time-table">
# <thead class="class-cards table minimal-headers">
# <tr>
# <th class="text-nowrap text-left text-muted h6 p-0" scope="col">Days / Times</th>
# <th class="text-nowrap text-right text-muted h6 p-0" scope="col">Locations</th>
# </tr>
# </thead>
# <tbody>
# <tr>
# <th class="text-nowrap text-left p-0" scope="row">
# <span data-day="Tu">Tu</span>/<span data-time="M">09:40AM-10:30AM</span>
# </th>
# <th class="text-nowrap text-right p-0" data-building-code="MEB" scope="row">
# <a href="http://map.utah.edu/index.html?code=MEB" target="_blank">MEB 3225</a>
# </th>
# </tr>
# </tbody>
# </table>
# </div>
# </div>
# </div>
# </div>
# <div class="class-info card mt-3" id="11411">
# <div class="card-body row d-none d-md-block">
# <div class="col-12 p-0">
# <div class="buttons">
# <a class="btn btn-secondary btn-sm" href="description.html?subj=CS&amp;catno=1400&amp;section=004">Class Details</a>
# </div>
# <h3>
# <a href="sections.html?subj=CS&amp;catno=1400">CS 1400</a>
#                         -
#                         <span>004</span>
# <span>Intro Comp Programming</span>
# </h3>
# </div>
# <div class="col-12 p-0">
# <ul class="row breadcrumb-list list-unstyled">
# <li class="col-sm-auto">Class Number:
#                             <a id="11411"></a>
# <span>11411</span>
# </li>
# <li class="col-sm-auto">Instructor:
#                             <span>
# <a href="https://profiles.faculty.utah.edu/u1364435" target="_blank">BROWN, NOELLE</a>
# </span>
# </li>
# <li class="col-sm-auto">Component:
#                             <span>Laboratory</span>
# </li>
# <li class="col-sm-auto">Type:
#                             <span data-type="P">In Person</span>
# </li>
# <li class="col-sm-auto" data-units="U-U-U">
#                             Units: <span>--</span>
# </li>
# <li class="col-sm-auto">Requisites: Yes</li>
# <li class="col-sm-auto">Wait List:
#
#                             <span>No</span>
# </li>
# <li class="col-sm-auto d-none" data-seats="true">
#                             Seats Available: <span>25</span>
# </li>
# <li class="col-sm-auto">
# <a href="https://student-course-feedback.app.utah.edu/reports/CS/1400/Laboratory" target="_blank">View Feedback</a>
# </li>
# </ul>
# </div>
# </div>
# <div class="card-body row d-block d-md-none">
# <div class="col-12 p-0">
# <h3>
# <a href="sections.html?subj=CS&amp;catno=1400">CS 1400</a>
#                             -
#                             <span>004</span>
# <span>Intro Comp Programming</span>
# </h3>
# </div>
# <div class="col-12 p-0">
# <ul class="row list-unstyled">
# <li class="col-sm-auto">Class Number:
#                                 <a name="11411"></a><span>11411</span>
# </li>
# <li class="col-sm-auto">Instructor:
#                                 <span>
# <a href="http://faculty.utah.edu/u1364435/teaching/index.hml" target="_blank">BROWN, NOELLE</a>
# </span>
# </li>
# <li class="col-sm-auto">Component:
#                                 <span>Laboratory</span>
# </li>
# <li class="col-sm-auto">Type:
#                                 <span data-type="P">In Person</span>
# </li>
# <li class="col-sm-auto" data-units="U-U-U">
#                                 Units: <span>--</span></li>
# <li class="col-sm-auto">Requisites: Yes</li>
# <li class="col-sm-auto">Wait List:
#
#                                 <span>No</span>
# </li>
# <li class="col-sm-auto" data-seats="true">
#                                 Seats Available: <span>25</span>
# </li>
# </ul>
# <div class="buttons">
# <a class="btn btn-secondary btn-sm" href="description.html?subj=CS&amp;catno=1400&amp;section=004">Class Details</a>
# </div>
# </div>
# </div>
# <div class="card-footer mp-1">
# <div class="row mb-2">
# <div class="col">
# <table class="table time-table">
# <thead class="class-cards table minimal-headers">
# <tr>
# <th class="text-nowrap text-left text-muted h6 p-0" scope="col">Days / Times</th>
# <th class="text-nowrap text-right text-muted h6 p-0" scope="col">Locations</th>
# </tr>
# </thead>
# <tbody>
# <tr>
# <th class="text-nowrap text-left p-0" scope="row">
# <span data-day="Tu">Tu</span>/<span data-time="M">10:45AM-11:35AM</span>
# </th>
# <th class="text-nowrap text-right p-0" data-building-code="MEB" scope="row">
# <a href="http://map.utah.edu/index.html?code=MEB" target="_blank">MEB 3225</a>
# </th>
# </tr>
# </tbody>
# </table>
# </div>
# </div>
# </div>
# </div>
# <div class="class-info card mt-3" id="11412">
# <div class="card-body row d-none d-md-block">
# <div class="col-12 p-0">
# <div class="buttons">
# <a class="btn btn-secondary btn-sm" href="description.html?subj=CS&amp;catno=1400&amp;section=005">Class Details</a>
# </div>
# <h3>
# <a href="sections.html?subj=CS&amp;catno=1400">CS 1400</a>
#                         -
#                         <span>005</span>
# <span>Intro Comp Programming</span>
# </h3>
# </div>
# <div class="col-12 p-0">
# <ul class="row breadcrumb-list list-unstyled">
# <li class="col-sm-auto">Class Number:
#                             <a id="11412"></a>
# <span>11412</span>
# </li>
# <li class="col-sm-auto">Instructor:
#                             <span>
# <a href="https://profiles.faculty.utah.edu/u1364435" target="_blank">BROWN, NOELLE</a>
# </span>
# </li>
# <li class="col-sm-auto">Component:
#                             <span>Laboratory</span>
# </li>
# <li class="col-sm-auto">Type:
#                             <span data-type="P">In Person</span>
# </li>
# <li class="col-sm-auto" data-units="U-U-U">
#                             Units: <span>--</span>
# </li>
# <li class="col-sm-auto">Requisites: Yes</li>
# <li class="col-sm-auto">Wait List:
#
#                             <span>No</span>
# </li>
# <li class="col-sm-auto d-none" data-seats="true">
#                             Seats Available: <span>20</span>
# </li>
# <li class="col-sm-auto">
# <a href="https://student-course-feedback.app.utah.edu/reports/CS/1400/Laboratory" target="_blank">View Feedback</a>
# </li>
# </ul>
# </div>
# </div>
# <div class="card-body row d-block d-md-none">
# <div class="col-12 p-0">
# <h3>
# <a href="sections.html?subj=CS&amp;catno=1400">CS 1400</a>
#                             -
#                             <span>005</span>
# <span>Intro Comp Programming</span>
# </h3>
# </div>
# <div class="col-12 p-0">
# <ul class="row list-unstyled">
# <li class="col-sm-auto">Class Number:
#                                 <a name="11412"></a><span>11412</span>
# </li>
# <li class="col-sm-auto">Instructor:
#                                 <span>
# <a href="http://faculty.utah.edu/u1364435/teaching/index.hml" target="_blank">BROWN, NOELLE</a>
# </span>
# </li>
# <li class="col-sm-auto">Component:
#                                 <span>Laboratory</span>
# </li>
# <li class="col-sm-auto">Type:
#                                 <span data-type="P">In Person</span>
# </li>
# <li class="col-sm-auto" data-units="U-U-U">
#                                 Units: <span>--</span></li>
# <li class="col-sm-auto">Requisites: Yes</li>
# <li class="col-sm-auto">Wait List:
#
#                                 <span>No</span>
# </li>
# <li class="col-sm-auto" data-seats="true">
#                                 Seats Available: <span>20</span>
# </li>
# </ul>
# <div class="buttons">
# <a class="btn btn-secondary btn-sm" href="description.html?subj=CS&amp;catno=1400&amp;section=005">Class Details</a>
# </div>
# </div>
# </div>
# <div class="card-footer mp-1">
# <div class="row mb-2">
# <div class="col">
# <table class="table time-table">
# <thead class="class-cards table minimal-headers">
# <tr>
# <th class="text-nowrap text-left text-muted h6 p-0" scope="col">Days / Times</th>
# <th class="text-nowrap text-right text-muted h6 p-0" scope="col">Locations</th>
# </tr>
# </thead>
# <tbody>
# <tr>
# <th class="text-nowrap text-left p-0" scope="row">
# <span data-day="Tu">Tu</span>/<span data-time="M">11:50AM-12:40PM</span>
# </th>
# <th class="text-nowrap text-right p-0" data-building-code="MEB" scope="row">
# <a href="http://map.utah.edu/index.html?code=MEB" target="_blank">MEB 3225</a>
# </th>
# </tr>
# </tbody>
# </table>
# </div>
# </div>
# </div>
# </div>
# <div class="class-info card mt-3" id="11413">
# <div class="card-body row d-none d-md-block">
# <div class="col-12 p-0">
# <div class="buttons">
# <a class="btn btn-secondary btn-sm" href="description.html?subj=CS&amp;catno=1400&amp;section=006">Class Details</a>
# </div>
# <h3>
# <a href="sections.html?subj=CS&amp;catno=1400">CS 1400</a>
#                         -
#                         <span>006</span>
# <span>Intro Comp Programming</span>
# </h3>
# </div>
# <div class="col-12 p-0">
# <ul class="row breadcrumb-list list-unstyled">
# <li class="col-sm-auto">Class Number:
#                             <a id="11413"></a>
# <span>11413</span>
# </li>
# <li class="col-sm-auto">Instructor:
#                             <span>
# <a href="https://profiles.faculty.utah.edu/u1364435" target="_blank">BROWN, NOELLE</a>
# </span>
# </li>
# <li class="col-sm-auto">Component:
#                             <span>Laboratory</span>
# </li>
# <li class="col-sm-auto">Type:
#                             <span data-type="P">In Person</span>
# </li>
# <li class="col-sm-auto" data-units="U-U-U">
#                             Units: <span>--</span>
# </li>
# <li class="col-sm-auto">Requisites: Yes</li>
# <li class="col-sm-auto">Wait List:
#
#                             <span>No</span>
# </li>
# <li class="col-sm-auto d-none" data-seats="true">
#                             Seats Available: <span>27</span>
# </li>
# <li class="col-sm-auto">
# <a href="https://student-course-feedback.app.utah.edu/reports/CS/1400/Laboratory" target="_blank">View Feedback</a>
# </li>
# </ul>
# </div>
# </div>
# <div class="card-body row d-block d-md-none">
# <div class="col-12 p-0">
# <h3>
# <a href="sections.html?subj=CS&amp;catno=1400">CS 1400</a>
#                             -
#                             <span>006</span>
# <span>Intro Comp Programming</span>
# </h3>
# </div>
# <div class="col-12 p-0">
# <ul class="row list-unstyled">
# <li class="col-sm-auto">Class Number:
#                                 <a name="11413"></a><span>11413</span>
# </li>
# <li class="col-sm-auto">Instructor:
#                                 <span>
# <a href="http://faculty.utah.edu/u1364435/teaching/index.hml" target="_blank">BROWN, NOELLE</a>
# </span>
# </li>
# <li class="col-sm-auto">Component:
#                                 <span>Laboratory</span>
# </li>
# <li class="col-sm-auto">Type:
#                                 <span data-type="P">In Person</span>
# </li>
# <li class="col-sm-auto" data-units="U-U-U">
#                                 Units: <span>--</span></li>
# <li class="col-sm-auto">Requisites: Yes</li>
# <li class="col-sm-auto">Wait List:
#
#                                 <span>No</span>
# </li>
# <li class="col-sm-auto" data-seats="true">
#                                 Seats Available: <span>27</span>
# </li>
# </ul>
# <div class="buttons">
# <a class="btn btn-secondary btn-sm" href="description.html?subj=CS&amp;catno=1400&amp;section=006">Class Details</a>
# </div>
# </div>
# </div>
# <div class="card-footer mp-1">
# <div class="row mb-2">
# <div class="col">
# <table class="table time-table">
# <thead class="class-cards table minimal-headers">
# <tr>
# <th class="text-nowrap text-left text-muted h6 p-0" scope="col">Days / Times</th>
# <th class="text-nowrap text-right text-muted h6 p-0" scope="col">Locations</th>
# </tr>
# </thead>
# <tbody>
# <tr>
# <th class="text-nowrap text-left p-0" scope="row">
# <span data-day="Tu">Tu</span>/<span data-time="A">12:55PM-01:45PM</span>
# </th>
# <th class="text-nowrap text-right p-0" data-building-code="MEB" scope="row">
# <a href="http://map.utah.edu/index.html?code=MEB" target="_blank">MEB 3225</a>
# </th>
# </tr>
# </tbody>
# </table>
# </div>
# </div>
# </div>
# </div>
# <div class="class-info card mt-3" id="11414">
# <div class="card-body row d-none d-md-block">
# <div class="col-12 p-0">
# <div class="buttons">
# <a class="btn btn-secondary btn-sm" href="description.html?subj=CS&amp;catno=1400&amp;section=007">Class Details</a>
# </div>
# <h3>
# <a href="sections.html?subj=CS&amp;catno=1400">CS 1400</a>
#                         -
#                         <span>007</span>
# <span>Intro Comp Programming</span>
# </h3>
# </div>
# <div class="col-12 p-0">
# <ul class="row breadcrumb-list list-unstyled">
# <li class="col-sm-auto">Class Number:
#                             <a id="11414"></a>
# <span>11414</span>
# </li>
# <li class="col-sm-auto">Instructor:
#                             <span>
# <a href="https://profiles.faculty.utah.edu/u1364435" target="_blank">BROWN, NOELLE</a>
# </span>
# </li>
# <li class="col-sm-auto">Component:
#                             <span>Laboratory</span>
# </li>
# <li class="col-sm-auto">Type:
#                             <span data-type="P">In Person</span>
# </li>
# <li class="col-sm-auto" data-units="U-U-U">
#                             Units: <span>--</span>
# </li>
# <li class="col-sm-auto">Requisites: Yes</li>
# <li class="col-sm-auto">Wait List:
#
#                             <span>No</span>
# </li>
# <li class="col-sm-auto d-none" data-seats="true">
#                             Seats Available: <span>23</span>
# </li>
# <li class="col-sm-auto">
# <a href="https://student-course-feedback.app.utah.edu/reports/CS/1400/Laboratory" target="_blank">View Feedback</a>
# </li>
# </ul>
# </div>
# </div>
# <div class="card-body row d-block d-md-none">
# <div class="col-12 p-0">
# <h3>
# <a href="sections.html?subj=CS&amp;catno=1400">CS 1400</a>
#                             -
#                             <span>007</span>
# <span>Intro Comp Programming</span>
# </h3>
# </div>
# <div class="col-12 p-0">
# <ul class="row list-unstyled">
# <li class="col-sm-auto">Class Number:
#                                 <a name="11414"></a><span>11414</span>
# </li>
# <li class="col-sm-auto">Instructor:
#                                 <span>
# <a href="http://faculty.utah.edu/u1364435/teaching/index.hml" target="_blank">BROWN, NOELLE</a>
# </span>
# </li>
# <li class="col-sm-auto">Component:
#                                 <span>Laboratory</span>
# </li>
# <li class="col-sm-auto">Type:
#                                 <span data-type="P">In Person</span>
# </li>
# <li class="col-sm-auto" data-units="U-U-U">
#                                 Units: <span>--</span></li>
# <li class="col-sm-auto">Requisites: Yes</li>
# <li class="col-sm-auto">Wait List:
#
#                                 <span>No</span>
# </li>
# <li class="col-sm-auto" data-seats="true">
#                                 Seats Available: <span>23</span>
# </li>
# </ul>
# <div class="buttons">
# <a class="btn btn-secondary btn-sm" href="description.html?subj=CS&amp;catno=1400&amp;section=007">Class Details</a>
# </div>
# </div>
# </div>
# <div class="card-footer mp-1">
# <div class="row mb-2">
# <div class="col">
# <table class="table time-table">
# <thead class="class-cards table minimal-headers">
# <tr>
# <th class="text-nowrap text-left text-muted h6 p-0" scope="col">Days / Times</th>
# <th class="text-nowrap text-right text-muted h6 p-0" scope="col">Locations</th>
# </tr>
# </thead>
# <tbody>
# <tr>
# <th class="text-nowrap text-left p-0" scope="row">
# <span data-day="Tu">Tu</span>/<span data-time="A">02:00PM-02:50PM</span>
# </th>
# <th class="text-nowrap text-right p-0" data-building-code="MEB" scope="row">
# <a href="http://map.utah.edu/index.html?code=MEB" target="_blank">MEB 3225</a>
# </th>
# </tr>
# </tbody>
# </table>
# </div>
# </div>
# </div>
# </div>
# <div class="class-info card mt-3" id="11418">
# <div class="card-body row d-none d-md-block">
# <div class="col-12 p-0">
# <div class="buttons">
# <a class="btn btn-secondary btn-sm" href="description.html?subj=CS&amp;catno=1410&amp;section=001">Class Details</a>
# </div>
# <h3>
# <a href="sections.html?subj=CS&amp;catno=1410">CS 1410</a>
#                         -
#                         <span>001</span>
# <span>Object-Oriented Prog</span>
# </h3>
# </div>
# <div class="col-12 p-0">
# <ul class="row breadcrumb-list list-unstyled">
# <li class="col-sm-auto">Class Number:
#                             <a id="11418"></a>
# </li>
# <li class="col-sm-auto">Instructor:
#                             <span>
# <a href="https://profiles.faculty.utah.edu/u6033603" target="_blank">MARTIN, TRAVIS B</a>
# </span>
# </li>
# <li class="col-sm-auto">Component:
#                             <span>Lecture</span>
# </li>
# <li class="col-sm-auto">Type:
#                             <span data-type="P">In Person</span>
# </li>
# <li class="col-sm-auto" data-units="U4_0">
#                             Units: <span>  4.0</span>
# </li>
# <li class="col-sm-auto">Requisites: Yes</li>
# <li class="col-sm-auto">Wait List:
#
#                             <span>No</span>
# </li>
# <li class="col-sm-auto d-none" data-seats="true">
#                             Seats Available: <span>152</span>
# </li>
# <li class="col-sm-auto">
# <a href="https://student-course-feedback.app.utah.edu/reports/CS/1410/Lecture" target="_blank">View Feedback</a>
# </li>
# </ul>
# <hr>
# <span> This course requires registration for a lab and/or discussion section. Students will be automatically registered for this lecture section when registering for the pertinent lab and/or discussion section. </span>
# </hr></div>
# </div>
# <div class="card-body row d-block d-md-none">
# <div class="col-12 p-0">
# <h3>
# <a href="sections.html?subj=CS&amp;catno=1410">CS 1410</a>
#                             -
#                             <span>001</span>
# <span>Object-Oriented Prog</span>
# </h3>
# </div>
# <div class="col-12 p-0">
# <ul class="row list-unstyled">
# <li class="col-sm-auto">Class Number:
#                                 <a name="11418"></a>
# </li>
# <li class="col-sm-auto">Instructor:
#                                 <span>
# <a href="http://faculty.utah.edu/u6033603/teaching/index.hml" target="_blank">MARTIN, TRAVIS B</a>
# </span>
# </li>
# <li class="col-sm-auto">Component:
#                                 <span>Lecture</span>
# </li>
# <li class="col-sm-auto">Type:
#                                 <span data-type="P">In Person</span>
# </li>
# <li class="col-sm-auto" data-units="U4_0">
#                                 Units: <span>  4.0</span></li>
# <li class="col-sm-auto">Requisites: Yes</li>
# <li class="col-sm-auto">Wait List:
#
#                                 <span>No</span>
# </li>
# <li class="col-sm-auto" data-seats="true">
#                                 Seats Available: <span>152</span>
# </li>
# </ul>
# <div class="buttons">
# <a class="btn btn-secondary btn-sm" href="description.html?subj=CS&amp;catno=1410&amp;section=001">Class Details</a>
# </div>
# <hr class="class-notes-divider"/>
# <span> This course requires registration for a lab and/or discussion section. Students will be automatically registered for this lecture section when registering for the pertinent lab and/or discussion section. </span>
# </div>
# </div>
# <div class="card-footer mp-1">
# <div class="row mb-2">
# <div class="col">
# <table class="table time-table">
# <thead class="class-cards table minimal-headers">
# <tr>
# <th class="text-nowrap text-left text-muted h6 p-0" scope="col">Days / Times</th>
# <th class="text-nowrap text-right text-muted h6 p-0" scope="col">Locations</th>
# </tr>
# </thead>
# <tbody>
# <tr>
# <th class="text-nowrap text-left p-0" scope="row">
# <span data-day="MoWe">MoWe</span>/<span data-time="A">03:00PM-04:20PM</span>
# </th>
# <th class="text-nowrap text-right p-0" data-building-code="GC" scope="row">
# <a href="http://map.utah.edu/index.html?code=GC" target="_blank">GC 1900</a>
# </th>
# </tr>
# </tbody>
# </table>
# </div>
# </div>
# </div>
# </div>
# <div class="class-info card mt-3" id="11420">
# <div class="card-body row d-none d-md-block">
# <div class="col-12 p-0">
# <div class="buttons">
# <a class="btn btn-secondary btn-sm" href="description.html?subj=CS&amp;catno=1410&amp;section=003">Class Details</a>
# </div>
# <h3>
# <a href="sections.html?subj=CS&amp;catno=1410">CS 1410</a>
#                         -
#                         <span>003</span>
# <span>Object-Oriented Prog</span>
# </h3>
# </div>
# <div class="col-12 p-0">
# <ul class="row breadcrumb-list list-unstyled">
# <li class="col-sm-auto">Class Number:
#                             <a id="11420"></a>
# <span>11420</span>
# </li>
# <li class="col-sm-auto">Instructor:
#                             <span>
# <a href="https://profiles.faculty.utah.edu/u6033603" target="_blank">MARTIN, TRAVIS B</a>
# </span>
# </li>
# <li class="col-sm-auto">Component:
#                             <span>Laboratory</span>
# </li>
# <li class="col-sm-auto">Type:
#                             <span data-type="P">In Person</span>
# </li>
# <li class="col-sm-auto" data-units="U-U-U">
#                             Units: <span>--</span>
# </li>
# <li class="col-sm-auto">Requisites: Yes</li>
# <li class="col-sm-auto">Wait List:
#
#                             <span>No</span>
# </li>
# <li class="col-sm-auto d-none" data-seats="false">
#                             Seats Available: <span>0</span>
# </li>
# <li class="col-sm-auto">
# <a href="https://student-course-feedback.app.utah.edu/reports/CS/1410/Laboratory" target="_blank">View Feedback</a>
# </li>
# </ul>
# </div>
# </div>
# <div class="card-body row d-block d-md-none">
# <div class="col-12 p-0">
# <h3>
# <a href="sections.html?subj=CS&amp;catno=1410">CS 1410</a>
#                             -
#                             <span>003</span>
# <span>Object-Oriented Prog</span>
# </h3>
# </div>
# <div class="col-12 p-0">
# <ul class="row list-unstyled">
# <li class="col-sm-auto">Class Number:
#                                 <a name="11420"></a><span>11420</span>
# </li>
# <li class="col-sm-auto">Instructor:
#                                 <span>
# <a href="http://faculty.utah.edu/u6033603/teaching/index.hml" target="_blank">MARTIN, TRAVIS B</a>
# </span>
# </li>
# <li class="col-sm-auto">Component:
#                                 <span>Laboratory</span>
# </li>
# <li class="col-sm-auto">Type:
#                                 <span data-type="P">In Person</span>
# </li>
# <li class="col-sm-auto" data-units="U-U-U">
#                                 Units: <span>--</span></li>
# <li class="col-sm-auto">Requisites: Yes</li>
# <li class="col-sm-auto">Wait List:
#
#                                 <span>No</span>
# </li>
# <li class="col-sm-auto" data-seats="false">
#                                 Seats Available: <span>0</span>
# </li>
# </ul>
# <div class="buttons">
# <a class="btn btn-secondary btn-sm" href="description.html?subj=CS&amp;catno=1410&amp;section=003">Class Details</a>
# </div>
# </div>
# </div>
# <div class="card-footer mp-1">
# <div class="row mb-2">
# <div class="col">
# <table class="table time-table">
# <thead class="class-cards table minimal-headers">
# <tr>
# <th class="text-nowrap text-left text-muted h6 p-0" scope="col">Days / Times</th>
# <th class="text-nowrap text-right text-muted h6 p-0" scope="col">Locations</th>
# </tr>
# </thead>
# <tbody>
# <tr>
# <th class="text-nowrap text-left p-0" scope="row">
# <span data-day="Th">Th</span>/<span data-time="M">09:40AM-10:30AM</span>
# </th>
# <th class="text-nowrap text-right p-0" data-building-code="MEB" scope="row">
# <a href="http://map.utah.edu/index.html?code=MEB" target="_blank">MEB 3225</a>
# </th>
# </tr>
# </tbody>
# </table>
# </div>
# </div>
# </div>
# </div>
# <div class="class-info card mt-3" id="11421">
# <div class="card-body row d-none d-md-block">
# <div class="col-12 p-0">
# <div class="buttons">
# <a class="btn btn-secondary btn-sm" href="description.html?subj=CS&amp;catno=1410&amp;section=004">Class Details</a>
# </div>
# <h3>
# <a href="sections.html?subj=CS&amp;catno=1410">CS 1410</a>
#                         -
#                         <span>004</span>
# <span>Object-Oriented Prog</span>
# </h3>
# </div>
# <div class="col-12 p-0">
# <ul class="row breadcrumb-list list-unstyled">
# <li class="col-sm-auto">Class Number:
#                             <a id="11421"></a>
# <span>11421</span>
# </li>
# <li class="col-sm-auto">Instructor:
#                             <span>
# <a href="https://profiles.faculty.utah.edu/u6033603" target="_blank">MARTIN, TRAVIS B</a>
# </span>
# </li>
# <li class="col-sm-auto">Component:
#                             <span>Laboratory</span>
# </li>
# <li class="col-sm-auto">Type:
#                             <span data-type="P">In Person</span>
# </li>
# <li class="col-sm-auto" data-units="U-U-U">
#                             Units: <span>--</span>
# </li>
# <li class="col-sm-auto">Requisites: Yes</li>
# <li class="col-sm-auto">Wait List:
#
#                             <span>No</span>
# </li>
# <li class="col-sm-auto d-none" data-seats="true">
#                             Seats Available: <span>1</span>
# </li>
# <li class="col-sm-auto">
# <a href="https://student-course-feedback.app.utah.edu/reports/CS/1410/Laboratory" target="_blank">View Feedback</a>
# </li>
# </ul>
# </div>
# </div>
# <div class="card-body row d-block d-md-none">
# <div class="col-12 p-0">
# <h3>
# <a href="sections.html?subj=CS&amp;catno=1410">CS 1410</a>
#                             -
#                             <span>004</span>
# <span>Object-Oriented Prog</span>
# </h3>
# </div>
# <div class="col-12 p-0">
# <ul class="row list-unstyled">
# <li class="col-sm-auto">Class Number:
#                                 <a name="11421"></a><span>11421</span>
# </li>
# <li class="col-sm-auto">Instructor:
#                                 <span>
# <a href="http://faculty.utah.edu/u6033603/teaching/index.hml" target="_blank">MARTIN, TRAVIS B</a>
# </span>
# </li>
# <li class="col-sm-auto">Component:
#                                 <span>Laboratory</span>
# </li>
# <li class="col-sm-auto">Type:
#                                 <span data-type="P">In Person</span>
# </li>
# <li class="col-sm-auto" data-units="U-U-U">
#                                 Units: <span>--</span></li>
# <li class="col-sm-auto">Requisites: Yes</li>
# <li class="col-sm-auto">Wait List:
#
#                                 <span>No</span>
# </li>
# <li class="col-sm-auto" data-seats="true">
#                                 Seats Available: <span>1</span>
# </li>
# </ul>
# <div class="buttons">
# <a class="btn btn-secondary btn-sm" href="description.html?subj=CS&amp;catno=1410&amp;section=004">Class Details</a>
# </div>
# </div>
# </div>
# <div class="card-footer mp-1">
# <div class="row mb-2">
# <div class="col">
# <table class="table time-table">
# <thead class="class-cards table minimal-headers">
# <tr>
# <th class="text-nowrap text-left text-muted h6 p-0" scope="col">Days / Times</th>
# <th class="text-nowrap text-right text-muted h6 p-0" scope="col">Locations</th>
# </tr>
# </thead>
# <tbody>
# <tr>
# <th class="text-nowrap text-left p-0" scope="row">
# <span data-day="Th">Th</span>/<span data-time="M">10:45AM-11:35AM</span>
# </th>
# <th class="text-nowrap text-right p-0" data-building-code="MEB" scope="row">
# <a href="http://map.utah.edu/index.html?code=MEB" target="_blank">MEB 3225</a>
# </th>
# </tr>
# </tbody>
# </table>
# </div>
# </div>
# </div>
# </div>
# <div class="class-info card mt-3" id="12256">
# <div class="card-body row d-none d-md-block">
# <div class="col-12 p-0">
# <div class="buttons">
# <a class="btn btn-secondary btn-sm" href="description.html?subj=CS&amp;catno=1410&amp;section=005">Class Details</a>
# </div>
# <h3>
# <a href="sections.html?subj=CS&amp;catno=1410">CS 1410</a>
#                         -
#                         <span>005</span>
# <span>Object-Oriented Prog</span>
# </h3>
# </div>
# <div class="col-12 p-0">
# <ul class="row breadcrumb-list list-unstyled">
# <li class="col-sm-auto">Class Number:
#                             <a id="12256"></a>
# <span>12256</span>
# </li>
# <li class="col-sm-auto">Instructor:
#                             <span>
# <a href="https://profiles.faculty.utah.edu/u6033603" target="_blank">MARTIN, TRAVIS B</a>
# </span>
# </li>
# <li class="col-sm-auto">Component:
#                             <span>Laboratory</span>
# </li>
# <li class="col-sm-auto">Type:
#                             <span data-type="P">In Person</span>
# </li>
# <li class="col-sm-auto" data-units="U-U-U">
#                             Units: <span>--</span>
# </li>
# <li class="col-sm-auto">Requisites: Yes</li>
# <li class="col-sm-auto">Wait List:
#
#                             <span>No</span>
# </li>
# <li class="col-sm-auto d-none" data-seats="true">
#                             Seats Available: <span>18</span>
# </li>
# <li class="col-sm-auto">
# <a href="https://student-course-feedback.app.utah.edu/reports/CS/1410/Laboratory" target="_blank">View Feedback</a>
# </li>
# </ul>
# </div>
# </div>
# <div class="card-body row d-block d-md-none">
# <div class="col-12 p-0">
# <h3>
# <a href="sections.html?subj=CS&amp;catno=1410">CS 1410</a>
#                             -
#                             <span>005</span>
# <span>Object-Oriented Prog</span>
# </h3>
# </div>
# <div class="col-12 p-0">
# <ul class="row list-unstyled">
# <li class="col-sm-auto">Class Number:
#                                 <a name="12256"></a><span>12256</span>
# </li>
# <li class="col-sm-auto">Instructor:
#                                 <span>
# <a href="http://faculty.utah.edu/u6033603/teaching/index.hml" target="_blank">MARTIN, TRAVIS B</a>
# </span>
# </li>
# <li class="col-sm-auto">Component:
#                                 <span>Laboratory</span>
# </li>
# <li class="col-sm-auto">Type:
#                                 <span data-type="P">In Person</span>
# </li>
# <li class="col-sm-auto" data-units="U-U-U">
#                                 Units: <span>--</span></li>
# <li class="col-sm-auto">Requisites: Yes</li>
# <li class="col-sm-auto">Wait List:
#
#                                 <span>No</span>
# </li>
# <li class="col-sm-auto" data-seats="true">
#                                 Seats Available: <span>18</span>
# </li>
# </ul>
# <div class="buttons">
# <a class="btn btn-secondary btn-sm" href="description.html?subj=CS&amp;catno=1410&amp;section=005">Class Details</a>
# </div>
# </div>
# </div>
# <div class="card-footer mp-1">
# <div class="row mb-2">
# <div class="col">
# <table class="table time-table">
# <thead class="class-cards table minimal-headers">
# <tr>
# <th class="text-nowrap text-left text-muted h6 p-0" scope="col">Days / Times</th>
# <th class="text-nowrap text-right text-muted h6 p-0" scope="col">Locations</th>
# </tr>
# </thead>
# <tbody>
# <tr>
# <th class="text-nowrap text-left p-0" scope="row">
# <span data-day="Th">Th</span>/<span data-time="M">11:50AM-12:40PM</span>
# </th>
# <th class="text-nowrap text-right p-0" data-building-code="MEB" scope="row">
# <a href="http://map.utah.edu/index.html?code=MEB" target="_blank">MEB 3225</a>
# </th>
# </tr>
# </tbody>
# </table>
# </div>
# </div>
# </div>
# </div>
# <div class="class-info card mt-3" id="11422">
# <div class="card-body row d-none d-md-block">
# <div class="col-12 p-0">
# <div class="buttons">
# <a class="btn btn-secondary btn-sm" href="description.html?subj=CS&amp;catno=1410&amp;section=006">Class Details</a>
# </div>
# <h3>
# <a href="sections.html?subj=CS&amp;catno=1410">CS 1410</a>
#                         -
#                         <span>006</span>
# <span>Object-Oriented Prog</span>
# </h3>
# </div>
# <div class="col-12 p-0">
# <ul class="row breadcrumb-list list-unstyled">
# <li class="col-sm-auto">Class Number:
#                             <a id="11422"></a>
# <span>11422</span>
# </li>
# <li class="col-sm-auto">Instructor:
#                             <span>
# <a href="https://profiles.faculty.utah.edu/u6033603" target="_blank">MARTIN, TRAVIS B</a>
# </span>
# </li>
# <li class="col-sm-auto">Component:
#                             <span>Laboratory</span>
# </li>
# <li class="col-sm-auto">Type:
#                             <span data-type="P">In Person</span>
# </li>
# <li class="col-sm-auto" data-units="U-U-U">
#                             Units: <span>--</span>
# </li>
# <li class="col-sm-auto">Requisites: Yes</li>
# <li class="col-sm-auto">Wait List:
#
#                             <span>No</span>
# </li>
# <li class="col-sm-auto d-none" data-seats="true">
#                             Seats Available: <span>14</span>
# </li>
# <li class="col-sm-auto">
# <a href="https://student-course-feedback.app.utah.edu/reports/CS/1410/Laboratory" target="_blank">View Feedback</a>
# </li>
# </ul>
# </div>
# </div>
# <div class="card-body row d-block d-md-none">
# <div class="col-12 p-0">
# <h3>
# <a href="sections.html?subj=CS&amp;catno=1410">CS 1410</a>
#                             -
#                             <span>006</span>
# <span>Object-Oriented Prog</span>
# </h3>
# </div>
# <div class="col-12 p-0">
# <ul class="row list-unstyled">
# <li class="col-sm-auto">Class Number:
#                                 <a name="11422"></a><span>11422</span>
# </li>
# <li class="col-sm-auto">Instructor:
#                                 <span>
# <a href="http://faculty.utah.edu/u6033603/teaching/index.hml" target="_blank">MARTIN, TRAVIS B</a>
# </span>
# </li>
# <li class="col-sm-auto">Component:
#                                 <span>Laboratory</span>
# </li>
# <li class="col-sm-auto">Type:
#                                 <span data-type="P">In Person</span>
# </li>
# <li class="col-sm-auto" data-units="U-U-U">
#                                 Units: <span>--</span></li>
# <li class="col-sm-auto">Requisites: Yes</li>
# <li class="col-sm-auto">Wait List:
#
#                                 <span>No</span>
# </li>
# <li class="col-sm-auto" data-seats="true">
#                                 Seats Available: <span>14</span>
# </li>
# </ul>
# <div class="buttons">
# <a class="btn btn-secondary btn-sm" href="description.html?subj=CS&amp;catno=1410&amp;section=006">Class Details</a>
# </div>
# </div>
# </div>
# <div class="card-footer mp-1">
# <div class="row mb-2">
# <div class="col">
# <table class="table time-table">
# <thead class="class-cards table minimal-headers">
# <tr>
# <th class="text-nowrap text-left text-muted h6 p-0" scope="col">Days / Times</th>
# <th class="text-nowrap text-right text-muted h6 p-0" scope="col">Locations</th>
# </tr>
# </thead>
# <tbody>
# <tr>
# <th class="text-nowrap text-left p-0" scope="row">
# <span data-day="Th">Th</span>/<span data-time="A">12:55PM-01:45PM</span>
# </th>
# <th class="text-nowrap text-right p-0" data-building-code="MEB" scope="row">
# <a href="http://map.utah.edu/index.html?code=MEB" target="_blank">MEB 3225</a>
# </th>
# </tr>
# </tbody>
# </table>
# </div>
# </div>
# </div>
# </div>
# <div class="class-info card mt-3" id="11423">
# <div class="card-body row d-none d-md-block">
# <div class="col-12 p-0">
# <div class="buttons">
# <a class="btn btn-secondary btn-sm" href="description.html?subj=CS&amp;catno=1410&amp;section=007">Class Details</a>
# </div>
# <h3>
# <a href="sections.html?subj=CS&amp;catno=1410">CS 1410</a>
#                         -
#                         <span>007</span>
# <span>Object-Oriented Prog</span>
# </h3>
# </div>
# <div class="col-12 p-0">
# <ul class="row breadcrumb-list list-unstyled">
# <li class="col-sm-auto">Class Number:
#                             <a id="11423"></a>
# <span>11423</span>
# </li>
# <li class="col-sm-auto">Instructor:
#                             <span>
# <a href="https://profiles.faculty.utah.edu/u6033603" target="_blank">MARTIN, TRAVIS B</a>
# </span>
# </li>
# <li class="col-sm-auto">Component:
#                             <span>Laboratory</span>
# </li>
# <li class="col-sm-auto">Type:
#                             <span data-type="P">In Person</span>
# </li>
# <li class="col-sm-auto" data-units="U-U-U">
#                             Units: <span>--</span>
# </li>
# <li class="col-sm-auto">Requisites: Yes</li>
# <li class="col-sm-auto">Wait List:
#
#                             <span>No</span>
# </li>
# <li class="col-sm-auto d-none" data-seats="true">
#                             Seats Available: <span>14</span>
# </li>
# <li class="col-sm-auto">
# <a href="https://student-course-feedback.app.utah.edu/reports/CS/1410/Laboratory" target="_blank">View Feedback</a>
# </li>
# </ul>
# </div>
# </div>
# <div class="card-body row d-block d-md-none">
# <div class="col-12 p-0">
# <h3>
# <a href="sections.html?subj=CS&amp;catno=1410">CS 1410</a>
#                             -
#                             <span>007</span>
# <span>Object-Oriented Prog</span>
# </h3>
# </div>
# <div class="col-12 p-0">
# <ul class="row list-unstyled">
# <li class="col-sm-auto">Class Number:
#                                 <a name="11423"></a><span>11423</span>
# </li>
# <li class="col-sm-auto">Instructor:
#                                 <span>
# <a href="http://faculty.utah.edu/u6033603/teaching/index.hml" target="_blank">MARTIN, TRAVIS B</a>
# </span>
# </li>
# <li class="col-sm-auto">Component:
#                                 <span>Laboratory</span>
# </li>
# <li class="col-sm-auto">Type:
#                                 <span data-type="P">In Person</span>
# </li>
# <li class="col-sm-auto" data-units="U-U-U">
#                                 Units: <span>--</span></li>
# <li class="col-sm-auto">Requisites: Yes</li>
# <li class="col-sm-auto">Wait List:
#
#                                 <span>No</span>
# </li>
# <li class="col-sm-auto" data-seats="true">
#                                 Seats Available: <span>14</span>
# </li>
# </ul>
# <div class="buttons">
# <a class="btn btn-secondary btn-sm" href="description.html?subj=CS&amp;catno=1410&amp;section=007">Class Details</a>
# </div>
# </div>
# </div>
# <div class="card-footer mp-1">
# <div class="row mb-2">
# <div class="col">
# <table class="table time-table">
# <thead class="class-cards table minimal-headers">
# <tr>
# <th class="text-nowrap text-left text-muted h6 p-0" scope="col">Days / Times</th>
# <th class="text-nowrap text-right text-muted h6 p-0" scope="col">Locations</th>
# </tr>
# </thead>
# <tbody>
# <tr>
# <th class="text-nowrap text-left p-0" scope="row">
# <span data-day="Th">Th</span>/<span data-time="A">02:00PM-02:50PM</span>
# </th>
# <th class="text-nowrap text-right p-0" data-building-code="MEB" scope="row">
# <a href="http://map.utah.edu/index.html?code=MEB" target="_blank">MEB 3225</a>
# </th>
# </tr>
# </tbody>
# </table>
# </div>
# </div>
# </div>
# </div>
# <div class="class-info card mt-3" id="11424">
# <div class="card-body row d-none d-md-block">
# <div class="col-12 p-0">
# <div class="buttons">
# <a class="btn btn-secondary btn-sm" href="description.html?subj=CS&amp;catno=1410&amp;section=008">Class Details</a>
# </div>
# <h3>
# <a href="sections.html?subj=CS&amp;catno=1410">CS 1410</a>
#                         -
#                         <span>008</span>
# <span>Object-Oriented Prog</span>
# </h3>
# </div>
# <div class="col-12 p-0">
# <ul class="row breadcrumb-list list-unstyled">
# <li class="col-sm-auto">Class Number:
#                             <a id="11424"></a>
# <span>11424</span>
# </li>
# <li class="col-sm-auto">Instructor:
#                             <span>
# <a href="https://profiles.faculty.utah.edu/u6033603" target="_blank">MARTIN, TRAVIS B</a>
# </span>
# </li>
# <li class="col-sm-auto">Component:
#                             <span>Laboratory</span>
# </li>
# <li class="col-sm-auto">Type:
#                             <span data-type="P">In Person</span>
# </li>
# <li class="col-sm-auto" data-units="U-U-U">
#                             Units: <span>--</span>
# </li>
# <li class="col-sm-auto">Requisites: Yes</li>
# <li class="col-sm-auto">Wait List:
#
#                             <span>No</span>
# </li>
# <li class="col-sm-auto d-none" data-seats="true">
#                             Seats Available: <span>23</span>
# </li>
# <li class="col-sm-auto">
# <a href="https://student-course-feedback.app.utah.edu/reports/CS/1410/Laboratory" target="_blank">View Feedback</a>
# </li>
# </ul>
# </div>
# </div>
# <div class="card-body row d-block d-md-none">
# <div class="col-12 p-0">
# <h3>
# <a href="sections.html?subj=CS&amp;catno=1410">CS 1410</a>
#                             -
#                             <span>008</span>
# <span>Object-Oriented Prog</span>
# </h3>
# </div>
# <div class="col-12 p-0">
# <ul class="row list-unstyled">
# <li class="col-sm-auto">Class Number:
#                                 <a name="11424"></a><span>11424</span>
# </li>
# <li class="col-sm-auto">Instructor:
#                                 <span>
# <a href="http://faculty.utah.edu/u6033603/teaching/index.hml" target="_blank">MARTIN, TRAVIS B</a>
# </span>
# </li>
# <li class="col-sm-auto">Component:
#                                 <span>Laboratory</span>
# </li>
# <li class="col-sm-auto">Type:
#                                 <span data-type="P">In Person</span>
# </li>
# <li class="col-sm-auto" data-units="U-U-U">
#                                 Units: <span>--</span></li>
# <li class="col-sm-auto">Requisites: Yes</li>
# <li class="col-sm-auto">Wait List:
#
#                                 <span>No</span>
# </li>
# <li class="col-sm-auto" data-seats="true">
#                                 Seats Available: <span>23</span>
# </li>
# </ul>
# <div class="buttons">
# <a class="btn btn-secondary btn-sm" href="description.html?subj=CS&amp;catno=1410&amp;section=008">Class Details</a>
# </div>
# </div>
# </div>
# <div class="card-footer mp-1">
# <div class="row mb-2">
# <div class="col">
# <table class="table time-table">
# <thead class="class-cards table minimal-headers">
# <tr>
# <th class="text-nowrap text-left text-muted h6 p-0" scope="col">Days / Times</th>
# <th class="text-nowrap text-right text-muted h6 p-0" scope="col">Locations</th>
# </tr>
# </thead>
# ...
#
#                                 <span>No</span>
# </li>
# <li class="col-sm-auto" data-seats="true">
#                                 Seats Available: <span>10</span>
# </li>
# </ul>
# <div class="buttons">
# <a class="btn btn-secondary btn-sm" href="description.html?subj=CS&amp;catno=7937&amp;section=001">Class Details</a>
# </div>
# <hr class="class-notes-divider"/>
# <span>Meets in MEB 2170  </span>
# </div>
# </div>
# <div class="card-footer mp-1">
# <div class="row mb-2">
# <div class="col">
# <table class="table time-table">
# <thead class="class-cards table minimal-headers">
# <tr>
# <th class="text-nowrap text-left text-muted h6 p-0" scope="col">Days / Times</th>
# <th class="text-nowrap text-right text-muted h6 p-0" scope="col">Locations</th>
# </tr>
# </thead>
# <tbody>
# <tr>
# <th class="text-nowrap text-left p-0" scope="row">
# <span data-day="Fr">Fr</span>/<span data-time="M">09:30AM-11:00AM</span>
# </th>
# <th class="text-nowrap text-right p-0" data-building-code="MEB RM" scope="row">
# <a href="http://map.utah.edu/index.html?code=MEB RM" target="_blank">MEB RM TBA</a>
# </th>
# </tr>
# </tbody>
# </table>
# </div>
# </div>
# </div>
# </div>
# <div class="class-info card mt-3" id="5527">
# <div class="card-body row d-none d-md-block">
# <div class="col-12 p-0">
# <div class="buttons">
# <a class="btn btn-secondary btn-sm" href="description.html?subj=CS&amp;catno=7938&amp;section=001">Class Details</a>
# </div>
# <h3>
# <a href="sections.html?subj=CS&amp;catno=7938">CS 7938</a>
#                         -
#                         <span>001</span>
# <span>Image Analysis Seminar</span>
# </h3>
# </div>
# <div class="col-12 p-0">
# <ul class="row breadcrumb-list list-unstyled">
# <li class="col-sm-auto">Class Number:
#                             <a id="5527"></a>
# <span>5527</span>
# </li>
# <li class="col-sm-auto">Instructor:
#                             <span>
# <a href="https://profiles.faculty.utah.edu/u0492366" target="_blank">JOSHI, SARANG</a>
# </span>
# </li>
# <li class="col-sm-auto">Component:
#                             <span>Seminar</span>
# </li>
# <li class="col-sm-auto">Type:
#                             <span data-type="P">In Person</span>
# </li>
# <li class="col-sm-auto" data-units="U1_0">
#                             Units: <span>  1.0</span>
# </li>
# <li class="col-sm-auto">Requisites: Yes</li>
# <li class="col-sm-auto">Wait List:
#
#                             <span>No</span>
# </li>
# <li class="col-sm-auto d-none" data-seats="true">
#                             Seats Available: <span>20</span>
# </li>
# <li class="col-sm-auto">
# <a href="https://student-course-feedback.app.utah.edu/reports/CS/7938/Seminar" target="_blank">View Feedback</a>
# </li>
# </ul>
# </div>
# </div>
# <div class="card-body row d-block d-md-none">
# <div class="col-12 p-0">
# <h3>
# <a href="sections.html?subj=CS&amp;catno=7938">CS 7938</a>
#                             -
#                             <span>001</span>
# <span>Image Analysis Seminar</span>
# </h3>
# </div>
# <div class="col-12 p-0">
# <ul class="row list-unstyled">
# <li class="col-sm-auto">Class Number:
#                                 <a name="5527"></a><span>5527</span>
# </li>
# <li class="col-sm-auto">Instructor:
#                                 <span>
# <a href="http://faculty.utah.edu/u0492366/teaching/index.hml" target="_blank">JOSHI, SARANG</a>
# </span>
# </li>
# <li class="col-sm-auto">Component:
#                                 <span>Seminar</span>
# </li>
# <li class="col-sm-auto">Type:
#                                 <span data-type="P">In Person</span>
# </li>
# <li class="col-sm-auto" data-units="U1_0">
#                                 Units: <span>  1.0</span></li>
# <li class="col-sm-auto">Requisites: Yes</li>
# <li class="col-sm-auto">Wait List:
#
#                                 <span>No</span>
# </li>
# <li class="col-sm-auto" data-seats="true">
#                                 Seats Available: <span>20</span>
# </li>
# </ul>
# <div class="buttons">
# <a class="btn btn-secondary btn-sm" href="description.html?subj=CS&amp;catno=7938&amp;section=001">Class Details</a>
# </div>
# </div>
# </div>
# <div class="card-footer mp-1">
# <div class="row mb-2">
# <div class="col">
# <table class="table time-table">
# <thead class="class-cards table minimal-headers">
# <tr>
# <th class="text-nowrap text-left text-muted h6 p-0" scope="col">Days / Times</th>
# <th class="text-nowrap text-right text-muted h6 p-0" scope="col">Locations</th>
# </tr>
# </thead>
# <tbody>
# <tr>
# <th class="text-nowrap text-left p-0" scope="row">
# <span data-day="Mo">Mo</span>/<span data-time="A">12:00PM-01:00PM</span>
# </th>
# <th class="text-nowrap text-right p-0" data-building-code="WEB" scope="row">
# <a href="http://map.utah.edu/index.html?code=WEB" target="_blank">WEB 3760</a>
# </th>
# </tr>
# </tbody>
# </table>
# </div>
# </div>
# <div class="row">
# <div class="col">
# <em> Meets With</em>
# <ul class="mb-0">
# <li>ECE 6960 002</li>
# </ul>
# </div>
# </div>
# </div>
# </div>
# <div class="class-info card mt-3" id="5028">
# <div class="card-body row d-none d-md-block">
# <div class="col-12 p-0">
# <div class="buttons">
# <a class="btn btn-secondary btn-sm" href="description.html?subj=CS&amp;catno=7939&amp;section=001">Class Details</a>
# </div>
# <h3>
# <a href="sections.html?subj=CS&amp;catno=7939">CS 7939</a>
#                         -
#                         <span>001</span>
# <span>Robotics Seminar</span>
# </h3>
# </div>
# <div class="col-12 p-0">
# <ul class="row breadcrumb-list list-unstyled">
# <li class="col-sm-auto">Class Number:
#                             <a id="5028"></a>
# <span>5028</span>
# </li>
# <li class="col-sm-auto">Instructor:
#                             <span>
# <a href="https://profiles.faculty.utah.edu/u6037174" target="_blank">ZHANG, HAOHAN</a>
# </span>
# </li>
# <li class="col-sm-auto">Component:
#                             <span>Seminar</span>
# </li>
# <li class="col-sm-auto">Type:
#                             <span data-type="P">In Person</span>
# </li>
# <li class="col-sm-auto" data-units="U1_0">
#                             Units: <span>  1.0</span>
# </li>
# <li class="col-sm-auto">Requisites: Yes</li>
# <li class="col-sm-auto">Wait List:
#
#                             <span>No</span>
# </li>
# <li class="col-sm-auto d-none" data-seats="true">
#                             Seats Available: <span>8</span>
# </li>
# <li class="col-sm-auto">
# <a href="https://student-course-feedback.app.utah.edu/reports/CS/7939/Seminar" target="_blank">View Feedback</a>
# </li>
# </ul>
# </div>
# </div>
# <div class="card-body row d-block d-md-none">
# <div class="col-12 p-0">
# <h3>
# <a href="sections.html?subj=CS&amp;catno=7939">CS 7939</a>
#                             -
#                             <span>001</span>
# <span>Robotics Seminar</span>
# </h3>
# </div>
# <div class="col-12 p-0">
# <ul class="row list-unstyled">
# <li class="col-sm-auto">Class Number:
#                                 <a name="5028"></a><span>5028</span>
# </li>
# <li class="col-sm-auto">Instructor:
#                                 <span>
# <a href="http://faculty.utah.edu/u6037174/teaching/index.hml" target="_blank">ZHANG, HAOHAN</a>
# </span>
# </li>
# <li class="col-sm-auto">Component:
#                                 <span>Seminar</span>
# </li>
# <li class="col-sm-auto">Type:
#                                 <span data-type="P">In Person</span>
# </li>
# <li class="col-sm-auto" data-units="U1_0">
#                                 Units: <span>  1.0</span></li>
# <li class="col-sm-auto">Requisites: Yes</li>
# <li class="col-sm-auto">Wait List:
#
#                                 <span>No</span>
# </li>
# <li class="col-sm-auto" data-seats="true">
#                                 Seats Available: <span>8</span>
# </li>
# </ul>
# <div class="buttons">
# <a class="btn btn-secondary btn-sm" href="description.html?subj=CS&amp;catno=7939&amp;section=001">Class Details</a>
# </div>
# </div>
# </div>
# <div class="card-footer mp-1">
# <div class="row mb-2">
# <div class="col">
# <table class="table time-table">
# <thead class="class-cards table minimal-headers">
# <tr>
# <th class="text-nowrap text-left text-muted h6 p-0" scope="col">Days / Times</th>
# <th class="text-nowrap text-right text-muted h6 p-0" scope="col">Locations</th>
# </tr>
# </thead>
# <tbody>
# <tr>
# <th class="text-nowrap text-left p-0" scope="row">
# <span data-day="Th">Th</span>/<span data-time="A">02:00PM-02:50PM</span>
# </th>
# <th class="text-nowrap text-right p-0" data-building-code="WEB" scope="row">
# <a href="http://map.utah.edu/index.html?code=WEB" target="_blank">WEB 2230</a>
# </th>
# </tr>
# </tbody>
# </table>
# </div>
# </div>
# <div class="row">
# <div class="col">
# <em> Meets With</em>
# <ul class="mb-0">
# <li>ECE 6868 001</li>
# <li>ME EN 6892 001</li>
# <li>ROBOT 5800 001</li>
# <li>ROBOT 6800 001</li>
# </ul>
# </div>
# </div>
# </div>
# </div>
# <div class="class-info card mt-3" id="6441">
# <div class="card-body row d-none d-md-block">
# <div class="col-12 p-0">
# <div class="buttons">
# <a class="btn btn-secondary btn-sm" href="description.html?subj=CS&amp;catno=7941&amp;section=001">Class Details</a>
# </div>
# <h3>
# <a href="sections.html?subj=CS&amp;catno=7941">CS 7941</a>
#                         -
#                         <span>001</span>
# <span>Data Science Seminar</span>
# </h3>
# </div>
# <div class="col-12 p-0">
# <ul class="row breadcrumb-list list-unstyled">
# <li class="col-sm-auto">Class Number:
#                             <a id="6441"></a>
# <span>6441</span>
# </li>
# <li class="col-sm-auto">Instructor:
#                             <span>
# <a href="https://profiles.faculty.utah.edu/u6001941" target="_blank">BHASKARA, ADITYA</a>
# </span>
# </li>
# <li class="col-sm-auto">Component:
#                             <span>Seminar</span>
# </li>
# <li class="col-sm-auto">Type:
#                             <span data-type="P">In Person</span>
# </li>
# <li class="col-sm-auto" data-units="U1_0">
#                             Units: <span>  1.0</span>
# </li>
# <li class="col-sm-auto">Requisites: Yes</li>
# <li class="col-sm-auto">Wait List:
#
#                             <span>No</span>
# </li>
# <li class="col-sm-auto d-none" data-seats="true">
#                             Seats Available: <span>40</span>
# </li>
# <li class="col-sm-auto">
# <a href="https://student-course-feedback.app.utah.edu/reports/CS/7941/Seminar" target="_blank">View Feedback</a>
# </li>
# </ul>
# </div>
# </div>
# <div class="card-body row d-block d-md-none">
# <div class="col-12 p-0">
# <h3>
# <a href="sections.html?subj=CS&amp;catno=7941">CS 7941</a>
#                             -
#                             <span>001</span>
# <span>Data Science Seminar</span>
# </h3>
# </div>
# <div class="col-12 p-0">
# <ul class="row list-unstyled">
# <li class="col-sm-auto">Class Number:
#                                 <a name="6441"></a><span>6441</span>
# </li>
# <li class="col-sm-auto">Instructor:
#                                 <span>
# <a href="http://faculty.utah.edu/u6001941/teaching/index.hml" target="_blank">BHASKARA, ADITYA</a>
# </span>
# </li>
# <li class="col-sm-auto">Component:
#                                 <span>Seminar</span>
# </li>
# <li class="col-sm-auto">Type:
#                                 <span data-type="P">In Person</span>
# </li>
# <li class="col-sm-auto" data-units="U1_0">
#                                 Units: <span>  1.0</span></li>
# <li class="col-sm-auto">Requisites: Yes</li>
# <li class="col-sm-auto">Wait List:
#
#                                 <span>No</span>
# </li>
# <li class="col-sm-auto" data-seats="true">
#                                 Seats Available: <span>40</span>
# </li>
# </ul>
# <div class="buttons">
# <a class="btn btn-secondary btn-sm" href="description.html?subj=CS&amp;catno=7941&amp;section=001">Class Details</a>
# </div>
# </div>
# </div>
# <div class="card-footer mp-1">
# <div class="row mb-2">
# <div class="col">
# <table class="table time-table">
# <thead class="class-cards table minimal-headers">
# <tr>
# <th class="text-nowrap text-left text-muted h6 p-0" scope="col">Days / Times</th>
# <th class="text-nowrap text-right text-muted h6 p-0" scope="col">Locations</th>
# </tr>
# </thead>
# <tbody>
# <tr>
# <th class="text-nowrap text-left p-0" scope="row">
# <span data-day="Fr">Fr</span>/<span data-time="A">01:25PM-02:45PM</span>
# </th>
# <th class="text-nowrap text-right p-0" data-building-code="WEB" scope="row">
# <a href="http://map.utah.edu/index.html?code=WEB" target="_blank">WEB L112</a>
# </th>
# </tr>
# </tbody>
# </table>
# </div>
# </div>
# <div class="row">
# <div class="col">
# <em> Meets With</em>
# <ul class="mb-0">
# <li>DS 3941 001</li>
# </ul>
# </div>
# </div>
# </div>
# </div>
# <div class="class-info card mt-3" id="6476">
# <div class="card-body row d-none d-md-block">
# <div class="col-12 p-0">
# <div class="buttons">
# <a class="btn btn-secondary btn-sm" href="description.html?subj=CS&amp;catno=7942&amp;section=001">Class Details</a>
# </div>
# <h3>
# <a href="sections.html?subj=CS&amp;catno=7942">CS 7942</a>
#                         -
#                         <span>001</span>
# <span>Visualization Seminar</span>
# </h3>
# </div>
# <div class="col-12 p-0">
# <ul class="row breadcrumb-list list-unstyled">
# <li class="col-sm-auto">Class Number:
#                             <a id="6476"></a>
# <span>6476</span>
# </li>
# <li class="col-sm-auto">Instructor:
#                             <span>
# <a href="https://profiles.faculty.utah.edu/u0731785" target="_blank">PHILLIPS, BEI WANG</a>
# </span>
# </li>
# <li class="col-sm-auto">Component:
#                             <span>Seminar</span>
# </li>
# <li class="col-sm-auto">Type:
#                             <span data-type="P">In Person</span>
# </li>
# <li class="col-sm-auto" data-units="U1_0">
#                             Units: <span>  1.0</span>
# </li>
# <li class="col-sm-auto">Requisites: Yes</li>
# <li class="col-sm-auto">Wait List:
#
#                             <span>No</span>
# </li>
# <li class="col-sm-auto d-none" data-seats="true">
#                             Seats Available: <span>30</span>
# </li>
# <li class="col-sm-auto">
# <a href="https://student-course-feedback.app.utah.edu/reports/CS/7942/Seminar" target="_blank">View Feedback</a>
# </li>
# </ul>
# <hr>
# <span>This class meets in WEB 3780.  </span>
# </hr></div>
# </div>
# <div class="card-body row d-block d-md-none">
# <div class="col-12 p-0">
# <h3>
# <a href="sections.html?subj=CS&amp;catno=7942">CS 7942</a>
#                             -
#                             <span>001</span>
# <span>Visualization Seminar</span>
# </h3>
# </div>
# <div class="col-12 p-0">
# <ul class="row list-unstyled">
# <li class="col-sm-auto">Class Number:
#                                 <a name="6476"></a><span>6476</span>
# </li>
# <li class="col-sm-auto">Instructor:
#                                 <span>
# <a href="http://faculty.utah.edu/u0731785/teaching/index.hml" target="_blank">PHILLIPS, BEI WANG</a>
# </span>
# </li>
# <li class="col-sm-auto">Component:
#                                 <span>Seminar</span>
# </li>
# <li class="col-sm-auto">Type:
#                                 <span data-type="P">In Person</span>
# </li>
# <li class="col-sm-auto" data-units="U1_0">
#                                 Units: <span>  1.0</span></li>
# <li class="col-sm-auto">Requisites: Yes</li>
# <li class="col-sm-auto">Wait List:
#
#                                 <span>No</span>
# </li>
# <li class="col-sm-auto" data-seats="true">
#                                 Seats Available: <span>30</span>
# </li>
# </ul>
# <div class="buttons">
# <a class="btn btn-secondary btn-sm" href="description.html?subj=CS&amp;catno=7942&amp;section=001">Class Details</a>
# </div>
# <hr class="class-notes-divider"/>
# <span>This class meets in WEB 3780.  </span>
# </div>
# </div>
# <div class="card-footer mp-1">
# <div class="row mb-2">
# <div class="col">
# <table class="table time-table">
# <thead class="class-cards table minimal-headers">
# <tr>
# <th class="text-nowrap text-left text-muted h6 p-0" scope="col">Days / Times</th>
# <th class="text-nowrap text-right text-muted h6 p-0" scope="col">Locations</th>
# </tr>
# </thead>
# <tbody>
# <tr>
# <th class="text-nowrap text-left p-0" scope="row">
# <span data-day="We">We</span>/<span data-time="A">12:00PM-01:00PM</span>
# </th>
# <th class="text-nowrap text-right p-0" data-building-code="TBA" scope="row">
# <span>TBA .</span>
# </th>
# </tr>
# </tbody>
# </table>
# </div>
# </div>
# </div>
# </div>
# </div>

# %%
import pandas as pd

course_table = []
for course in courses.find_all(class_="class-info"):
    # the first link nested under a h3 element contains the course number
    course_number = course.select('h3>a')[0].get_text()
    # the second span nested under a h3 element is the course title
    course_title = course.select('h3>span')[1].get_text()
    # the link is easy to get
    course_link = course.select('h3>a')[0].get("href")
    # the instructor is in a div>ul>li a hierarchy. Note that we're just getting the first listed instructor here.
    instructor_name = course.select('div>ul>li a')[1].get_text()
    course_table.append([course_number, course_title, course_link, instructor_name])

course_df = pd.DataFrame(course_table, columns=["number", "title", "link", "instructor"])    
course_df.head(30)
# Out:
#      number                    title                              link  \
# 0   CS 1400   Intro Comp Programming  sections.html?subj=CS&catno=1400
# 1   CS 1400   Intro Comp Programming  sections.html?subj=CS&catno=1400
# 2   CS 1400   Intro Comp Programming  sections.html?subj=CS&catno=1400
# 3   CS 1400   Intro Comp Programming  sections.html?subj=CS&catno=1400
# 4   CS 1400   Intro Comp Programming  sections.html?subj=CS&catno=1400
# 5   CS 1400   Intro Comp Programming  sections.html?subj=CS&catno=1400
# 6   CS 1410     Object-Oriented Prog  sections.html?subj=CS&catno=1410
# 7   CS 1410     Object-Oriented Prog  sections.html?subj=CS&catno=1410
# 8   CS 1410     Object-Oriented Prog  sections.html?subj=CS&catno=1410
# 9   CS 1410     Object-Oriented Prog  sections.html?subj=CS&catno=1410
# 10  CS 1410     Object-Oriented Prog  sections.html?subj=CS&catno=1410
# 11  CS 1410     Object-Oriented Prog  sections.html?subj=CS&catno=1410
# 12  CS 1410     Object-Oriented Prog  sections.html?subj=CS&catno=1410
# 13  CS 1410     Object-Oriented Prog  sections.html?subj=CS&catno=1410
# 14  CS 1420    Accel Obj-Orient Prog  sections.html?subj=CS&catno=1420
# 15  CS 1420    Accel Obj-Orient Prog  sections.html?subj=CS&catno=1420
# 16  CS 1420    Accel Obj-Orient Prog  sections.html?subj=CS&catno=1420
# 17  CS 1420    Accel Obj-Orient Prog  sections.html?subj=CS&catno=1420
# 18  CS 1420    Accel Obj-Orient Prog  sections.html?subj=CS&catno=1420
# 19  CS 1420    Accel Obj-Orient Prog  sections.html?subj=CS&catno=1420
# 20  CS 1810    Intro to Comp Systems  sections.html?subj=CS&catno=1810
# 21  CS 1810    Intro to Comp Systems  sections.html?subj=CS&catno=1810
# 22  CS 1810    Intro to Comp Systems  sections.html?subj=CS&catno=1810
# 23  CS 2100      Discrete Structures  sections.html?subj=CS&catno=2100
# 24  CS 2100      Discrete Structures  sections.html?subj=CS&catno=2100
# 25  CS 2100      Discrete Structures  sections.html?subj=CS&catno=2100
# 26  CS 2100      Discrete Structures  sections.html?subj=CS&catno=2100
# 27  CS 2100      Discrete Structures  sections.html?subj=CS&catno=2100
# 28  CS 2100      Discrete Structures  sections.html?subj=CS&catno=2100
# 29  CS 2420  Intro Alg & Data Struct  sections.html?subj=CS&catno=2420
#
#           instructor
# 0      BROWN, NOELLE
# 1      BROWN, NOELLE
# 2      BROWN, NOELLE
# 3      BROWN, NOELLE
# 4      BROWN, NOELLE
# 5      BROWN, NOELLE
# 6   MARTIN, TRAVIS B
# 7   MARTIN, TRAVIS B
# 8   MARTIN, TRAVIS B
# 9   MARTIN, TRAVIS B
# 10  MARTIN, TRAVIS B
# 11  MARTIN, TRAVIS B
# 12  MARTIN, TRAVIS B
# 13  MARTIN, TRAVIS B
# 14        JONES, BEN
# 15        JONES, BEN
# 16        JONES, BEN
# 17        JONES, BEN
# 18        JONES, BEN
# 19        JONES, BEN
# 20      PARKER, ERIN
# 21      PARKER, ERIN
# 22      PARKER, ERIN
# 23     View Feedback
# 24     View Feedback
# 25     View Feedback
# 26     View Feedback
# 27     View Feedback
# 28     View Feedback
# 29     View Feedback

# %% [markdown]
# This table has a lot of duplicates because of the different sections that we're ignoring here. Let's de-duplicate:

# %%
course_df = course_df.drop_duplicates()
course_df.head(30)
# Out:
#      number                           title                              link  \
# 0   CS 1400          Intro Comp Programming  sections.html?subj=CS&catno=1400
# 6   CS 1410            Object-Oriented Prog  sections.html?subj=CS&catno=1410
# 14  CS 1420           Accel Obj-Orient Prog  sections.html?subj=CS&catno=1420
# 20  CS 1810           Intro to Comp Systems  sections.html?subj=CS&catno=1810
# 23  CS 2100             Discrete Structures  sections.html?subj=CS&catno=2100
# 29  CS 2420         Intro Alg & Data Struct  sections.html?subj=CS&catno=2420
# 44  CS 3011                  Industry Forum  sections.html?subj=CS&catno=3011
# 45  CS 3090             Ethics in Computing  sections.html?subj=CS&catno=3090
# 46  CS 3100           Models Of Computation  sections.html?subj=CS&catno=3100
# 47  CS 3130                  Eng Prob Stats  sections.html?subj=CS&catno=3130
# 48  CS 3200                  Intro Sci Comp  sections.html?subj=CS&catno=3200
# 49  CS 3500               Software Practice  sections.html?subj=CS&catno=3500
# 59  CS 3505            Software Practice II  sections.html?subj=CS&catno=3505
# 66  CS 3540         Design Human Center Sys  sections.html?subj=CS&catno=3540
# 67  CS 3550              Web Software Dev I  sections.html?subj=CS&catno=3550
# 68  CS 3700           Digital System Design  sections.html?subj=CS&catno=3700
# 70  CS 3810           Computer Organization  sections.html?subj=CS&catno=3810
# 71  CS 3960  Human-Centered Data Management  sections.html?subj=CS&catno=3960
# 72  CS 3992          Pre-Thesis/Clinic/Proj  sections.html?subj=CS&catno=3992
# 73  CS 4000          Senior Capstone Design  sections.html?subj=CS&catno=4000
# 74  CS 4150                      Algorithms  sections.html?subj=CS&catno=4150
# 75  CS 4400                Computer Systems  sections.html?subj=CS&catno=4400
# 83  CS 4440               Computer Security  sections.html?subj=CS&catno=4440
# 84  CS 4470                       Compilers  sections.html?subj=CS&catno=4470
# 85  CS 4480               Computer Networks  sections.html?subj=CS&catno=4480
# 86  CS 4500         Senior Capstone Project  sections.html?subj=CS&catno=4500
# 87  CS 4530          Mobile App Programming  sections.html?subj=CS&catno=4530
# 88  CS 4550             Web Software Dev II  sections.html?subj=CS&catno=4550
# 89  CS 4960      Theory of Machine Learning  sections.html?subj=CS&catno=4960
# 90  CS 4961  Parallel Num Software Crctness  sections.html?subj=CS&catno=4961
#
#                  instructor
# 0             BROWN, NOELLE
# 6          MARTIN, TRAVIS B
# 14               JONES, BEN
# 20             PARKER, ERIN
# 23            View Feedback
# 29            View Feedback
# 44             WIESE, Jason
# 45            BROWN, NOELLE
# 46             WANG, HAITAO
# 47            Zhe, Shandian
# 48          BERZINS, MARTIN
# 49            View Feedback
# 59            HEISLER, ERIC
# 66             WIESE, Jason
# 67           JOHNSON, DAVID
# 68             GARCIA, LUIS
# 70  BALASUBRAMONIAN, RAJEEV
# 71             FARIHA, ANNA
# 72            PATWARI, NEAL
# 73      DE ST GERMAIN, JOHN
# 74         MARTIN, TRAVIS B
# 75             REGEHR, JOHN
# 83                  XU, JUN
# 84       GREENMAN, BENJAMIN
# 85   VAN DER MERWE, Jacobus
# 86              BEAN, DAVID
# 87               JONES, BEN
# 88              WOOD, AARON
# 89         BHASKARA, ADITYA
# 90   GOPALAKRISHNAN, GANESH

# %% [markdown]
# So who's teaching the most Lectures/Seminars/Special Topic Courses this semester?

# %%
course_df["instructor"].value_counts()
# Out:
# instructor
# View Feedback                    3
# BHASKARA, ADITYA                 3
# BROWN, NOELLE                    2
# JOHNSON, CHRISTOPHER             2
# Sullivan, Blair                  2
# WIESE, ELIANE S                  2
# REZIG, EL KINDI                  2
# PHILLIPS, JEFF                   2
# MARTIN, TRAVIS B                 2
# YUKSEL, CEM                      2
# BROWN, DANIEL                    2
# GAILLARDON, PIERRE-EMMANUEL J    2
# NAGY, STEFAN                     2
# PANDEY, VINEET                   2
# FLATT, Matthew                   2
# YANG, YIN                        2
# PHILLIPS, BEI WANG               2
# KOGAN, MARINA                    2
# GOPALAKRISHNAN, GANESH           2
# BURTSEV, ANTON                   2
# GREENMAN, BENJAMIN               2
# DE ST GERMAIN, JOHN              2
# WIESE, Jason                     2
# PATWARI, NEAL                    2
# FARIHA, ANNA                     2
# JONES, BEN                       2
# BEAN, DAVID                      1
# PARKER, ERIN                     1
# KUNTZ, ALAN                      1
# KASERA, SNEHA K                  1
# ZHANG, MU                        1
# HENDERSON, THOMAS                1
# HERMANS, Tucker                  1
# MARASOVIC, ANA                   1
# MCNUTT, ANDREW                   1
# MASCARO, STEPHEN A               1
# IMEL, ZAC                        1
# EIDE, ERIC N                     1
# NAGARAJAN, VIJAYANAND            1
# JOSHI, SARANG                    1
# SRIKUMAR, Vivek                  1
# MAKAREM, NABIL                   1
# LEX, ALEXANDER                   1
# WOOD, AARON                      1
# WANG, HAITAO                     1
# Zhe, Shandian                    1
# BERZINS, MARTIN                  1
# TAO, GUANHONG                    1
# HEISLER, ERIC                    1
# JOHNSON, DAVID                   1
# GARCIA, LUIS                     1
# BALASUBRAMONIAN, RAJEEV          1
# KOPTA, DANIEL                    1
# STEVENS, KENNETH S               1
# REGEHR, JOHN                     1
# XU, JUN                          1
# VAN DER MERWE, Jacobus           1
# ZHANG, HAOHAN                    1
# Name: count, dtype: int64

# %% [markdown]
# Do you notice anything wrong with this?

# %% [markdown]
# ### Counting Enrollment
#
# But let's look at which classes have the most students. To do this, we have to go one more level down and retreice the class details.
#
# Here is what the html looks like:
#
# ![Inspecting the course details table](table.png)
#
# This is in an actual html table. That's nice, because we can use pandas to read a html table!

# %%
enrollment_url = "https://class-schedule.app.utah.edu/main/1254/sections.html?subj=CS&catno=4500"
with urllib.request.urlopen(enrollment_url) as response:
    class_student_html = response.read()
class_student_soup = BeautifulSoup(class_student_html, 'html.parser')

# %%
# we use pandas to read the table
student_ar = pd.read_html(str(class_student_soup))
# The dataframe is wrapped in an array, we can get the DF out of it
student_df = student_ar[0]
student_df
# Out:
# /var/folders/nj/_p8y5bj50sb4sp0v6f3th6w80000gn/T/ipykernel_68222/676324291.py:2: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   student_ar = pd.read_html(str(class_student_soup))
#    Class # Subject  Catalog #  Section                    Title  \
# 0     4841      CS       4500        1  Senior Capstone Project
#
#                    Title.1  Enrollment Cap  Wait List  Currently Enrolled  \
# 0  Senior Capstone Project             168          0                 103
#
#    Seats Available
# 0               65

# %% [markdown]
# Now, we can retreive the student number:

# %%
students = student_df["Currently Enrolled"][0]
students
# Out:
# 103

# %% [markdown]
# Let's pack this all up in a function that takes the URL and returns the number:

# %%
from io import StringIO

base_url = 'https://class-schedule.app.utah.edu/main/1254/'
def scrape_students(sub_url):
    """
    Retrieve the number of students from the table on the website specified in the URL
    """
    with urllib.request.urlopen(base_url+sub_url) as response:
        class_student_html = response.read()
    class_student_soup = BeautifulSoup(class_student_html, 'html.parser')
    # we use pandas to read the table
    student_df = pd.read_html(StringIO(str(class_student_soup)))[0]
    students = student_df["Currently Enrolled"][0]
    return students

# %%
# Let's test this with the first course
scrape_students(course_df['link'][0])
# Out:
# 30

# %% [markdown]
# Now we can do this for all the courses. **Warning!!** this actually runs lots of requests, so don't re-run this excessively, or you might get blocked.

# %%
course_df['students'] = course_df['link'].apply(scrape_students)

# %%
course_df.sort_values(by="students", ascending=False, inplace=True)
course_df.head(30)
# Out:
#       number                           title  \
# 97   CS 5530                Database Systems
# 6    CS 1410            Object-Oriented Prog
# 29   CS 2420         Intro Alg & Data Struct
# 86   CS 4500         Senior Capstone Project
# 46   CS 3100           Models Of Computation
# 75   CS 4400                Computer Systems
# 67   CS 3550              Web Software Dev I
# 59   CS 3505            Software Practice II
# 74   CS 4150                      Algorithms
# 44   CS 3011                  Industry Forum
# 85   CS 4480               Computer Networks
# 45   CS 3090             Ethics in Computing
# 73   CS 4000          Senior Capstone Design
# 118  CS 6140                     Data Mining
# 96   CS 5460               Operating Systems
# 83   CS 4440               Computer Security
# 122  CS 6460               Operating Systems
# 87   CS 4530          Mobile App Programming
# 84   CS 4470                       Compilers
# 120  CS 6350                Machine Learning
# 124  CS 6491         Software & Sys Security
# 70   CS 3810           Computer Organization
# 141  CS 6964       Manage Data for & with ML
# 47   CS 3130                  Eng Prob Stats
# 71   CS 3960  Human-Centered Data Management
# 0    CS 1400          Intro Comp Programming
# 48   CS 3200                  Intro Sci Comp
# 88   CS 4550             Web Software Dev II
# 123  CS 6490                Network Security
# 133  CS 6955     Adv Artificial Intelligence
#
#                                  link               instructor  students
# 97   sections.html?subj=CS&catno=5530            KOPTA, DANIEL       132
# 6    sections.html?subj=CS&catno=1410         MARTIN, TRAVIS B       118
# 29   sections.html?subj=CS&catno=2420            View Feedback       105
# 86   sections.html?subj=CS&catno=4500              BEAN, DAVID       103
# 46   sections.html?subj=CS&catno=3100             WANG, HAITAO        97
# 75   sections.html?subj=CS&catno=4400             REGEHR, JOHN        80
# 67   sections.html?subj=CS&catno=3550           JOHNSON, DAVID        76
# 59   sections.html?subj=CS&catno=3505            HEISLER, ERIC        65
# 74   sections.html?subj=CS&catno=4150         MARTIN, TRAVIS B        65
# 44   sections.html?subj=CS&catno=3011             WIESE, Jason        54
# 85   sections.html?subj=CS&catno=4480   VAN DER MERWE, Jacobus        52
# 45   sections.html?subj=CS&catno=3090            BROWN, NOELLE        51
# 73   sections.html?subj=CS&catno=4000      DE ST GERMAIN, JOHN        40
# 118  sections.html?subj=CS&catno=6140           PHILLIPS, JEFF        39
# 96   sections.html?subj=CS&catno=5460           BURTSEV, ANTON        38
# 83   sections.html?subj=CS&catno=4440                  XU, JUN        37
# 122  sections.html?subj=CS&catno=6460           BURTSEV, ANTON        37
# 87   sections.html?subj=CS&catno=4530               JONES, BEN        37
# 84   sections.html?subj=CS&catno=4470       GREENMAN, BENJAMIN        36
# 120  sections.html?subj=CS&catno=6350          SRIKUMAR, Vivek        36
# 124  sections.html?subj=CS&catno=6491                ZHANG, MU        35
# 70   sections.html?subj=CS&catno=3810  BALASUBRAMONIAN, RAJEEV        34
# 141  sections.html?subj=CS&catno=6964          REZIG, EL KINDI        32
# 47   sections.html?subj=CS&catno=3130            Zhe, Shandian        30
# 71   sections.html?subj=CS&catno=3960             FARIHA, ANNA        30
# 0    sections.html?subj=CS&catno=1400            BROWN, NOELLE        30
# 48   sections.html?subj=CS&catno=3200          BERZINS, MARTIN        29
# 88   sections.html?subj=CS&catno=4550              WOOD, AARON        29
# 123  sections.html?subj=CS&catno=6490          KASERA, SNEHA K        29
# 133  sections.html?subj=CS&catno=6955            BROWN, DANIEL        28

# %% [markdown]
# Now, we want to answer the question **at which level are the most students enrolled in CS?** Levels are the leading digit of the course number. Let's create a new column level and add it to the dataframe:

# %%
# the 4th character in CS 1410 is "1", which corresponds to the level.
course_df["level"] = course_df["number"].map(lambda x: (str(x)[3]))
course_df = course_df.sort_values(by="level")
course_df.head(100)
# Out:
#       number                           title  \
# 6    CS 1410            Object-Oriented Prog
# 14   CS 1420           Accel Obj-Orient Prog
# 0    CS 1400          Intro Comp Programming
# 20   CS 1810           Intro to Comp Systems
# 29   CS 2420         Intro Alg & Data Struct
# ..       ...                             ...
# 147  CS 7930                             001
# 149  CS 7932        Human-Centered Computing
# 152  CS 7936  Types, Inference, & Proof Sear
# 156  CS 7941            Data Science Seminar
# 157  CS 7942           Visualization Seminar
#
#                                  link          instructor  students level
# 6    sections.html?subj=CS&catno=1410    MARTIN, TRAVIS B       118     1
# 14   sections.html?subj=CS&catno=1420          JONES, BEN        20     1
# 0    sections.html?subj=CS&catno=1400       BROWN, NOELLE        30     1
# 20   sections.html?subj=CS&catno=1810        PARKER, ERIN        11     1
# 29   sections.html?subj=CS&catno=2420       View Feedback       105     2
# ..                                ...                 ...       ...   ...
# 147  sections.html?subj=CS&catno=7930      MARASOVIC, ANA         1     7
# 149  sections.html?subj=CS&catno=7932       KOGAN, MARINA         3     7
# 152  sections.html?subj=CS&catno=7936  GREENMAN, BENJAMIN         3     7
# 156  sections.html?subj=CS&catno=7941    BHASKARA, ADITYA         0     7
# 157  sections.html?subj=CS&catno=7942  PHILLIPS, BEI WANG         0     7
#
# [86 rows x 6 columns]

# %% [markdown]
# We can calculate the answer with groupby:

# %%
import numpy as np


#student_stats = course_df.groupby("level")["students"].agg([np.sum, np.mean, np.std, np.size])
student_stats = course_df.groupby("level")["students"].agg(["sum", "mean", "std", "size"])
student_stats
# Out:
#        sum       mean        std  size
# level
# 1      179  44.750000  49.446099     4
# 2      132  66.000000  55.154329     2
# 3      511  39.307692  28.229372    13
# 4      490  32.666667  32.155130    15
# 5      229  22.900000  40.264266    10
# 6      540  17.419355  11.485568    31
# 7       10   0.909091   1.221028    11

# %% [markdown]
# Let's visualize this with box plots:

# %%
props = dict(linewidth=2)
# here we group by level
course_df.boxplot(by='level', figsize=(8, 6),  boxprops=props, medianprops=props, whiskerprops=props, capprops=props)
# Out:
# <Axes: title={'center': 'students'}, xlabel='[level]'>

# %% [markdown]
# And plot a bar chart for the number of students in the classes:

# %%
student_sum = course_df.groupby("level").aggregate("sum")
student_sum.plot.bar(legend=False, figsize=(6, 4))
# Out:
# <Axes: xlabel='level'>

# %% [markdown]
# We can see that the most students are in the 3000/4000 level and there is a small peak at the 6000 level classes.

# %% [markdown]
# ## Scraping Wrap-Up
#
# Scraping is a way to get information from website that were not designed to make data accessible. As such, it can often be **brittle**: a website change will break your scraping script. It is also often not welcome, as a scaper can cause a lot of traffic.
#
# The way we scraped information here also made the **assumption that HTML is generated consistently** based just on the URL. That is, unfortunately, less and less common, as websites adapt to browser types, resolutions, locales, but also as a lot of content is loaded dynamically e.g., via web-sockets. For example, many websites now auotmatically load more data once you scroll to the bottom of the page. These websites couldn't be scraped with our approach, instead, a browser-emulation approach, using e.g., [Selenium]() would be necessary. [Here is a tutorial](https://medium.com/the-andela-way/introduction-to-web-scraping-using-selenium-7ec377a8cf72) on how to do that.
#
# Finally, many services make their data available through a well-defined interface, an API. Using an API is always a better idea than scraping, but scraping is a good fallback!

# %% [markdown]
# ## Exercise 1: Exceptional Olympians
#
# Scrape data from [this wikipedia site](https://en.wikipedia.org/wiki/List_of_multiple_Olympic_medalists) about exceptional Olympic medalists.
#
# 1. Download the html using urllib.
# 2. Parse this html with BeautifulSoup.
# 3. Extract the html that corresponds to the big table from the soup.
# 4. Parse the table into a pandas dataframe. Hint: both the "No." and the "Total." column use row-spans which are tricky to parse, both with a pandas reader and manually. For the purpose of this exercise, exclude all rows that are not easy to parse.
# 5. Create a table that shows for each country how many gold, silver, bronze, and total medals it won in that list.
